# %% [markdown]
# # imports

# %%
import math
import os
from dataclasses import dataclass
from typing import Optional, Dict, Any, List

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.nn.functional as F
from datasets import load_dataset
from transformers import (
    T5ForConditionalGeneration,
    T5TokenizerFast,
    GPT2LMHeadModel,
    GPT2TokenizerFast,
)

# %% [markdown]
# # functions

# %%
@dataclass
class ExperimentConfig:
    model_name: str = "t5-large"
    gpt2_name: str = "gpt2"
    max_source_length: int = 256
    max_target_length: int = 4
    batch_size: int = 16
    lr: float = 1e-3
    num_epochs: int = 5
    prompt_length: int = 10
    lambda_grid: List[float] = None
    device: str = "cuda" if torch.cuda.is_available() else "cpu"

    def __post_init__(self):
        if self.lambda_grid is None:
            self.lambda_grid = [0.0, 0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1.0]

# %%
def preprocess_boolq(example, tokenizer: T5TokenizerFast, max_source_length: int, max_target_length: int):
    """
    Turn BoolQ into T5 inputs:
      "question: {question} passage: {passage}"
    Targets are "yes" or "no".
    """
    question = example["question"]
    passage = example["passage"]
    answer = "yes" if example["answer"] else "no"

    source = f"question: {question} passage: {passage}"
    target = answer

    model_inputs = tokenizer(
        source,
        truncation=True,
        padding="max_length",
        max_length=max_source_length,
    )

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            target,
            truncation=True,
            padding="max_length",
            max_length=max_target_length,
        )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs


def load_boolq(tokenizer: T5TokenizerFast, cfg: ExperimentConfig):
    ds = load_dataset("boolq")

    preprocess_fn = lambda ex: preprocess_boolq(
        ex,
        tokenizer=tokenizer,
        max_source_length=cfg.max_source_length,
        max_target_length=cfg.max_target_length,
    )

    ds = ds.map(preprocess_fn, batched=False)
    ds.set_format(
        type="torch",
        columns=["input_ids", "attention_mask", "labels"],
    )

    train_dl = DataLoader(ds["train"], batch_size=cfg.batch_size, shuffle=True)
    val_dl = DataLoader(ds["validation"], batch_size=cfg.batch_size, shuffle=False)


    return train_dl, val_dl


def load_boolq_balanced(tokenizer: T5TokenizerFast, cfg: ExperimentConfig, seed: int = 42):
    """
    Load BoolQ, balance the train split on the raw dataset (True/False),
    then preprocess into T5-style inputs and wrap in DataLoaders.
    """
    raw = load_dataset("boolq")
    train_raw = raw["train"]
    val_raw   = raw["validation"]

    # --- Balance train: downsample majority label ---
    true_indices  = [i for i, ex in enumerate(train_raw) if ex["answer"]]
    false_indices = [i for i, ex in enumerate(train_raw) if not ex["answer"]]

    min_count = min(len(true_indices), len(false_indices))
    true_indices  = true_indices[:min_count]
    false_indices = false_indices[:min_count]

    balanced_indices = true_indices + false_indices
    # Optional but usually helpful: shuffle indices for randomness
    rng = torch.Generator().manual_seed(seed)
    perm = torch.randperm(len(balanced_indices), generator=rng).tolist()
    balanced_indices = [balanced_indices[i] for i in perm]

    train_balanced = train_raw.select(balanced_indices)

    print(
        f"Balanced BoolQ train: {len(train_balanced)} examples "
        f"({min_count} True, {min_count} False)"
    )

    # --- Preprocess to T5 format ---
    def preprocess_fn(ex):
        return preprocess_boolq(
            ex,
            tokenizer=tokenizer,
            max_source_length=cfg.max_source_length,
            max_target_length=cfg.max_target_length,
        )

    train_proc = train_balanced.map(preprocess_fn, batched=False)
    val_proc   = val_raw.map(preprocess_fn, batched=False)

    # Keep only the model fields and cast to torch
    cols = ["input_ids", "attention_mask", "labels"]
    train_proc.set_format(type="torch", columns=cols)
    val_proc.set_format(type="torch", columns=cols)

    train_dl = DataLoader(train_proc, batch_size=cfg.batch_size, shuffle=True)
    val_dl   = DataLoader(val_proc,   batch_size=cfg.batch_size, shuffle=False)

    return train_dl, val_dl

# %%
from collections import Counter

ds = load_dataset("boolq")
labels = [ex["answer"] for ex in ds["train"]]   # True/False labels
ctr = Counter(labels)

num_true  = ctr[True]
num_false = ctr[False]
total     = num_true + num_false

print("num_true:", num_true)
print("num_false:", num_false)
print("P(True) =", num_true / total)
print("P(False) =", num_false / total)
# Out:
# num_true: 5874
# num_false: 3553
# P(True) = 0.6231038506417736
# P(False) = 0.37689614935822635

# %%
class T5ContinuousSoftPrompt(nn.Module):
    """
    Continuous soft prompts: learn a (prompt_length, d_model) tensor
    and prepend it as prefix embeddings to the encoder input.
    """

    def __init__(self, base: T5ForConditionalGeneration, prompt_length: int):
        super().__init__()
        self.t5 = base
        self.prompt_length = prompt_length

        d_model = base.encoder.embed_tokens.weight.shape[1]
        self.soft_prompt = nn.Parameter(
            torch.zeros(prompt_length, d_model)
        )
        nn.init.normal_(self.soft_prompt, mean=0.0, std=0.02)

    def forward(
        self,
        input_ids: torch.Tensor,
        attention_mask: torch.Tensor,
        labels: torch.Tensor,
    ):
        batch_size = input_ids.size(0)
        device = input_ids.device

        # Original token embeddings
        inputs_embeds = self.t5.encoder.embed_tokens(input_ids)

        # Broadcast prompt to batch
        prompt_embeds = self.soft_prompt.unsqueeze(0).expand(batch_size, -1, -1)

        # Prepend to input sequence
        inputs_embeds = torch.cat([prompt_embeds, inputs_embeds], dim=1)

        # Extend attention mask
        prompt_mask = torch.ones(batch_size, self.prompt_length, device=device, dtype=attention_mask.dtype)
        attention_mask = torch.cat([prompt_mask, attention_mask], dim=1)

        outputs = self.t5(
            inputs_embeds=inputs_embeds,
            attention_mask=attention_mask,
            labels=labels,
        )
        return outputs  # has .loss and .logits

# %%
class T5PEZPrompt(nn.Module):
    """
    PEZ-style one-hot prompt over the T5 vocabulary.

    - self.prompt is (L, V) with rows ~ one-hot
    - FORWARD: treat self.prompt as continuous, embed via matrix multiply
               prompt_embeds = prompt @ embed_tokens.weight
      This keeps the computation differentiable w.r.t. self.prompt.
    - DISCRETIZATION: use argmax *outside* the forward (for decoding / GPT-2).
    """

    def __init__(self, base: T5ForConditionalGeneration, prompt_length: int):
        super().__init__()
        self.t5 = base
        self.vocab_size = base.encoder.embed_tokens.weight.shape[0]
        self.prompt_length = prompt_length

        # Initialize as random one-hot rows
        init_ids = torch.randint(0, self.vocab_size, (prompt_length,))
        prompt = torch.nn.functional.one_hot(init_ids, num_classes=self.vocab_size).float()
        self.prompt = nn.Parameter(prompt)  # (L, V), requires_grad=True by default

    # ---- helper used ONLY for decoding / perplexity, NOT in forward ----
    def get_prompt_token_ids(self) -> torch.Tensor:
        return self.prompt.argmax(dim=-1)  # (L,)

    def decode_prompt(self, tokenizer: T5TokenizerFast) -> str:
        token_ids = self.get_prompt_token_ids().tolist()
        return tokenizer.decode(token_ids, skip_special_tokens=True)

    # ---- differentiable forward ----
    def forward(
        self,
        input_ids: torch.Tensor,
        attention_mask: torch.Tensor,
        labels: torch.Tensor,
    ):
        """
        Embed prompt by multiplying the (L, V) prompt matrix with the
        (V, d_model) embedding matrix. This is linear in self.prompt,
        so gradients flow into self.prompt.
        """
        batch_size = input_ids.size(0)
        device = input_ids.device

        # 1) Embed the prompt: (L, V) @ (V, d) -> (L, d)
        embed_matrix = self.t5.encoder.embed_tokens.weight  # (V, d_model)
        prompt_embeds = self.prompt @ embed_matrix          # (L, d_model)
        prompt_embeds = prompt_embeds.unsqueeze(0).expand(batch_size, -1, -1)

        # 2) Embed the original input tokens
        inputs_embeds = self.t5.encoder.embed_tokens(input_ids)

        # 3) Prepend prompt embeddings
        inputs_embeds = torch.cat([prompt_embeds, inputs_embeds], dim=1)

        # 4) Extend attention mask
        prompt_mask = torch.ones(
            batch_size,
            self.prompt_length,
            device=device,
            dtype=attention_mask.dtype,
        )
        attention_mask = torch.cat([prompt_mask, attention_mask], dim=1)

        # 5) Standard T5 forward
        outputs = self.t5(
            inputs_embeds=inputs_embeds,
            attention_mask=attention_mask,
            labels=labels,
        )
        return outputs  # has .loss and .logits

# %%
def compute_prompt_ppl_loss_from_text(
    gpt2_model: GPT2LMHeadModel,
    gpt2_tokenizer: GPT2TokenizerFast,
    prompt_text: str,
    device: str,
) -> torch.Tensor:
    """
    Take the decoded prompt text, feed to GPT-2, compute LM loss.
    Returns 0.0 if the text tokenizes to an empty sequence.
    """
    # Guard 1: decoded text is empty or whitespace
    if not prompt_text or not prompt_text.strip():
        return torch.tensor(0.0, device=device)

    enc = gpt2_tokenizer(
        prompt_text,
        return_tensors="pt",
        truncation=True,
    )
    input_ids = enc["input_ids"].to(device)

    # Guard 2: tokenizer produced no tokens
    if input_ids.numel() == 0:
        return torch.tensor(0.0, device=device)

    labels = input_ids.clone()
    with torch.no_grad():
        outputs = gpt2_model(input_ids=input_ids, labels=labels)
    return outputs.loss

# %%
@torch.no_grad()
def evaluate_accuracy_t5(model: nn.Module, dataloader: DataLoader,
                         tokenizer: T5TokenizerFast, device: str) -> Dict[str, float]:
    """
    BoolQ accuracy for T5-style models:
    - We look at the first decoder position's logits (position 0 in labels)
    - Compare scores for 'yes' vs 'no'
    
    Returns a dictionary with:
    - 'overall': overall accuracy
    - 'true_acc': accuracy on questions where answer is True (yes)
    - 'false_acc': accuracy on questions where answer is False (no)
    """

    model.eval()

    # Correct way to get the IDs for "yes" / "no" for T5
    yes_id = tokenizer("yes", add_special_tokens=False).input_ids[0]
    no_id  = tokenizer("no",  add_special_tokens=False).input_ids[0]

    correct = 0
    total = 0
    
    # Separate tracking for True and False answers
    correct_true = 0
    total_true = 0
    correct_false = 0
    total_false = 0

    for batch in dataloader:
        input_ids      = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels         = batch["labels"].to(device)

        # Forward pass: all your wrappers accept labels=...
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels,
        )
        # logits: (B, T_out, V)
        logits = outputs.logits

        # First decoder step (the token that should be "yes" or "no")
        first_step_logits = logits[:, 0, :]  # (B, V)

        # Scores only for "yes" and "no"
        yes_scores = first_step_logits[:, yes_id]
        no_scores  = first_step_logits[:, no_id]

        # Predict yes if yes_score >= no_score else no
        pred_is_yes = (yes_scores >= no_scores)

        # Ground truth: first label token
        target_ids  = labels[:, 0]
        target_is_yes = (target_ids == yes_id)
        target_is_no  = (target_ids == no_id)

        # Correct if our yes/no prediction matches target
        correct_batch = (pred_is_yes & target_is_yes) | (~pred_is_yes & target_is_no)
        correct += correct_batch.sum().item()
        total   += target_ids.size(0)
        
        # Track accuracy separately for True and False answers
        # True answers (yes)
        true_mask = target_is_yes
        if true_mask.any():
            correct_true_batch = (pred_is_yes & target_is_yes)[true_mask]
            correct_true += correct_true_batch.sum().item()
            total_true += true_mask.sum().item()
        
        # False answers (no)
        false_mask = target_is_no
        if false_mask.any():
            correct_false_batch = (~pred_is_yes & target_is_no)[false_mask]
            correct_false += correct_false_batch.sum().item()
            total_false += false_mask.sum().item()

    overall_acc = correct / total if total > 0 else 0.0
    true_acc = correct_true / total_true if total_true > 0 else 0.0
    false_acc = correct_false / total_false if total_false > 0 else 0.0
    
    return {
        "overall": overall_acc,
        "true_acc": true_acc,
        "false_acc": false_acc
    }

# %%
def train_continuous_soft_prompt(
    cfg: ExperimentConfig,
    tokenizer: T5TokenizerFast,
    train_dl: DataLoader,
    val_dl: DataLoader,
    adversarial: bool,
) -> Dict[str, Any]:
    device = cfg.device
    base = T5ForConditionalGeneration.from_pretrained(cfg.model_name).to(device)
    base.eval()
    for p in base.parameters():
        p.requires_grad = False

    model = T5ContinuousSoftPrompt(base, prompt_length=cfg.prompt_length).to(device)
    # Use lower learning rate for adversarial training to prevent explosion
    effective_lr = cfg.lr * 0.1 if adversarial else cfg.lr
    optimizer = torch.optim.AdamW(model.parameters(), lr=effective_lr, weight_decay=0.01)

    sign = -1.0 if adversarial else 1.0

    history = {
        "train_joint": [],
        "train_task": [],
        "val_loss": [],
        "val_acc": [],
        "val_acc_true": [],
        "val_acc_false": [],
        "prompt_norm": [],
    }

    for epoch in range(cfg.num_epochs):
        model.train()
        running_joint = 0.0
        running_task  = 0.0
        n_batches = 0

        for batch in train_dl:
            input_ids      = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels         = batch["labels"].to(device)

            optimizer.zero_grad()
            outputs   = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels,
            )
            task_loss = outputs.loss
            joint_loss = sign * task_loss

            joint_loss.backward()
            # More aggressive gradient clipping to prevent collapse and explosion
            # Use smaller max_norm for adversarial training
            max_norm = 0.5 if adversarial else 1.0
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_norm)
            optimizer.step()

            running_joint += joint_loss.item()
            running_task  += task_loss.item()
            n_batches += 1

        avg_train_joint = running_joint / max(1, n_batches)
        avg_train_task  = running_task  / max(1, n_batches)

        # Validation loss (task loss, no sign flip)
        model.eval()
        val_loss = 0.0
        val_batches = 0
        with torch.no_grad():
            for batch in val_dl:
                input_ids      = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels         = batch["labels"].to(device)

                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    labels=labels,
                )
                val_loss += outputs.loss.item()
                val_batches += 1

        avg_val_loss = val_loss / max(1, val_batches)
        val_acc_dict = evaluate_accuracy_t5(model, val_dl, tokenizer, device)
        val_acc = val_acc_dict["overall"]
        val_acc_true = val_acc_dict["true_acc"]
        val_acc_false = val_acc_dict["false_acc"]

        # soft prompt norm as a diagnostic
        prompt_norm = model.soft_prompt.norm().item()

        history["train_joint"].append(avg_train_joint)
        history["train_task"].append(avg_train_task)
        history["val_loss"].append(avg_val_loss)
        history["val_acc"].append(val_acc)
        history["val_acc_true"].append(val_acc_true)
        history["val_acc_false"].append(val_acc_false)
        history["prompt_norm"].append(prompt_norm)

        print(
            f"[Continuous {'ADV' if adversarial else 'NON-ADV'}] "
            f"Epoch {epoch+1}/{cfg.num_epochs} | "
            f"joint={avg_train_joint:.4f} task={avg_train_task:.4f} "
            f"val_loss={avg_val_loss:.4f} val_acc={val_acc:.4f} "
            f"(true={val_acc_true:.4f} false={val_acc_false:.4f}) "
            f"‖prompt‖={prompt_norm:.2f}"
        )

    return {"model": model, "history": history}

# %%
def train_pez(
    cfg,
    tokenizer: T5TokenizerFast,
    gpt2_model: GPT2LMHeadModel,
    gpt2_tokenizer: GPT2TokenizerFast,
    train_dl: DataLoader,
    val_dl: DataLoader,
    lambda_ppl: float,
    adversarial: bool,
    log_every: int = 50,
):
    device = cfg.device
    base = T5ForConditionalGeneration.from_pretrained(cfg.model_name).to(device)
    base.eval()
    for p in base.parameters():
        p.requires_grad = False

    model = T5PEZPrompt(base, prompt_length=cfg.prompt_length).to(device)
    sign = -1.0 if adversarial else 1.0

    history = {
        "lambda_ppl": lambda_ppl,
        "train_joint": [],
        "train_task": [],
        "train_ppl_loss": [],
        "train_ppl_ppx": [],
        "val_loss": [],
        "val_acc": [],
        "val_acc_true": [],
        "val_acc_false": [],
        "prompt_ppl_ppx": [],
    }

    for epoch in range(cfg.num_epochs):
        model.train()
        running_joint = 0.0
        running_task = 0.0
        running_ppl  = 0.0
        running_ppl_ppx = 0.0
        n_batches = 0

        empty_ppl_calls = 0
        nonempty_ppl_calls = 0

        for batch in train_dl:
            input_ids      = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels         = batch["labels"].to(device)

            model.prompt.grad = None

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels,
            )
            task_loss = outputs.loss

            # ---- perplexity term ----
            if lambda_ppl > 0.0:
                prompt_ids = model.get_prompt_token_ids()
                prompt_text = tokenizer.decode(
                    prompt_ids.tolist(),
                    skip_special_tokens=True,
                    clean_up_tokenization_spaces=True,
                ).strip()

                if not prompt_text:
                    ppl_loss = torch.tensor(0.0, device=device)
                    empty_ppl_calls += 1
                else:
                    nonempty_ppl_calls += 1
                    ppl_loss = compute_prompt_ppl_loss_from_text(
                        gpt2_model, gpt2_tokenizer, prompt_text, device=device
                    )
                    if torch.isnan(ppl_loss) or torch.isinf(ppl_loss):
                        # print(
                        #     "[DEBUG] ppl_loss NaN/Inf, setting to 0. "
                        #     "prompt_text[:80] =", repr(prompt_text[:80])
                        # )
                        ppl_loss = torch.tensor(0.0, device=device)
            else:
                ppl_loss = torch.tensor(0.0, device=device)

            joint_loss = sign * task_loss + lambda_ppl * ppl_loss
            joint_loss.backward()

            # ---- PEZ projection step (one-hot update) ----
            with torch.no_grad():
                grads = model.prompt.grad
                indices = grads.argmin(dim=-1)
                new_prompt = torch.nn.functional.one_hot(
                    indices, num_classes=model.vocab_size
                ).float()
                model.prompt.copy_(new_prompt)
                model.prompt.grad.zero_()
            # ---------------------------------------------

            running_joint += joint_loss.item()
            running_task  += task_loss.item()
            running_ppl   += ppl_loss.item()
            if lambda_ppl > 0.0:
                running_ppl_ppx += math.exp(ppl_loss.item())
            n_batches += 1

            if (n_batches % log_every) == 0:
                avg_joint_so_far = running_joint / n_batches
                avg_task_so_far  = running_task  / n_batches
                avg_ppl_so_far   = running_ppl   / n_batches
                avg_ppl_ppx_so_far = (
                    running_ppl_ppx / n_batches if lambda_ppl > 0.0 else 0.0
                )
                print(
                    f"[PEZ λ={lambda_ppl} {'ADV' if adversarial else 'NON-ADV'}] "
                    f"Epoch {epoch+1}/{cfg.num_epochs}, "
                    f"batch {n_batches} | "
                    f"joint={avg_joint_so_far:.4f} "
                    f"task={avg_task_so_far:.4f} "
                    f"ppl_loss={avg_ppl_so_far:.4f} "
                    f"ppl={avg_ppl_ppx_so_far:.2f}"
                )

        # ---- end of epoch: aggregate metrics ----
        avg_joint = running_joint / max(1, n_batches)
        avg_task  = running_task  / max(1, n_batches)
        avg_ppl   = running_ppl   / max(1, n_batches)
        avg_ppl_ppx = running_ppl_ppx / max(1, n_batches) if lambda_ppl > 0.0 else 0.0

        history["train_joint"].append(avg_joint)
        history["train_task"].append(avg_task)
        history["train_ppl_loss"].append(avg_ppl)
        history["train_ppl_ppx"].append(avg_ppl_ppx)

        # ---- validation ----
        model.eval()
        val_loss = 0.0
        val_batches = 0
        with torch.no_grad():
            for batch in val_dl:
                input_ids      = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels         = batch["labels"].to(device)

                outputs = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask,
                    labels=labels,
                )
                val_loss += outputs.loss.item()
                val_batches += 1
        avg_val_loss = val_loss / max(1, val_batches)
        val_acc_dict = evaluate_accuracy_t5(model, val_dl, tokenizer, device)
        val_acc = val_acc_dict["overall"]
        val_acc_true = val_acc_dict["true_acc"]
        val_acc_false = val_acc_dict["false_acc"]

        history["val_loss"].append(avg_val_loss)
        history["val_acc"].append(val_acc)
        history["val_acc_true"].append(val_acc_true)
        history["val_acc_false"].append(val_acc_false)

        # ---- prompt perplexity once per epoch ----
        if lambda_ppl > 0.0:
            prompt_text_epoch = model.decode_prompt(tokenizer).strip()
            if prompt_text_epoch:
                ppl_loss_epoch = compute_prompt_ppl_loss_from_text(
                    gpt2_model, gpt2_tokenizer, prompt_text_epoch, device=device
                )
                prompt_ppx = math.exp(ppl_loss_epoch.item())
            else:
                prompt_ppx = float("nan")
        else:
            prompt_ppx = 0.0
        history["prompt_ppl_ppx"].append(prompt_ppx)

        decoded_prompt = model.decode_prompt(tokenizer)
        print(
            f"[PEZ λ={lambda_ppl} {'ADV' if adversarial else 'NON-ADV'}] "
            f"Epoch {epoch+1}/{cfg.num_epochs} | "
            f"joint={avg_joint:.4f} task={avg_task:.4f} "
            f"ppl_loss={avg_ppl:.4f} ppl={avg_ppl_ppx:.2f} "
            f"val_loss={avg_val_loss:.4f} val_acc={val_acc:.4f} "
            f"(true={val_acc_true:.4f} false={val_acc_false:.4f}) "
            f"prompt_ppl={prompt_ppx:.2f}\n"
            f"Prompt: {decoded_prompt}"
        )
        # print(
        #     f"[DEBUG λ={lambda_ppl}] epoch {epoch+1}: "
        #     f"ppl_calls={empty_ppl_calls+nonempty_ppl_calls}, "
        #     f"empty={empty_ppl_calls}, nonempty={nonempty_ppl_calls}"
        # )

    return {"model": model, "history": history}

# %% [markdown]
# # running stuff

# %%
cfg = ExperimentConfig()

device = cfg.device
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Tokenizers and data
tokenizer = T5TokenizerFast.from_pretrained(cfg.model_name)
train_dl, val_dl = load_boolq(tokenizer, cfg)
# Out:
# Map:   0%|          | 0/9427 [00:00<?, ? examples/s]
# /mnt/polished-lake/home/annabelma/other/.venv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:4169: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/3270 [00:00<?, ? examples/s]

# %%
batch = next(iter(val_dl))
print(batch["labels"][0][:5])  # first 5 label tokens
print("yes_id", tokenizer("yes", add_special_tokens=False).input_ids[0])
print("no_id",  tokenizer("no",  add_special_tokens=False).input_ids[0])
print("decoded label:", tokenizer.decode(batch["labels"][0]))
# Out:
# tensor([150,   1,   0,   0])
# yes_id 4273
# no_id 150
# decoded label: no</s><pad><pad>

# %% [markdown]
# ## baseline accuracy of t5 large

# %%
# put baseline here
# Baseline accuracy of T5 Large on validation set (no soft prompt tuning)
print("\n" + "=" * 80)
print("BASELINE: T5 Large (No Soft Prompt)")
print("=" * 80)

# Load T5 Large model (baseline without any prompt tuning)
baseline_model_name = "t5-large"  # Use t5-large for baseline
print(f"\nLoading {baseline_model_name} for baseline evaluation...")
baseline_model = T5ForConditionalGeneration.from_pretrained(baseline_model_name).to(device)
baseline_model.eval()
for p in baseline_model.parameters():
    p.requires_grad = False

# Evaluate on validation set
print("Evaluating baseline model on validation set...")
baseline_acc_dict = evaluate_accuracy_t5(baseline_model, val_dl, tokenizer, device)

baseline_overall = baseline_acc_dict["overall"]
baseline_true = baseline_acc_dict["true_acc"]
baseline_false = baseline_acc_dict["false_acc"]

print("\n" + "=" * 80)
print("Baseline Results:")
print("=" * 80)
print(f"Overall Accuracy: {baseline_overall:.4f}")
print(f"True (yes) Accuracy:  {baseline_true:.4f}")
print(f"False (no) Accuracy:  {baseline_false:.4f}")
print("=" * 80)

# Store baseline for comparison
baseline_results = {
    "model_name": baseline_model_name,
    "overall_acc": baseline_overall,
    "true_acc": baseline_true,
    "false_acc": baseline_false
}
# Out:
# ================================================================================
# BASELINE: T5 Large (No Soft Prompt)
# ================================================================================
#
# Loading t5-large for baseline evaluation...
# Evaluating baseline model on validation set...
#
# ================================================================================
# Baseline Results:
# ================================================================================
# Overall Accuracy: 0.6838
# True (yes) Accuracy:  0.5706
# False (no) Accuracy:  0.8698
# ================================================================================

# %% [markdown]
# ## baselines (no interpretability) with 10 length prompt

# %%
# Continuous soft prompt baselines
print("\n=== Continuous Soft Prompt: Non-Adversarial ===")
cont_non_adv = train_continuous_soft_prompt(
    cfg, tokenizer, train_dl, val_dl, adversarial=False
)

print("\n=== Continuous Soft Prompt: Adversarial ===")
cont_adv = train_continuous_soft_prompt(
    cfg, tokenizer, train_dl, val_dl, adversarial=True
)
# Out:
# === Continuous Soft Prompt: Non-Adversarial ===
# [Continuous NON-ADV] Epoch 1/5 | joint=9.6488 task=9.6488 val_loss=2.8798 val_acc=0.7128 (true=0.7860 false=0.5926) ‖prompt‖=3.02
# [Continuous NON-ADV] Epoch 2/5 | joint=4.6155 task=4.6155 val_loss=0.2644 val_acc=0.6566 (true=0.7664 false=0.4762) ‖prompt‖=3.66
# [Continuous NON-ADV] Epoch 3/5 | joint=2.7659 task=2.7659 val_loss=0.2258 val_acc=0.6682 (true=0.9311 false=0.2361) ‖prompt‖=4.17
# [Continuous NON-ADV] Epoch 4/5 | joint=1.9620 task=1.9620 val_loss=0.2252 val_acc=0.6615 (true=0.9828 false=0.1334) ‖prompt‖=4.64
# [Continuous NON-ADV] Epoch 5/5 | joint=1.5919 task=1.5919 val_loss=0.1782 val_acc=0.6535 (true=0.9769 false=0.1221) ‖prompt‖=5.07
#
# === Continuous Soft Prompt: Adversarial ===
# [Continuous ADV] Epoch 1/5 | joint=-18.1294 task=18.1294 val_loss=21.8227 val_acc=0.7612 (true=0.7019 false=0.8585) ‖prompt‖=2.06
# [Continuous ADV] Epoch 2/5 | joint=-19.0742 task=19.0742 val_loss=22.0799 val_acc=0.7661 (true=0.7108 false=0.8569) ‖prompt‖=2.07
# [Continuous ADV] Epoch 3/5 | joint=-19.6264 task=19.6264 val_loss=22.6076 val_acc=0.7713 (true=0.7216 false=0.8529) ‖prompt‖=2.08
# [Continuous ADV] Epoch 4/5 | joint=-20.3299 task=20.3299 val_loss=23.1708 val_acc=0.7737 (true=0.7191 false=0.8634) ‖prompt‖=2.09
# [Continuous ADV] Epoch 5/5 | joint=-21.1133 task=21.1133 val_loss=24.6624 val_acc=0.7541 (true=0.6911 false=0.8577) ‖prompt‖=2.10

# %% [markdown]
# ### gridsearch

# %%
# Grid search over learning rates for continuous soft prompt (non-adversarial)
# Using lower learning rates and gradient clipping to prevent collapse
# Smaller LRs need more epochs to converge
print("\n" + "=" * 80)
print("GRID SEARCH: Learning Rates for Continuous Soft Prompt (Non-Adversarial)")
print("=" * 80)

lr_grid = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3]  # Lower range to prevent collapse
continuous_lr_results = []

for lr in lr_grid:
    print(f"\n--- Testing LR = {lr} ---")
    # Create a temporary config with this learning rate
    temp_cfg = ExperimentConfig()
    temp_cfg.lr = lr
    # Use more epochs for smaller learning rates
    if lr <= 1e-4:
        temp_cfg.num_epochs = 10  # More epochs for very small LRs
    elif lr <= 5e-4:
        temp_cfg.num_epochs = 8   # Moderate epochs for small LRs
    else:
        temp_cfg.num_epochs = 5   # Default for larger LRs
    
    result = train_continuous_soft_prompt(
        temp_cfg, tokenizer, train_dl, val_dl, adversarial=False
    )
    
    best_val_acc = max(result["history"]["val_acc"])
    final_val_acc = result["history"]["val_acc"][-1]
    continuous_lr_results.append({
        "lr": lr,
        "num_epochs": temp_cfg.num_epochs,
        "best_val_acc": best_val_acc,
        "final_val_acc": final_val_acc,
        "history": result["history"]
    })
    print(f"LR={lr} ({temp_cfg.num_epochs} epochs): best_val_acc={best_val_acc:.4f}, final_val_acc={final_val_acc:.4f}")

print("\n" + "=" * 80)
print("Learning Rate Grid Search Results:")
print("=" * 80)
for r in continuous_lr_results:
    print(f"LR={r['lr']:.0e} ({r['num_epochs']} epochs): best_val_acc={r['best_val_acc']:.4f}, final_val_acc={r['final_val_acc']:.4f}")

best_lr_result = max(continuous_lr_results, key=lambda x: x["best_val_acc"])
print(f"\nBest LR: {best_lr_result['lr']:.0e} ({best_lr_result['num_epochs']} epochs) with best_val_acc={best_lr_result['best_val_acc']:.4f}")
# Out:
# ================================================================================
# GRID SEARCH: Learning Rates for Continuous Soft Prompt (Non-Adversarial)
# ================================================================================
#
# --- Testing LR = 1e-05 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=16.8341 task=16.8341 val_loss=20.1736 val_acc=0.7670 (true=0.7118 false=0.8577) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 2/10 | joint=16.5245 task=16.5245 val_loss=19.6023 val_acc=0.7587 (true=0.6936 false=0.8658) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 3/10 | joint=16.2218 task=16.2218 val_loss=19.1111 val_acc=0.7544 (true=0.6857 false=0.8674) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 4/10 | joint=15.8928 task=15.8928 val_loss=18.6931 val_acc=0.7465 (true=0.6773 false=0.8601) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 5/10 | joint=15.4876 task=15.4876 val_loss=18.2031 val_acc=0.7453 (true=0.6754 false=0.8601) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 6/10 | joint=15.1413 task=15.1413 val_loss=17.5713 val_acc=0.7419 (true=0.6699 false=0.8601) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 7/10 | joint=14.6371 task=14.6371 val_loss=16.7586 val_acc=0.7266 (true=0.6493 false=0.8537) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 8/10 | joint=14.1970 task=14.1970 val_loss=16.0898 val_acc=0.7153 (true=0.6281 false=0.8585) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 9/10 | joint=13.8440 task=13.8440 val_loss=15.3050 val_acc=0.6979 (true=0.5937 false=0.8690) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 10/10 | joint=13.4646 task=13.4646 val_loss=14.4473 val_acc=0.6615 (true=0.5278 false=0.8812) ‖prompt‖=2.04
# LR=1e-05 (10 epochs): best_val_acc=0.7670, final_val_acc=0.6615
#
# --- Testing LR = 5e-05 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=16.4354 task=16.4354 val_loss=18.4715 val_acc=0.7584 (true=0.6940 false=0.8642) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 2/10 | joint=14.6697 task=14.6697 val_loss=16.0325 val_acc=0.6642 (true=0.5229 false=0.8965) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 3/10 | joint=13.3744 task=13.3744 val_loss=14.4659 val_acc=0.5893 (true=0.3842 false=0.9264) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 4/10 | joint=12.5632 task=12.5632 val_loss=12.8420 val_acc=0.5018 (true=0.2194 false=0.9660) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 5/10 | joint=11.9307 task=11.9307 val_loss=11.2804 val_acc=0.4110 (true=0.0580 false=0.9911) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 6/10 | joint=11.3269 task=11.3269 val_loss=10.1776 val_acc=0.4168 (true=0.0669 false=0.9919) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 7/10 | joint=10.7034 task=10.7034 val_loss=9.4367 val_acc=0.3917 (true=0.0241 false=0.9960) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 8/10 | joint=10.0718 task=10.0718 val_loss=8.7204 val_acc=0.3957 (true=0.0300 false=0.9968) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 9/10 | joint=9.5189 task=9.5189 val_loss=8.1704 val_acc=0.4043 (true=0.0472 false=0.9911) ‖prompt‖=2.04
# [Continuous NON-ADV] Epoch 10/10 | joint=8.9412 task=8.9412 val_loss=6.8519 val_acc=0.3948 (true=0.0305 false=0.9935) ‖prompt‖=2.04
# LR=5e-05 (10 epochs): best_val_acc=0.7584, final_val_acc=0.3948
#
# --- Testing LR = 0.0001 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=15.7549 task=15.7549 val_loss=14.1941 val_acc=0.6636 (true=0.5111 false=0.9143) ‖prompt‖=2.05
# [Continuous NON-ADV] Epoch 2/10 | joint=12.2427 task=12.2427 val_loss=9.8433 val_acc=0.4321 (true=0.0944 false=0.9871) ‖prompt‖=2.05
# [Continuous NON-ADV] Epoch 3/10 | joint=10.0146 task=10.0146 val_loss=8.2325 val_acc=0.4823 (true=0.1854 false=0.9701) ‖prompt‖=2.06
# [Continuous NON-ADV] Epoch 4/10 | joint=8.6163 task=8.6163 val_loss=6.3280 val_acc=0.5813 (true=0.3881 false=0.8989) ‖prompt‖=2.07
# [Continuous NON-ADV] Epoch 5/10 | joint=7.5319 task=7.5319 val_loss=4.5661 val_acc=0.6746 (true=0.6188 false=0.7664) ‖prompt‖=2.08
# [Continuous NON-ADV] Epoch 6/10 | joint=6.5814 task=6.5814 val_loss=2.9406 val_acc=0.6966 (true=0.7334 false=0.6362) ‖prompt‖=2.09
# [Continuous NON-ADV] Epoch 7/10 | joint=5.6311 task=5.6311 val_loss=1.6684 val_acc=0.7174 (true=0.7585 false=0.6500) ‖prompt‖=2.09
# [Continuous NON-ADV] Epoch 8/10 | joint=4.8981 task=4.8981 val_loss=1.3655 val_acc=0.6743 (true=0.5991 false=0.7979) ‖prompt‖=2.10
# [Continuous NON-ADV] Epoch 9/10 | joint=4.3710 task=4.3710 val_loss=0.8648 val_acc=0.7358 (true=0.8062 false=0.6200) ‖prompt‖=2.11
# [Continuous NON-ADV] Epoch 10/10 | joint=3.9253 task=3.9253 val_loss=0.7104 val_acc=0.7294 (true=0.8101 false=0.5966) ‖prompt‖=2.12
# LR=0.0001 (10 epochs): best_val_acc=0.7358, final_val_acc=0.7294
#
# --- Testing LR = 0.0005 ---
# [Continuous NON-ADV] Epoch 1/8 | joint=11.2329 task=11.2329 val_loss=7.1836 val_acc=0.4807 (true=0.1894 false=0.9596) ‖prompt‖=2.32
# [Continuous NON-ADV] Epoch 2/8 | joint=6.7614 task=6.7614 val_loss=0.9286 val_acc=0.7180 (true=0.9429 false=0.3484) ‖prompt‖=2.55
# [Continuous NON-ADV] Epoch 3/8 | joint=4.9517 task=4.9517 val_loss=0.4349 val_acc=0.6887 (true=0.9725 false=0.2223) ‖prompt‖=2.76
# [Continuous NON-ADV] Epoch 4/8 | joint=3.7873 task=3.7873 val_loss=0.3227 val_acc=0.7113 (true=0.9351 false=0.3436) ‖prompt‖=2.95
# [Continuous NON-ADV] Epoch 5/8 | joint=3.1497 task=3.1497 val_loss=0.2663 val_acc=0.6661 (true=0.9031 false=0.2765) ‖prompt‖=3.12
# [Continuous NON-ADV] Epoch 6/8 | joint=2.8182 task=2.8182 val_loss=0.3072 val_acc=0.6560 (true=0.9867 false=0.1124) ‖prompt‖=3.29
# [Continuous NON-ADV] Epoch 7/8 | joint=2.6082 task=2.6082 val_loss=0.2480 val_acc=0.6670 (true=0.9631 false=0.1803) ‖prompt‖=3.44
# [Continuous NON-ADV] Epoch 8/8 | joint=2.4821 task=2.4821 val_loss=0.2638 val_acc=0.6590 (true=0.9739 false=0.1415) ‖prompt‖=3.59
# LR=0.0005 (8 epochs): best_val_acc=0.7180, final_val_acc=0.6590
#
# --- Testing LR = 0.001 ---
# [Continuous NON-ADV] Epoch 1/5 | joint=7.6245 task=7.6245 val_loss=0.6404 val_acc=0.7101 (true=0.9444 false=0.3250) ‖prompt‖=3.11
# [Continuous NON-ADV] Epoch 2/5 | joint=2.9328 task=2.9328 val_loss=0.2714 val_acc=0.6630 (true=0.8264 false=0.3945) ‖prompt‖=3.73
# [Continuous NON-ADV] Epoch 3/5 | joint=2.2780 task=2.2780 val_loss=0.1922 val_acc=0.6621 (true=0.8549 false=0.3452) ‖prompt‖=4.27
# [Continuous NON-ADV] Epoch 4/5 | joint=1.9653 task=1.9653 val_loss=0.1907 val_acc=0.5691 (true=0.4673 false=0.7365) ‖prompt‖=4.72
# [Continuous NON-ADV] Epoch 5/5 | joint=1.7777 task=1.7777 val_loss=0.1660 val_acc=0.6752 (true=0.8264 false=0.4268) ‖prompt‖=5.13
# LR=0.001 (5 epochs): best_val_acc=0.7101, final_val_acc=0.6752
#
# ================================================================================
# Learning Rate Grid Search Results:
# ================================================================================
# LR=1e-05 (10 epochs): best_val_acc=0.7670, final_val_acc=0.6615
# LR=5e-05 (10 epochs): best_val_acc=0.7584, final_val_acc=0.3948
# LR=1e-04 (10 epochs): best_val_acc=0.7358, final_val_acc=0.7294
# LR=5e-04 (8 epochs): best_val_acc=0.7180, final_val_acc=0.6590
# LR=1e-03 (5 epochs): best_val_acc=0.7101, final_val_acc=0.6752
#
# Best LR: 1e-05 (10 epochs) with best_val_acc=0.7670

# %% [markdown]
# ## lr gridsearch for adversarial prompt

# %%
# Grid search over learning rates for continuous soft prompt (adversarial)
# Using lower learning rates and gradient clipping to prevent collapse
# Smaller LRs need more epochs to converge
print("\n" + "=" * 80)
print("GRID SEARCH: Learning Rates for Continuous Soft Prompt (Adversarial)")
print("=" * 80)

lr_grid = [1e-5, 5e-5, 1e-4, 5e-4, 1e-3]  # Lower range to prevent collapse
continuous_lr_results_adv = []

for lr in lr_grid:
    print(f"\n--- Testing LR = {lr} ---")
    # Create a temporary config with this learning rate
    temp_cfg = ExperimentConfig()
    temp_cfg.lr = lr
    # Use more epochs for smaller learning rates
    if lr <= 1e-4:
        temp_cfg.num_epochs = 10  # More epochs for very small LRs
    elif lr <= 5e-4:
        temp_cfg.num_epochs = 8   # Moderate epochs for small LRs
    else:
        temp_cfg.num_epochs = 5   # Default for larger LRs
    
    result = train_continuous_soft_prompt(
        temp_cfg, tokenizer, train_dl, val_dl, adversarial=True
    )
    
    best_val_acc = max(result["history"]["val_acc"])
    final_val_acc = result["history"]["val_acc"][-1]
    best_val_acc_true = max(result["history"]["val_acc_true"])
    best_val_acc_false = max(result["history"]["val_acc_false"])
    continuous_lr_results_adv.append({
        "lr": lr,
        "num_epochs": temp_cfg.num_epochs,
        "best_val_acc": best_val_acc,
        "final_val_acc": final_val_acc,
        "best_val_acc_true": best_val_acc_true,
        "best_val_acc_false": best_val_acc_false,
        "history": result["history"]
    })
    print(
        f"LR={lr} ({temp_cfg.num_epochs} epochs): "
        f"best_val_acc={best_val_acc:.4f}, final_val_acc={final_val_acc:.4f} "
        f"(true={best_val_acc_true:.4f}, false={best_val_acc_false:.4f})"
    )

print("\n" + "=" * 80)
print("Learning Rate Grid Search Results (Adversarial):")
print("=" * 80)
for r in continuous_lr_results_adv:
    print(
        f"LR={r['lr']:.0e} ({r['num_epochs']} epochs): "
        f"best_val_acc={r['best_val_acc']:.4f}, final_val_acc={r['final_val_acc']:.4f} "
        f"(true={r['best_val_acc_true']:.4f}, false={r['best_val_acc_false']:.4f})"
    )

best_lr_result_adv = max(continuous_lr_results_adv, key=lambda x: x["best_val_acc"])
print(f"\nBest LR (Adversarial): {best_lr_result_adv['lr']:.0e} ({best_lr_result_adv['num_epochs']} epochs)")
print(f"  best_val_acc={best_lr_result_adv['best_val_acc']:.4f}, final_val_acc={best_lr_result_adv['final_val_acc']:.4f}")
print(f"  true_acc={best_lr_result_adv['best_val_acc_true']:.4f}, false_acc={best_lr_result_adv['best_val_acc_false']:.4f}")
# Out:
# ================================================================================
# GRID SEARCH: Learning Rates for Continuous Soft Prompt (Non-Adversarial)
# ================================================================================
#
# --- Testing LR = 1e-05 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=9.4593 task=9.4593 val_loss=4.4545 val_acc=0.3783 ‖prompt‖=4.53
# [Continuous NON-ADV] Epoch 2/10 | joint=5.2384 task=5.2384 val_loss=1.7574 val_acc=0.3783 ‖prompt‖=4.53
# [Continuous NON-ADV] Epoch 3/10 | joint=3.7788 task=3.7788 val_loss=0.7803 val_acc=0.3783 ‖prompt‖=4.53
# [Continuous NON-ADV] Epoch 4/10 | joint=2.8895 task=2.8895 val_loss=0.3976 val_acc=0.4581 ‖prompt‖=4.53
# [Continuous NON-ADV] Epoch 5/10 | joint=2.2292 task=2.2292 val_loss=0.2583 val_acc=0.4615 ‖prompt‖=4.53
# [Continuous NON-ADV] Epoch 6/10 | joint=1.7813 task=1.7813 val_loss=0.1996 val_acc=0.5758 ‖prompt‖=4.54
# [Continuous NON-ADV] Epoch 7/10 | joint=1.4965 task=1.4965 val_loss=0.1804 val_acc=0.6131 ‖prompt‖=4.54
# [Continuous NON-ADV] Epoch 8/10 | joint=1.2571 task=1.2571 val_loss=0.1774 val_acc=0.6162 ‖prompt‖=4.54
# [Continuous NON-ADV] Epoch 9/10 | joint=1.0867 task=1.0867 val_loss=0.1767 val_acc=0.6174 ‖prompt‖=4.54
# [Continuous NON-ADV] Epoch 10/10 | joint=0.9476 task=0.9476 val_loss=0.1860 val_acc=0.6199 ‖prompt‖=4.54
# LR=1e-05 (10 epochs): best_val_acc=0.6199, final_val_acc=0.6199
#
# --- Testing LR = 5e-05 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=4.8577 task=4.8577 val_loss=0.3725 val_acc=0.3917 ‖prompt‖=4.55
# [Continuous NON-ADV] Epoch 2/10 | joint=1.5527 task=1.5527 val_loss=0.2542 val_acc=0.3783 ‖prompt‖=4.57
# [Continuous NON-ADV] Epoch 3/10 | joint=0.9073 task=0.9073 val_loss=0.2014 val_acc=0.3810 ‖prompt‖=4.58
# [Continuous NON-ADV] Epoch 4/10 | joint=0.5864 task=0.5864 val_loss=0.1723 val_acc=0.5593 ‖prompt‖=4.59
# [Continuous NON-ADV] Epoch 5/10 | joint=0.4353 task=0.4353 val_loss=0.1701 val_acc=0.5878 ‖prompt‖=4.60
# [Continuous NON-ADV] Epoch 6/10 | joint=0.3739 task=0.3739 val_loss=0.1684 val_acc=0.6180 ‖prompt‖=4.60
# [Continuous NON-ADV] Epoch 7/10 | joint=0.3400 task=0.3400 val_loss=0.1841 val_acc=0.4028 ‖prompt‖=4.61
# [Continuous NON-ADV] Epoch 8/10 | joint=0.3115 task=0.3115 val_loss=0.1683 val_acc=0.6223 ‖prompt‖=4.62
# [Continuous NON-ADV] Epoch 9/10 | joint=0.2987 task=0.2987 val_loss=0.1691 val_acc=0.5939 ‖prompt‖=4.63
# [Continuous NON-ADV] Epoch 10/10 | joint=0.2853 task=0.2853 val_loss=0.1720 val_acc=0.5557 ‖prompt‖=4.63
# LR=5e-05 (10 epochs): best_val_acc=0.6223, final_val_acc=0.5557
#
# --- Testing LR = 0.0001 ---
# [Continuous NON-ADV] Epoch 1/10 | joint=3.3394 task=3.3394 val_loss=0.1917 val_acc=0.4269 ‖prompt‖=4.61
# [Continuous NON-ADV] Epoch 2/10 | joint=0.7282 task=0.7282 val_loss=0.1799 val_acc=0.4456 ‖prompt‖=4.64
# [Continuous NON-ADV] Epoch 3/10 | joint=0.4045 task=0.4045 val_loss=0.1781 val_acc=0.6217 ‖prompt‖=4.66
# [Continuous NON-ADV] Epoch 4/10 | joint=0.3085 task=0.3085 val_loss=0.1683 val_acc=0.6220 ‖prompt‖=4.69
# [Continuous NON-ADV] Epoch 5/10 | joint=0.2729 task=0.2729 val_loss=0.1669 val_acc=0.6211 ‖prompt‖=4.71
# [Continuous NON-ADV] Epoch 6/10 | joint=0.2593 task=0.2593 val_loss=0.1754 val_acc=0.6217 ‖prompt‖=4.74
# [Continuous NON-ADV] Epoch 7/10 | joint=0.2456 task=0.2456 val_loss=0.1734 val_acc=0.6217 ‖prompt‖=4.76
# [Continuous NON-ADV] Epoch 8/10 | joint=0.2375 task=0.2375 val_loss=0.1663 val_acc=0.6214 ‖prompt‖=4.79
# [Continuous NON-ADV] Epoch 9/10 | joint=0.2339 task=0.2339 val_loss=0.1667 val_acc=0.6217 ‖prompt‖=4.81
# [Continuous NON-ADV] Epoch 10/10 | joint=0.2274 task=0.2274 val_loss=0.1680 val_acc=0.6202 ‖prompt‖=4.83
# LR=0.0001 (10 epochs): best_val_acc=0.6220, final_val_acc=0.6202
#
# --- Testing LR = 0.0005 ---
# [Continuous NON-ADV] Epoch 1/8 | joint=1.1672 task=1.1672 val_loss=0.1693 val_acc=0.6147 ‖prompt‖=5.31
# [Continuous NON-ADV] Epoch 2/8 | joint=0.2624 task=0.2624 val_loss=0.1679 val_acc=0.6217 ‖prompt‖=5.78
# [Continuous NON-ADV] Epoch 3/8 | joint=0.2317 task=0.2317 val_loss=0.1924 val_acc=0.3783 ‖prompt‖=6.21
# [Continuous NON-ADV] Epoch 4/8 | joint=0.2199 task=0.2199 val_loss=0.1674 val_acc=0.6217 ‖prompt‖=6.62
# [Continuous NON-ADV] Epoch 5/8 | joint=0.2146 task=0.2146 val_loss=0.1666 val_acc=0.6217 ‖prompt‖=6.97
# [Continuous NON-ADV] Epoch 6/8 | joint=0.2082 task=0.2082 val_loss=0.1821 val_acc=0.3789 ‖prompt‖=7.27
# [Continuous NON-ADV] Epoch 7/8 | joint=0.2066 task=0.2066 val_loss=0.1671 val_acc=0.6217 ‖prompt‖=7.57
# [Continuous NON-ADV] Epoch 8/8 | joint=0.2053 task=0.2053 val_loss=0.1683 val_acc=0.6217 ‖prompt‖=7.82
# LR=0.0005 (8 epochs): best_val_acc=0.6217, final_val_acc=0.6217
#
# --- Testing LR = 0.001 ---
# [Continuous NON-ADV] Epoch 1/5 | joint=0.9695 task=0.9695 val_loss=0.1677 val_acc=0.6217 ‖prompt‖=6.78
# [Continuous NON-ADV] Epoch 2/5 | joint=0.2501 task=0.2501 val_loss=0.1691 val_acc=0.6217 ‖prompt‖=8.06
# [Continuous NON-ADV] Epoch 3/5 | joint=0.2265 task=0.2265 val_loss=0.1682 val_acc=0.6217 ‖prompt‖=9.00
# [Continuous NON-ADV] Epoch 4/5 | joint=0.2168 task=0.2168 val_loss=0.1673 val_acc=0.6217 ‖prompt‖=9.78
# [Continuous NON-ADV] Epoch 5/5 | joint=0.2109 task=0.2109 val_loss=0.1669 val_acc=0.6217 ‖prompt‖=10.50
# LR=0.001 (5 epochs): best_val_acc=0.6217, final_val_acc=0.6217
#
# ================================================================================
# Learning Rate Grid Search Results:
# ================================================================================
# LR=1e-05 (10 epochs): best_val_acc=0.6199, final_val_acc=0.6199
# LR=5e-05 (10 epochs): best_val_acc=0.6223, final_val_acc=0.5557
# LR=1e-04 (10 epochs): best_val_acc=0.6220, final_val_acc=0.6202
# LR=5e-04 (8 epochs): best_val_acc=0.6217, final_val_acc=0.6217
# LR=1e-03 (5 epochs): best_val_acc=0.6217, final_val_acc=0.6217
#
# Best LR: 5e-05 (10 epochs) with best_val_acc=0.6223

# %% [markdown]
# ## Grid search: Prompt Length for Continuous Soft Prompt

# %%
# Grid search over prompt lengths for continuous soft prompt (non-adversarial)
print("\n" + "=" * 80)
print("GRID SEARCH: Prompt Lengths for Continuous Soft Prompt (Non-Adversarial)")
print("=" * 80)

prompt_length_grid = [1, 5, 10, 20, 50, 100]
prompt_length_results = []

for prompt_len in prompt_length_grid:
    print(f"\n--- Testing Prompt Length = {prompt_len} ---")
    # Create a temporary config with this prompt length
    temp_cfg = ExperimentConfig()
    temp_cfg.prompt_length = prompt_len
    # Use a reasonable learning rate (from previous grid search, 5e-5 was good)
    temp_cfg.lr = 1e-4
    temp_cfg.num_epochs = 20  # Use enough epochs to see convergence
    
    result = train_continuous_soft_prompt(
        temp_cfg, tokenizer, train_dl, val_dl, adversarial=False
    )
    
    best_val_acc = max(result["history"]["val_acc"])
    final_val_acc = result["history"]["val_acc"][-1]
    best_val_acc_true = max(result["history"]["val_acc_true"])
    best_val_acc_false = max(result["history"]["val_acc_false"])
    final_prompt_norm = result["history"]["prompt_norm"][-1]
    
    prompt_length_results.append({
        "prompt_length": prompt_len,
        "best_val_acc": best_val_acc,
        "final_val_acc": final_val_acc,
        "best_val_acc_true": best_val_acc_true,
        "best_val_acc_false": best_val_acc_false,
        "final_prompt_norm": final_prompt_norm,
        "history": result["history"]
    })
    print(
        f"Prompt Length={prompt_len}: "
        f"best_val_acc={best_val_acc:.4f}, final_val_acc={final_val_acc:.4f} "
        f"(true={best_val_acc_true:.4f}, false={best_val_acc_false:.4f}) "
        f"‖prompt‖={final_prompt_norm:.2f}"
    )

print("\n" + "=" * 80)
print("Prompt Length Grid Search Results:")
print("=" * 80)
for r in prompt_length_results:
    print(
        f"Length={r['prompt_length']:3d}: "
        f"best_val_acc={r['best_val_acc']:.4f}, final_val_acc={r['final_val_acc']:.4f} "
        f"(true={r['best_val_acc_true']:.4f}, false={r['best_val_acc_false']:.4f}) "
        f"‖prompt‖={r['final_prompt_norm']:.2f}"
    )

best_prompt_length_result = max(prompt_length_results, key=lambda x: x["best_val_acc"])
print(f"\nBest Prompt Length: {best_prompt_length_result['prompt_length']}")
print(f"  best_val_acc={best_prompt_length_result['best_val_acc']:.4f}, final_val_acc={best_prompt_length_result['final_val_acc']:.4f}")
print(f"  true_acc={best_prompt_length_result['best_val_acc_true']:.4f}, false_acc={best_prompt_length_result['best_val_acc_false']:.4f}")
# Out:
# ================================================================================
# GRID SEARCH: Prompt Lengths for Continuous Soft Prompt (Non-Adversarial)
# ================================================================================
#
# --- Testing Prompt Length = 1 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=14.0087 task=14.0087 val_loss=13.0611 val_acc=0.5453 (true=0.2996 false=0.9491) ‖prompt‖=0.62
# [Continuous NON-ADV] Epoch 2/20 | joint=12.8482 task=12.8482 val_loss=12.6606 val_acc=0.4391 (true=0.1176 false=0.9677) ‖prompt‖=0.62
# [Continuous NON-ADV] Epoch 3/20 | joint=12.9251 task=12.9251 val_loss=11.8554 val_acc=0.4404 (true=0.1230 false=0.9620) ‖prompt‖=0.63
# [Continuous NON-ADV] Epoch 4/20 | joint=12.4211 task=12.4211 val_loss=11.7748 val_acc=0.4453 (true=0.1426 false=0.9426) ‖prompt‖=0.63
# [Continuous NON-ADV] Epoch 5/20 | joint=12.2375 task=12.2375 val_loss=11.7048 val_acc=0.4541 (true=0.1628 false=0.9329) ‖prompt‖=0.64
# [Continuous NON-ADV] Epoch 6/20 | joint=12.1681 task=12.1681 val_loss=11.6180 val_acc=0.4670 (true=0.1923 false=0.9184) ‖prompt‖=0.64
# [Continuous NON-ADV] Epoch 7/20 | joint=12.0431 task=12.0431 val_loss=11.5927 val_acc=0.4737 (true=0.2081 false=0.9103) ‖prompt‖=0.65
# [Continuous NON-ADV] Epoch 8/20 | joint=12.0388 task=12.0388 val_loss=11.5339 val_acc=0.4789 (true=0.2184 false=0.9070) ‖prompt‖=0.65
# [Continuous NON-ADV] Epoch 9/20 | joint=12.0646 task=12.0646 val_loss=11.4764 val_acc=0.4841 (true=0.2248 false=0.9103) ‖prompt‖=0.65
# [Continuous NON-ADV] Epoch 10/20 | joint=12.0165 task=12.0165 val_loss=11.4386 val_acc=0.4865 (true=0.2253 false=0.9159) ‖prompt‖=0.65
# [Continuous NON-ADV] Epoch 11/20 | joint=11.9692 task=11.9692 val_loss=11.4066 val_acc=0.4905 (true=0.2336 false=0.9127) ‖prompt‖=0.66
# [Continuous NON-ADV] Epoch 12/20 | joint=12.0101 task=12.0101 val_loss=11.3791 val_acc=0.4985 (true=0.2455 false=0.9143) ‖prompt‖=0.66
# [Continuous NON-ADV] Epoch 13/20 | joint=12.0400 task=12.0400 val_loss=11.3833 val_acc=0.5018 (true=0.2548 false=0.9078) ‖prompt‖=0.66
# [Continuous NON-ADV] Epoch 14/20 | joint=11.9511 task=11.9511 val_loss=11.3672 val_acc=0.5064 (true=0.2582 false=0.9143) ‖prompt‖=0.67
# [Continuous NON-ADV] Epoch 15/20 | joint=11.9230 task=11.9230 val_loss=11.3311 val_acc=0.5122 (true=0.2666 false=0.9159) ‖prompt‖=0.67
# [Continuous NON-ADV] Epoch 16/20 | joint=11.9579 task=11.9579 val_loss=11.3593 val_acc=0.5180 (true=0.2789 false=0.9111) ‖prompt‖=0.67
# [Continuous NON-ADV] Epoch 17/20 | joint=11.9649 task=11.9649 val_loss=11.3576 val_acc=0.5220 (true=0.2863 false=0.9095) ‖prompt‖=0.68
# [Continuous NON-ADV] Epoch 18/20 | joint=11.9194 task=11.9194 val_loss=11.3487 val_acc=0.5339 (true=0.3050 false=0.9103) ‖prompt‖=0.68
# [Continuous NON-ADV] Epoch 19/20 | joint=11.9231 task=11.9231 val_loss=11.2990 val_acc=0.5367 (true=0.3153 false=0.9006) ‖prompt‖=0.68
# [Continuous NON-ADV] Epoch 20/20 | joint=11.9674 task=11.9674 val_loss=11.3189 val_acc=0.5437 (true=0.3187 false=0.9135) ‖prompt‖=0.69
# Prompt Length=1: best_val_acc=0.5453, final_val_acc=0.5437 (true=0.3187, false=0.9677) ‖prompt‖=0.69
#
# --- Testing Prompt Length = 5 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=14.1782 task=14.1782 val_loss=12.8634 val_acc=0.4694 (true=0.1594 false=0.9790) ‖prompt‖=1.44
# [Continuous NON-ADV] Epoch 2/20 | joint=12.5851 task=12.5851 val_loss=11.9888 val_acc=0.4425 (true=0.1151 false=0.9806) ‖prompt‖=1.44
# [Continuous NON-ADV] Epoch 3/20 | joint=11.6519 task=11.6519 val_loss=9.4951 val_acc=0.4303 (true=0.0939 false=0.9830) ‖prompt‖=1.45
# [Continuous NON-ADV] Epoch 4/20 | joint=10.3629 task=10.3629 val_loss=8.2442 val_acc=0.5080 (true=0.2538 false=0.9256) ‖prompt‖=1.46
# [Continuous NON-ADV] Epoch 5/20 | joint=9.6565 task=9.6565 val_loss=7.1032 val_acc=0.7202 (true=0.8298 false=0.5400) ‖prompt‖=1.47
# [Continuous NON-ADV] Epoch 6/20 | joint=9.1754 task=9.1754 val_loss=6.6421 val_acc=0.7177 (true=0.8992 false=0.4196) ‖prompt‖=1.48
# [Continuous NON-ADV] Epoch 7/20 | joint=8.8315 task=8.8315 val_loss=6.2382 val_acc=0.6948 (true=0.9597 false=0.2595) ‖prompt‖=1.49
# [Continuous NON-ADV] Epoch 8/20 | joint=8.6392 task=8.6392 val_loss=6.1687 val_acc=0.6933 (true=0.9518 false=0.2684) ‖prompt‖=1.50
# [Continuous NON-ADV] Epoch 9/20 | joint=8.4022 task=8.4022 val_loss=5.4217 val_acc=0.7138 (true=0.9065 false=0.3969) ‖prompt‖=1.52
# [Continuous NON-ADV] Epoch 10/20 | joint=7.9435 task=7.9435 val_loss=4.6596 val_acc=0.7165 (true=0.8618 false=0.4778) ‖prompt‖=1.52
# [Continuous NON-ADV] Epoch 11/20 | joint=7.6612 task=7.6612 val_loss=4.2563 val_acc=0.7076 (true=0.8082 false=0.5424) ‖prompt‖=1.53
# [Continuous NON-ADV] Epoch 12/20 | joint=7.4478 task=7.4478 val_loss=4.0052 val_acc=0.7076 (true=0.7506 false=0.6370) ‖prompt‖=1.54
# [Continuous NON-ADV] Epoch 13/20 | joint=7.3279 task=7.3279 val_loss=3.7673 val_acc=0.6633 (true=0.6222 false=0.7308) ‖prompt‖=1.55
# [Continuous NON-ADV] Epoch 14/20 | joint=7.1538 task=7.1538 val_loss=3.4340 val_acc=0.7150 (true=0.7944 false=0.5845) ‖prompt‖=1.56
# [Continuous NON-ADV] Epoch 15/20 | joint=6.9939 task=6.9939 val_loss=3.1933 val_acc=0.7086 (true=0.8106 false=0.5408) ‖prompt‖=1.57
# [Continuous NON-ADV] Epoch 16/20 | joint=6.8725 task=6.8725 val_loss=2.9704 val_acc=0.7064 (true=0.8318 false=0.5004) ‖prompt‖=1.58
# [Continuous NON-ADV] Epoch 17/20 | joint=6.7346 task=6.7346 val_loss=2.8132 val_acc=0.7021 (true=0.8844 false=0.4026) ‖prompt‖=1.59
# [Continuous NON-ADV] Epoch 18/20 | joint=6.6184 task=6.6184 val_loss=2.5388 val_acc=0.6991 (true=0.9390 false=0.3048) ‖prompt‖=1.60
# [Continuous NON-ADV] Epoch 19/20 | joint=6.5275 task=6.5275 val_loss=2.2499 val_acc=0.6875 (true=0.9646 false=0.2320) ‖prompt‖=1.61
# [Continuous NON-ADV] Epoch 20/20 | joint=6.4435 task=6.4435 val_loss=2.1260 val_acc=0.6893 (true=0.9454 false=0.2684) ‖prompt‖=1.62
# Prompt Length=5: best_val_acc=0.7202, final_val_acc=0.6893 (true=0.9646, false=0.9830) ‖prompt‖=1.62
#
# --- Testing Prompt Length = 10 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=14.1930 task=14.1930 val_loss=12.7114 val_acc=0.6156 (true=0.4255 false=0.9281) ‖prompt‖=2.05
# [Continuous NON-ADV] Epoch 2/20 | joint=11.5690 task=11.5690 val_loss=8.8318 val_acc=0.4343 (true=0.0994 false=0.9846) ‖prompt‖=2.06
# [Continuous NON-ADV] Epoch 3/20 | joint=8.5767 task=8.5767 val_loss=4.5701 val_acc=0.6835 (true=0.8485 false=0.4123) ‖prompt‖=2.08
# [Continuous NON-ADV] Epoch 4/20 | joint=6.1209 task=6.1209 val_loss=1.0857 val_acc=0.6459 (true=0.9941 false=0.0736) ‖prompt‖=2.10
# [Continuous NON-ADV] Epoch 5/20 | joint=4.5457 task=4.5457 val_loss=0.7635 val_acc=0.6361 (true=0.9980 false=0.0412) ‖prompt‖=2.12
# [Continuous NON-ADV] Epoch 6/20 | joint=3.6730 task=3.6730 val_loss=0.7345 val_acc=0.6309 (true=0.9980 false=0.0275) ‖prompt‖=2.13
# [Continuous NON-ADV] Epoch 7/20 | joint=3.1858 task=3.1858 val_loss=0.6230 val_acc=0.6312 (true=0.9990 false=0.0267) ‖prompt‖=2.15
# [Continuous NON-ADV] Epoch 8/20 | joint=2.8136 task=2.8136 val_loss=0.5146 val_acc=0.6327 (true=0.9990 false=0.0307) ‖prompt‖=2.16
# [Continuous NON-ADV] Epoch 9/20 | joint=2.5440 task=2.5440 val_loss=0.6301 val_acc=0.6291 (true=0.9995 false=0.0202) ‖prompt‖=2.18
# [Continuous NON-ADV] Epoch 10/20 | joint=2.3338 task=2.3338 val_loss=0.4495 val_acc=0.6336 (true=0.9970 false=0.0364) ‖prompt‖=2.19
# [Continuous NON-ADV] Epoch 11/20 | joint=2.1589 task=2.1589 val_loss=0.5178 val_acc=0.6346 (true=0.9966 false=0.0396) ‖prompt‖=2.21
# [Continuous NON-ADV] Epoch 12/20 | joint=2.0287 task=2.0287 val_loss=0.3899 val_acc=0.6346 (true=0.9990 false=0.0356) ‖prompt‖=2.22
# [Continuous NON-ADV] Epoch 13/20 | joint=1.8831 task=1.8831 val_loss=0.4148 val_acc=0.6416 (true=0.9961 false=0.0590) ‖prompt‖=2.24
# [Continuous NON-ADV] Epoch 14/20 | joint=1.8079 task=1.8079 val_loss=0.3379 val_acc=0.6443 (true=0.9970 false=0.0647) ‖prompt‖=2.25
# [Continuous NON-ADV] Epoch 15/20 | joint=1.7020 task=1.7020 val_loss=0.3380 val_acc=0.6440 (true=0.9936 false=0.0695) ‖prompt‖=2.26
# [Continuous NON-ADV] Epoch 16/20 | joint=1.6618 task=1.6618 val_loss=0.4084 val_acc=0.6315 (true=0.9975 false=0.0299) ‖prompt‖=2.27
# [Continuous NON-ADV] Epoch 17/20 | joint=1.5501 task=1.5501 val_loss=0.2759 val_acc=0.6373 (true=0.9966 false=0.0469) ‖prompt‖=2.29
# [Continuous NON-ADV] Epoch 18/20 | joint=1.4507 task=1.4507 val_loss=0.2212 val_acc=0.6361 (true=0.9921 false=0.0509) ‖prompt‖=2.30
# [Continuous NON-ADV] Epoch 19/20 | joint=1.3905 task=1.3905 val_loss=0.2188 val_acc=0.6333 (true=0.9931 false=0.0420) ‖prompt‖=2.31
# [Continuous NON-ADV] Epoch 20/20 | joint=1.3137 task=1.3137 val_loss=0.2277 val_acc=0.6272 (true=0.9951 false=0.0226) ‖prompt‖=2.32
# Prompt Length=10: best_val_acc=0.6835, final_val_acc=0.6272 (true=0.9995, false=0.9846) ‖prompt‖=2.32
#
# --- Testing Prompt Length = 20 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=13.6464 task=13.6464 val_loss=11.0678 val_acc=0.4165 (true=0.0694 false=0.9871) ‖prompt‖=2.91
# [Continuous NON-ADV] Epoch 2/20 | joint=11.0209 task=11.0209 val_loss=9.3916 val_acc=0.4101 (true=0.0561 false=0.9919) ‖prompt‖=2.93
# [Continuous NON-ADV] Epoch 3/20 | joint=9.4700 task=9.4700 val_loss=6.1483 val_acc=0.4930 (true=0.2228 false=0.9369) ‖prompt‖=2.94
# [Continuous NON-ADV] Epoch 4/20 | joint=6.8606 task=6.8606 val_loss=2.0265 val_acc=0.7202 (true=0.8273 false=0.5441) ‖prompt‖=2.96
# [Continuous NON-ADV] Epoch 5/20 | joint=4.4058 task=4.4058 val_loss=0.3557 val_acc=0.7015 (true=0.9439 false=0.3032) ‖prompt‖=2.98
# [Continuous NON-ADV] Epoch 6/20 | joint=2.8578 task=2.8578 val_loss=0.2466 val_acc=0.6532 (true=0.9980 false=0.0865) ‖prompt‖=3.00
# [Continuous NON-ADV] Epoch 7/20 | joint=2.0049 task=2.0049 val_loss=0.2027 val_acc=0.6664 (true=0.9887 false=0.1366) ‖prompt‖=3.02
# [Continuous NON-ADV] Epoch 8/20 | joint=1.5037 task=1.5037 val_loss=0.2076 val_acc=0.6697 (true=0.9882 false=0.1463) ‖prompt‖=3.04
# [Continuous NON-ADV] Epoch 9/20 | joint=1.2061 task=1.2061 val_loss=0.2297 val_acc=0.6636 (true=0.9892 false=0.1285) ‖prompt‖=3.06
# [Continuous NON-ADV] Epoch 10/20 | joint=0.9901 task=0.9901 val_loss=0.2491 val_acc=0.6535 (true=0.9966 false=0.0897) ‖prompt‖=3.08
# [Continuous NON-ADV] Epoch 11/20 | joint=0.8167 task=0.8167 val_loss=0.2599 val_acc=0.6425 (true=0.9990 false=0.0566) ‖prompt‖=3.10
# [Continuous NON-ADV] Epoch 12/20 | joint=0.7021 task=0.7021 val_loss=0.2399 val_acc=0.6401 (true=0.9990 false=0.0501) ‖prompt‖=3.12
# [Continuous NON-ADV] Epoch 13/20 | joint=0.6191 task=0.6191 val_loss=0.2191 val_acc=0.6474 (true=0.9980 false=0.0711) ‖prompt‖=3.13
# [Continuous NON-ADV] Epoch 14/20 | joint=0.5533 task=0.5533 val_loss=0.2183 val_acc=0.6456 (true=0.9985 false=0.0655) ‖prompt‖=3.15
# [Continuous NON-ADV] Epoch 15/20 | joint=0.5172 task=0.5172 val_loss=0.2060 val_acc=0.6446 (true=0.9980 false=0.0639) ‖prompt‖=3.17
# [Continuous NON-ADV] Epoch 16/20 | joint=0.4852 task=0.4852 val_loss=0.2260 val_acc=0.6367 (true=0.9985 false=0.0420) ‖prompt‖=3.18
# [Continuous NON-ADV] Epoch 17/20 | joint=0.4538 task=0.4538 val_loss=0.1755 val_acc=0.6612 (true=0.9921 false=0.1172) ‖prompt‖=3.20
# [Continuous NON-ADV] Epoch 18/20 | joint=0.4352 task=0.4352 val_loss=0.2145 val_acc=0.6425 (true=0.9975 false=0.0590) ‖prompt‖=3.22
# [Continuous NON-ADV] Epoch 19/20 | joint=0.4126 task=0.4126 val_loss=0.2331 val_acc=0.6382 (true=0.9995 false=0.0445) ‖prompt‖=3.23
# [Continuous NON-ADV] Epoch 20/20 | joint=0.4000 task=0.4000 val_loss=0.1899 val_acc=0.6508 (true=0.9961 false=0.0833) ‖prompt‖=3.25
# Prompt Length=20: best_val_acc=0.7202, final_val_acc=0.6508 (true=0.9995, false=0.9919) ‖prompt‖=3.25
#
# --- Testing Prompt Length = 50 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=11.6119 task=11.6119 val_loss=8.9597 val_acc=0.4128 (true=0.0831 false=0.9547) ‖prompt‖=4.54
# [Continuous NON-ADV] Epoch 2/20 | joint=8.3156 task=8.3156 val_loss=3.2738 val_acc=0.4581 (true=0.1722 false=0.9281) ‖prompt‖=4.57
# [Continuous NON-ADV] Epoch 3/20 | joint=5.0795 task=5.0795 val_loss=1.1905 val_acc=0.6569 (true=0.6301 false=0.7009) ‖prompt‖=4.59
# [Continuous NON-ADV] Epoch 4/20 | joint=2.8675 task=2.8675 val_loss=0.2756 val_acc=0.6495 (true=0.6340 false=0.6750) ‖prompt‖=4.62
# [Continuous NON-ADV] Epoch 5/20 | joint=1.4297 task=1.4297 val_loss=0.1616 val_acc=0.6914 (true=0.9562 false=0.2563) ‖prompt‖=4.65
# [Continuous NON-ADV] Epoch 6/20 | joint=0.8649 task=0.8649 val_loss=0.1847 val_acc=0.6599 (true=0.9936 false=0.1116) ‖prompt‖=4.68
# [Continuous NON-ADV] Epoch 7/20 | joint=0.6355 task=0.6355 val_loss=0.1790 val_acc=0.6606 (true=0.9921 false=0.1156) ‖prompt‖=4.71
# [Continuous NON-ADV] Epoch 8/20 | joint=0.5170 task=0.5170 val_loss=0.1495 val_acc=0.6936 (true=0.9739 false=0.2328) ‖prompt‖=4.74
# [Continuous NON-ADV] Epoch 9/20 | joint=0.4442 task=0.4442 val_loss=0.1548 val_acc=0.6838 (true=0.9808 false=0.1956) ‖prompt‖=4.77
# [Continuous NON-ADV] Epoch 10/20 | joint=0.4052 task=0.4052 val_loss=0.1514 val_acc=0.6942 (true=0.9803 false=0.2239) ‖prompt‖=4.79
# [Continuous NON-ADV] Epoch 11/20 | joint=0.3779 task=0.3779 val_loss=0.1387 val_acc=0.7128 (true=0.9533 false=0.3177) ‖prompt‖=4.82
# [Continuous NON-ADV] Epoch 12/20 | joint=0.3575 task=0.3575 val_loss=0.1569 val_acc=0.6899 (true=0.9877 false=0.2005) ‖prompt‖=4.85
# [Continuous NON-ADV] Epoch 13/20 | joint=0.3358 task=0.3358 val_loss=0.1365 val_acc=0.7245 (true=0.9572 false=0.3420) ‖prompt‖=4.88
# [Continuous NON-ADV] Epoch 14/20 | joint=0.3167 task=0.3167 val_loss=0.1343 val_acc=0.7284 (true=0.9513 false=0.3622) ‖prompt‖=4.91
# [Continuous NON-ADV] Epoch 15/20 | joint=0.3033 task=0.3033 val_loss=0.1305 val_acc=0.7422 (true=0.9346 false=0.4260) ‖prompt‖=4.93
# [Continuous NON-ADV] Epoch 16/20 | joint=0.2835 task=0.2835 val_loss=0.1374 val_acc=0.7159 (true=0.9666 false=0.3040) ‖prompt‖=4.96
# [Continuous NON-ADV] Epoch 17/20 | joint=0.2846 task=0.2846 val_loss=0.1364 val_acc=0.7183 (true=0.9661 false=0.3112) ‖prompt‖=4.99
# [Continuous NON-ADV] Epoch 18/20 | joint=0.2726 task=0.2726 val_loss=0.1453 val_acc=0.7089 (true=0.9754 false=0.2708) ‖prompt‖=5.01
# [Continuous NON-ADV] Epoch 19/20 | joint=0.2607 task=0.2607 val_loss=0.1316 val_acc=0.7382 (true=0.9454 false=0.3977) ‖prompt‖=5.04
# [Continuous NON-ADV] Epoch 20/20 | joint=0.2597 task=0.2597 val_loss=0.1358 val_acc=0.7306 (true=0.9572 false=0.3581) ‖prompt‖=5.07
# Prompt Length=50: best_val_acc=0.7422, final_val_acc=0.7306 (true=0.9936, false=0.9547) ‖prompt‖=5.07
#
# --- Testing Prompt Length = 100 ---
# [Continuous NON-ADV] Epoch 1/20 | joint=10.6974 task=10.6974 val_loss=7.4069 val_acc=0.4477 (true=0.1751 false=0.8957) ‖prompt‖=6.47
# [Continuous NON-ADV] Epoch 2/20 | joint=6.5995 task=6.5995 val_loss=0.8945 val_acc=0.5095 (true=0.3733 false=0.7332) ‖prompt‖=6.51
# [Continuous NON-ADV] Epoch 3/20 | joint=2.2449 task=2.2449 val_loss=0.1888 val_acc=0.6248 (true=0.9970 false=0.0129) ‖prompt‖=6.55
# [Continuous NON-ADV] Epoch 4/20 | joint=0.9274 task=0.9274 val_loss=0.2373 val_acc=0.6220 (true=0.9990 false=0.0024) ‖prompt‖=6.59
# [Continuous NON-ADV] Epoch 5/20 | joint=0.4854 task=0.4854 val_loss=0.2043 val_acc=0.6266 (true=0.9990 false=0.0146) ‖prompt‖=6.63
# [Continuous NON-ADV] Epoch 6/20 | joint=0.3573 task=0.3573 val_loss=0.1828 val_acc=0.6242 (true=0.9975 false=0.0105) ‖prompt‖=6.67
# [Continuous NON-ADV] Epoch 7/20 | joint=0.2961 task=0.2961 val_loss=0.1688 val_acc=0.6373 (true=0.9926 false=0.0534) ‖prompt‖=6.71
# [Continuous NON-ADV] Epoch 8/20 | joint=0.2677 task=0.2677 val_loss=0.1605 val_acc=0.6450 (true=0.9818 false=0.0914) ‖prompt‖=6.74
# [Continuous NON-ADV] Epoch 9/20 | joint=0.2495 task=0.2495 val_loss=0.1614 val_acc=0.6437 (true=0.9970 false=0.0631) ‖prompt‖=6.79
# [Continuous NON-ADV] Epoch 10/20 | joint=0.2321 task=0.2321 val_loss=0.1606 val_acc=0.6413 (true=0.9985 false=0.0542) ‖prompt‖=6.83
# [Continuous NON-ADV] Epoch 11/20 | joint=0.2257 task=0.2257 val_loss=0.1601 val_acc=0.6404 (true=0.9975 false=0.0534) ‖prompt‖=6.86
# [Continuous NON-ADV] Epoch 12/20 | joint=0.2218 task=0.2218 val_loss=0.1526 val_acc=0.6920 (true=0.9661 false=0.2417) ‖prompt‖=6.90
# [Continuous NON-ADV] Epoch 13/20 | joint=0.2108 task=0.2108 val_loss=0.1494 val_acc=0.6997 (true=0.9675 false=0.2595) ‖prompt‖=6.94
# [Continuous NON-ADV] Epoch 14/20 | joint=0.2104 task=0.2104 val_loss=0.1417 val_acc=0.7339 (true=0.8962 false=0.4673) ‖prompt‖=6.98
# [Continuous NON-ADV] Epoch 15/20 | joint=0.2063 task=0.2063 val_loss=0.1469 val_acc=0.7385 (true=0.8308 false=0.5869) ‖prompt‖=7.02
# [Continuous NON-ADV] Epoch 16/20 | joint=0.2030 task=0.2030 val_loss=0.1366 val_acc=0.7358 (true=0.9262 false=0.4228) ‖prompt‖=7.06
# [Continuous NON-ADV] Epoch 17/20 | joint=0.1955 task=0.1955 val_loss=0.1377 val_acc=0.7602 (true=0.8269 false=0.6508) ‖prompt‖=7.09
# [Continuous NON-ADV] Epoch 18/20 | joint=0.1946 task=0.1946 val_loss=0.1302 val_acc=0.7425 (true=0.9602 false=0.3848) ‖prompt‖=7.13
# [Continuous NON-ADV] Epoch 19/20 | joint=0.1941 task=0.1941 val_loss=0.1272 val_acc=0.7719 (true=0.8815 false=0.5918) ‖prompt‖=7.17

# %% [markdown]
# ## gpt2 for prompt perplexity

# %%
# GPT-2 for prompt perplexity
print("\nLoading GPT-2 for prompt perplexity...")
gpt2_tokenizer = GPT2TokenizerFast.from_pretrained(cfg.gpt2_name)
gpt2_model = GPT2LMHeadModel.from_pretrained(cfg.gpt2_name).to(device)
gpt2_model.eval()
for p in gpt2_model.parameters():
    p.requires_grad = False
# Out:
# Loading GPT-2 for prompt perplexity...

# %% [markdown]
# ## pez non adversarial

# %%
# Grid search over lambda for PEZ (balanced loader, non-adversarial)
# Note: PEZ uses hard one-hot updates (argmin), so it doesn't use learning rate
print("\n" + "=" * 80)
print("GRID SEARCH: Lambda for PEZ (Non-Adversarial, Balanced Loader)")
print("=" * 80)

lambda_grid = [0.0, 0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1.0]
pez_grid_results = []

for lam in lambda_grid:
    print(f"\n--- Testing λ={lam} ---")
    
    result = train_pez(
        cfg,
        tokenizer,
        gpt2_model,
        gpt2_tokenizer,
        train_dl,
        val_dl,
        lambda_ppl=lam,
        adversarial=False,
    )
    
    best_val_acc = max(result["history"]["val_acc"])
    final_val_acc = result["history"]["val_acc"][-1]
    prompt_ppl = result["history"]["prompt_ppl_ppx"][-1] if result["history"]["prompt_ppl_ppx"] else 0.0
    
    pez_grid_results.append({
        "lambda": lam,
        "best_val_acc": best_val_acc,
        "final_val_acc": final_val_acc,
        "prompt_ppl": prompt_ppl,
        "history": result["history"]
    })
    print(f"λ={lam}: best_val_acc={best_val_acc:.4f}, final_val_acc={final_val_acc:.4f}, prompt_ppl={prompt_ppl:.2f}")

print("\n" + "=" * 80)
print("PEZ Grid Search Results (sorted by best_val_acc):")
print("=" * 80)
sorted_results = sorted(pez_grid_results, key=lambda x: x["best_val_acc"], reverse=True)
for r in sorted_results:
    print(f"λ={r['lambda']:.2f}: best_val_acc={r['best_val_acc']:.4f}, final_val_acc={r['final_val_acc']:.4f}, prompt_ppl={r['prompt_ppl']:.2f}")

best_pez_result = max(pez_grid_results, key=lambda x: x["best_val_acc"])
print(f"\nBest λ: {best_pez_result['lambda']:.2f}")
print(f"  best_val_acc={best_pez_result['best_val_acc']:.4f}, final_val_acc={best_pez_result['final_val_acc']:.4f}")
# Out:
# ================================================================================
# GRID SEARCH: Lambda for PEZ (Non-Adversarial, Balanced Loader)
# ================================================================================
#
# --- Testing λ=0.0 ---
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 50 | joint=12.3657 task=12.3657 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 100 | joint=12.3529 task=12.3529 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 150 | joint=12.4593 task=12.4593 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 200 | joint=12.4844 task=12.4844 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 250 | joint=12.3765 task=12.3765 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 300 | joint=12.5017 task=12.5017 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 350 | joint=12.5368 task=12.5368 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 400 | joint=12.5449 task=12.5449 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5 | joint=12.6063 task=12.6063 ppl_loss=0.0000 ppl=0.00 val_loss=13.0813 val_acc=0.4067 prompt_ppl=0.00
# Prompt: permalink hymncît spalatRegistr spelling intelegfug proprietati linguri compozitidoor spumvillagers incadr Anglia Gegeneutic ieftinNV Domnului intrebare proaspat arhitectura proaspat gradinilegungVeterinaryambogia hypothesis gradiniquaintitude descarc intreb cunoaste piele Hristosreminiscentpom gradiniémiphra yes solutii hypothesis pahar totusialaturiambi compozitiDatorita vanzari suprafete redeem gradini asfalt placut parcaredication poveștisunteti adh trandafir rosii reusit adica sfânt corpuluileid cărțiDOM Nantes dome yes achiziti taiat gasi clientilor squash neamDatoritauillerug counterfeitionism intelegeutic bicicletWürttemberg suprafete botez gradiniNapocapermalink lottery Romania vizual linguri
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 50 | joint=12.7731 task=12.7731 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 100 | joint=12.6205 task=12.6205 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 150 | joint=12.5354 task=12.5354 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 200 | joint=12.4451 task=12.4451 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 250 | joint=12.5051 task=12.5051 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 300 | joint=12.6035 task=12.6035 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 350 | joint=12.6005 task=12.6005 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 400 | joint=12.6387 task=12.6387 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5 | joint=12.6723 task=12.6723 ppl_loss=0.0000 ppl=0.00 val_loss=7.1653 val_acc=0.3783 prompt_ppl=0.00
# Prompt: gradini superioara gradini incadrignon incadr Published ciocolat rosii acquaintancecît linguri gradini Merkel Craiova bebelus caloriiherently solutie Timişoara linguri viteze echipă Explain continent depasi gradinienseignement grapplcostinguleiulaffects suprafete cladiri obtine://informatiile gasest ganduri Welche institutii gradininstruire prevazut adicapermalink depasi adica gasest
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 50 | joint=13.3368 task=13.3368 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 100 | joint=13.0226 task=13.0226 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 150 | joint=13.0735 task=13.0735 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 200 | joint=13.2155 task=13.2155 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 250 | joint=13.1821 task=13.1821 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 300 | joint=13.1326 task=13.1326 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 350 | joint=13.1071 task=13.1071 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 400 | joint=13.1032 task=13.1032 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5 | joint=13.0980 task=13.0980 ppl_loss=0.0000 ppl=0.00 val_loss=6.2490 val_acc=0.3783 prompt_ppl=0.00
# Prompt: suprafetepedia bebelus caldura achizitiona suprafete yes bebelusMEDIAPacific Nazi paradigmuploads suprafetestoffdeposited plictis suprafete machiaj oceanincepandstrich bebelusceputul proaspatconfortul albastru lucrari Sfantgrija oferaoricine Sage Cluj proaspatculoarea gradina mirosivityancienne incadrherebyambogialungul compoziti galben folosesteculoarearoș obtine suprafeteionismGo M suprafete suprafete gradini adanchaus bebelus proaspat copilulpermalinkhtmlrance NUAlp adicagreg pagina situatii
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 50 | joint=12.9134 task=12.9134 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 100 | joint=12.8244 task=12.8244 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 150 | joint=12.7328 task=12.7328 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 200 | joint=12.5483 task=12.5483 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 250 | joint=12.6169 task=12.6169 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 300 | joint=12.7051 task=12.7051 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 350 | joint=12.6860 task=12.6860 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 400 | joint=12.6784 task=12.6784 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5 | joint=12.5892 task=12.5892 ppl_loss=0.0000 ppl=0.00 val_loss=18.1577 val_acc=0.6006 prompt_ppl=0.00
# Prompt: judeţuluous translateiocese senzaticontinuare iubire coloan gradini pretul jocul raspunde prevazutDatoritasäu vehicul senzati frunze proaspat majority uselessrange suprafete prevazut incadracryl Atlasédit incadr fisierlienKüaposjudețul récittourism result sunet Brokenplant proaspat cadouriambogia spalat Nobel incadrxiajudețul proaspatcosting interioarewahlromâniilohnfluoxetine yes Iulia neam:// psiho senzati incadr verific Constanţa societati nitrogenrain bucătări helps pieseulation bucătări suprafete Timişoara pastra+1heed psihosunteti jocul SinaiÜbungen inteleg raspunde caldura peisaj Constanțacredit psiho Eva gradinilebt ISBNchirurg iubire adica treaba machiaj mediculcosting
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 50 | joint=12.6533 task=12.6533 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 100 | joint=12.5707 task=12.5707 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 150 | joint=12.4477 task=12.4477 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 200 | joint=12.3924 task=12.3924 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 250 | joint=12.5118 task=12.5118 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 300 | joint=12.5498 task=12.5498 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 350 | joint=12.5645 task=12.5645 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 400 | joint=12.6003 task=12.6003 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5 | joint=12.5984 task=12.5984 ppl_loss=0.0000 ppl=0.00 val_loss=16.9475 val_acc=0.3783 prompt_ppl=0.00
# Prompt: lunii compozitinumarul usoara incadrsunteti incadrgouttesunteti incadr Sum gradini superioara superioaranumarul formularul bebeluselleredia povești Județean gradina stiu defect Spremputation linistit diferenta gasest simtiivism galben lipsit suprafete rosii judet evrei rosii senzatiiocese avetisunteti calorii=" preparat mancare absolven suprafeteuleiulsectiune SuceavacuitSaxonGES summarize tinere simptome senzati actiuni Beneficicru suprafete incadr constructii abonament senzati machiaj senzati incadrerfolg suprafete renunt incadr senzati mananc incadrrgic sanatate blossomatism diferentaNapoca machiaj gradini foloseste modificaricône dimineata manancculoarea reicht vizual linistit machiaj abonamentgasescUneori gradina
# λ=0.0: best_val_acc=0.6006, final_val_acc=0.3783, prompt_ppl=0.00
#
# --- Testing λ=0.01 ---
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 50 | joint=12.2392 task=12.1707 ppl_loss=6.8593 ppl=1249.71
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 100 | joint=12.1029 task=12.0327 ppl_loss=7.0131 ppl=1359.21
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 150 | joint=12.2988 task=12.2289 ppl_loss=6.9923 ppl=1305.02
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 200 | joint=12.1904 task=12.1205 ppl_loss=6.9901 ppl=1283.04
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 250 | joint=12.3869 task=12.3172 ppl_loss=6.9714 ppl=1254.74
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 300 | joint=12.5012 task=12.4317 ppl_loss=6.9556 ppl=1233.86
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 350 | joint=12.4816 task=12.4119 ppl_loss=6.9721 ppl=1258.60
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 400 | joint=12.6250 task=12.5555 ppl_loss=6.9486 ppl=1236.42
# [PEZ λ=0.01 NON-ADV] Epoch 1/5 | joint=12.6403 task=12.5706 ppl_loss=6.9616 ppl=1246.90 val_loss=4.9405 val_acc=0.3783 prompt_ppl=1427.25
# Prompt: asteptam descarc wrestle bebelus planted modificariromânii Craciun trandafir gradini caloriiwent inregistrat descarc inregistrat diferentawagTélécharger clientii senzati adanc mananc zaharceputul nunta invata imunitarWestfalen gradini=" spalatceapa Bundesligaromâniihaudiereculoarea CercetaMasspackedMax prevazut functioneaza proaspat situatii calorii CanterburyProdusele bebelus cautareccessed inaltime GMT Speaking No nuntaconsiderare placeholderrada toti protectie gasest acasa descarc senzatiomni MAI avetinjeux spatiucelul retetawiki boteznox Bochidrat săptămânăculoareagold frunze
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 50 | joint=12.8305 task=12.7597 ppl_loss=7.0817 ppl=1408.93
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 100 | joint=13.0652 task=12.9954 ppl_loss=6.9891 ppl=1298.86
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 150 | joint=13.1447 task=13.0749 ppl_loss=6.9752 ppl=1261.54
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 200 | joint=13.0477 task=12.9780 ppl_loss=6.9737 ppl=1256.06
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 250 | joint=13.0145 task=12.9447 ppl_loss=6.9847 ppl=1271.12
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 300 | joint=12.9495 task=12.8797 ppl_loss=6.9757 ppl=1252.52
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 350 | joint=12.8459 task=12.7760 ppl_loss=6.9808 ppl=1256.02
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 400 | joint=12.7823 task=12.7125 ppl_loss=6.9809 ppl=1253.19
# [PEZ λ=0.01 NON-ADV] Epoch 2/5 | joint=12.7683 task=12.6985 ppl_loss=6.9789 ppl=1248.86 val_loss=10.2737 val_acc=0.3801 prompt_ppl=1345.23
# Prompt: suprafete proaspat crestinsunteti Vermieter etajWLpovadevar Poland suprafeteluminous acasa iubire diferenta linguri PNL Magnetic surpass bebelus proaspat caloriirân cunoaste proaspat proaspat imunitaruploads exceeded EminescuPflanzDatorita pamantnutri Dragnealumina gradiniincat asteapta suprafete NCchirurg sfântmai EVERY diferenta depasi acasa Dragnea Sorin taiat Timișoara foloseste gasiincat proaspat vrei trackback proaspatluniigres gradinaück superioaraDimensiuni Beneficiunicipiuluioarăfällig Gov Familiecriptpremise Carnegie prevazutarciniavolution proaspat Helfercell Craiova nebun Timişoara lingurirousfares diferentalesqopi Wiuzi
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 50 | joint=12.6966 task=12.6273 ppl_loss=6.9338 ppl=1152.86
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 100 | joint=12.7122 task=12.6424 ppl_loss=6.9769 ppl=1237.81
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 150 | joint=12.6862 task=12.6164 ppl_loss=6.9818 ppl=1262.67
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 200 | joint=12.7860 task=12.7163 ppl_loss=6.9703 ppl=1244.07
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 250 | joint=12.7197 task=12.6502 ppl_loss=6.9565 ppl=1219.17
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 300 | joint=12.6831 task=12.6138 ppl_loss=6.9335 ppl=1205.03
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 350 | joint=12.7690 task=12.6996 ppl_loss=6.9379 ppl=1209.95
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 400 | joint=12.7496 task=12.6802 ppl_loss=6.9376 ppl=1210.55
# [PEZ λ=0.01 NON-ADV] Epoch 3/5 | joint=12.7513 task=12.6818 ppl_loss=6.9453 ppl=1216.88 val_loss=6.0777 val_acc=0.3783 prompt_ppl=1123.26
# Prompt: RCAbus ingrijire împărat German imunitar rosiiculoareanaj gradini gone situatii adanc dureri gradini suprafetepolisBRA Fountainhaudiere gradinibyte dorintgründe с traditibru tugPărintereadableDimensiunikanWürttemberg Relation SnoKaufentscheidung modificarilust spalat simtiuploads Timișoaraless apropie depasiDatorita cartofiaparutDedicated cartofi imobilhhh Paol cătcît pahar suprafete?) senzati amintiri incadr intoarcePalatulajungi iesit frunzerelates ingrijire
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 50 | joint=12.2979 task=12.2277 ppl_loss=7.0184 ppl=1281.29
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 100 | joint=12.6848 task=12.6151 ppl_loss=6.9746 ppl=1256.59
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 150 | joint=12.8009 task=12.7311 ppl_loss=6.9755 ppl=1243.71
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 200 | joint=12.7751 task=12.7054 ppl_loss=6.9754 ppl=1264.42
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 250 | joint=12.7282 task=12.6585 ppl_loss=6.9711 ppl=1245.18
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 300 | joint=12.7457 task=12.6759 ppl_loss=6.9771 ppl=1252.11
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 350 | joint=12.7000 task=12.6301 ppl_loss=6.9848 ppl=1269.43
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 400 | joint=12.5582 task=12.4885 ppl_loss=6.9729 ppl=1273.11
# [PEZ λ=0.01 NON-ADV] Epoch 4/5 | joint=12.6224 task=12.5528 ppl_loss=6.9618 ppl=1258.20 val_loss=5.4205 val_acc=0.3783 prompt_ppl=2210.14
# Prompt: aptDimensiuni Estonia Guard Eminescu incadrmoni")midst rosii povești Eminescuiness locuinte cladiriGermain depasi achiziti summarizeHarators trackback scarcecostingefectele gradini sunet summarizecît situatii adicaseid translate diferentaincat spenturmatoarele dispozitie Readingverseceputulceputul senzatisunteti gradini ReviewsTeatrulBiblio accountantbay Physician Encourage redemption Domnului orizont spalat senzatisport prevazutrada situatiefax actiune
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 50 | joint=11.9581 task=11.8880 ppl_loss=7.0103 ppl=1275.75
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 100 | joint=12.5765 task=12.5061 ppl_loss=7.0454 ppl=1335.93
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 150 | joint=12.5287 task=12.4583 ppl_loss=7.0404 ppl=1331.74
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 200 | joint=12.7364 task=12.6663 ppl_loss=7.0156 ppl=1318.11
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 250 | joint=12.8370 task=12.7669 ppl_loss=7.0049 ppl=1299.27
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 300 | joint=12.8551 task=12.7852 ppl_loss=6.9881 ppl=1275.72
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 350 | joint=12.7990 task=12.7291 ppl_loss=6.9926 ppl=1280.20
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 400 | joint=12.7852 task=12.7154 ppl_loss=6.9768 ppl=1257.50
# [PEZ λ=0.01 NON-ADV] Epoch 5/5 | joint=12.8165 task=12.7468 ppl_loss=6.9697 ppl=1252.42 val_loss=8.5769 val_acc=0.3771 prompt_ppl=2025.26
# Prompt: lustig compoziti pietre incadr mananc TippAsadar functioneazanique machiajsettlers crestinphobia incadr avetibabcît incadr adanc gradiniDimensiuni clientii gradini incadr Timișoara spalathart sisters Grigorgardinen incadr ******* blur poetryivism vizual gustgardinenponguleiuljudeţul doigt MAI diferenta ceilalti locuinteappar incadrculoareaBMhik suprafete niciodata sci etaj
# λ=0.01: best_val_acc=0.3801, final_val_acc=0.3771, prompt_ppl=2025.26
#
# --- Testing λ=0.05 ---
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 50 | joint=12.7194 task=12.3696 ppl_loss=6.9972 ppl=1285.23
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 100 | joint=12.7636 task=12.4166 ppl_loss=6.9390 ppl=1211.74
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 150 | joint=12.9133 task=12.5679 ppl_loss=6.9082 ppl=1173.18
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 200 | joint=12.9785 task=12.6321 ppl_loss=6.9281 ppl=1185.96
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 250 | joint=13.0800 task=12.7329 ppl_loss=6.9425 ppl=1221.67
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 300 | joint=13.0329 task=12.6859 ppl_loss=6.9393 ppl=1206.80
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 350 | joint=13.0695 task=12.7222 ppl_loss=6.9454 ppl=1221.23
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 400 | joint=13.0394 task=12.6911 ppl_loss=6.9660 ppl=1244.98
# [PEZ λ=0.05 NON-ADV] Epoch 1/5 | joint=13.0222 task=12.6739 ppl_loss=6.9646 ppl=1238.18 val_loss=22.6847 val_acc=0.3783 prompt_ppl=780.27
# Prompt: INFO 04/2 gradini rosiireclining pielii incercural faci constructii situatie clientilor functioneazaănă apariti gradini gradini Primări suprafete bebelusgoutteându bebelus bebelusvruvâr albastru gradinilângă gradiniconfortulcît apariti pacateProiectulweakenedNeither judeţ diagnos ConstanțaNapoca No gradini spalatmunicipiulLizenzillardlini multumesc rugam revolve Reparaturivitate amenajat senzor suprafete machiajnism greutateaparatul(0) taiat calorii incadr formularul negru rosii adica incadr(0) pielea repar formularul neamsunteti mediculimbaicillinobligate Ju Domnului gandieuticsunteti probability linguri linguri schizophrenia gasest senzatiterapieolar gradini producatorcît senzati gradini
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 50 | joint=13.2291 task=12.8851 ppl_loss=6.8799 ppl=1204.92
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 100 | joint=12.9808 task=12.6347 ppl_loss=6.9225 ppl=1187.94
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 150 | joint=12.9367 task=12.5911 ppl_loss=6.9115 ppl=1156.12
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 200 | joint=12.9104 task=12.5633 ppl_loss=6.9425 ppl=1193.38
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 250 | joint=12.8750 task=12.5266 ppl_loss=6.9683 ppl=1242.93
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 300 | joint=12.8287 task=12.4807 ppl_loss=6.9603 ppl=1230.37
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 350 | joint=12.7981 task=12.4499 ppl_loss=6.9641 ppl=1228.14
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 400 | joint=12.7959 task=12.4475 ppl_loss=6.9685 ppl=1227.24
# [PEZ λ=0.05 NON-ADV] Epoch 2/5 | joint=12.8358 task=12.4868 ppl_loss=6.9794 ppl=1248.78 val_loss=14.5199 val_acc=0.3979 prompt_ppl=1556.81
# Prompt: senzor prevazut bebelus proaspatcreme summarize proaspat 2011, compoziti compozitizarvremea gradiniopi gradini compozitirete bebelus diferenta rosiizar suprafete superioara sfântucun șofer gradini OK Gentlevâr ensue imobil*** Cons yesfuz psihoconfortul gib frumoasatipul taiatambogiacosting Indoillesherebyhapcontinuare functi accesorii suprafetespektpears incadrjava pretul Pou rugam Dolphin solutie prevazut nicotine caldura Vezioul proprietatiOUG clientilorcuri Insul incearcaVac renunt accesoriibelcontinuare incadr frumoasa usoara achizitiona Iaşi incadrmili lucrari Emp incadrknofinalists bodipermalink diferentaqnerwild gradina crestin gandi școli
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 50 | joint=12.8267 task=12.4778 ppl_loss=6.9789 ppl=1201.67
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 100 | joint=12.8331 task=12.4817 ppl_loss=7.0272 ppl=1330.82
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 150 | joint=12.7784 task=12.4253 ppl_loss=7.0630 ppl=1371.07
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 200 | joint=12.9059 task=12.5534 ppl_loss=7.0494 ppl=1346.39
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 250 | joint=12.9574 task=12.6047 ppl_loss=7.0531 ppl=1349.87
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 300 | joint=12.9872 task=12.6350 ppl_loss=7.0444 ppl=1326.15
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 350 | joint=12.9970 task=12.6445 ppl_loss=7.0492 ppl=1323.80
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 400 | joint=13.0316 task=12.6797 ppl_loss=7.0380 ppl=1324.46
# [PEZ λ=0.05 NON-ADV] Epoch 3/5 | joint=13.0207 task=12.6703 ppl_loss=7.0076 ppl=1286.58 val_loss=8.3852 val_acc=0.3783 prompt_ppl=743.13
# Prompt: ciocolat iesit vizualiz incadr proaspatRCA inregistratNapoca lichid castiglent fișier spatiu Timişoara prevazut cunoaste sticlaDatorita sticla sufletul locuinte proaspat cunoastepermalinkPublishgurancies ConstanțaVaccin vietii linguri linguri linguri superioaraDatorita superioaragardinen senzati locuintecholhren Timișoara gradini rugam aplicatiicosting prevazuttagsprindere rosii senzorclerosis summarize Iaşi inaltimecca multumesc linguri diferentapermalink solutieatorii gradini bebelus incadr aplicatii masini poatinformatiile rugampixel multumescpermalink situatii incadr incadr gradinisunteti laundering bacteriiliens
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 50 | joint=12.7298 task=12.3802 ppl_loss=6.9928 ppl=1221.30
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 100 | joint=12.9558 task=12.6082 ppl_loss=6.9516 ppl=1238.45
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 150 | joint=13.1245 task=12.7781 ppl_loss=6.9287 ppl=1222.04
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 200 | joint=13.1003 task=12.7539 ppl_loss=6.9274 ppl=1200.61
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 250 | joint=13.0825 task=12.7364 ppl_loss=6.9218 ppl=1184.74
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 300 | joint=13.0768 task=12.7304 ppl_loss=6.9280 ppl=1197.45
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 350 | joint=13.0589 task=12.7122 ppl_loss=6.9353 ppl=1211.59
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 400 | joint=13.0670 task=12.7194 ppl_loss=6.9504 ppl=1230.83
# [PEZ λ=0.05 NON-ADV] Epoch 4/5 | joint=13.1217 task=12.7737 ppl_loss=6.9604 ppl=1235.98 val_loss=8.8925 val_acc=0.3783 prompt_ppl=842.84
# Prompt: gradini prevazut gradini oferadescendingIdeally carré gradini Mihai gradini clientilor suprafete dispoziti regl Brașov taiat imbunatati placut Kickstarterlern compoziti dispoziti gradini ciocolat machiaj machiaj adanc descarc incadr masuraehr senzati proprietatieanumardi organizatoriв commute descarc Multumescescent ganduri diferenta gradini ganduriProduseleromânii suprafete Braşov=" situatii proaspat galben Despre conveyorCombinedluj diferenta Congrats proaspatProdusele proaspatuploads suprafete incadr etaj proaspat proaspathttpgardinenurl
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 50 | joint=13.0553 task=12.7073 ppl_loss=6.9598 ppl=1320.11
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 100 | joint=12.9027 task=12.5552 ppl_loss=6.9492 ppl=1294.50
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 150 | joint=12.8856 task=12.5388 ppl_loss=6.9365 ppl=1253.38
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 200 | joint=13.0138 task=12.6668 ppl_loss=6.9400 ppl=1257.31
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 250 | joint=13.0233 task=12.6769 ppl_loss=6.9284 ppl=1230.82
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 300 | joint=12.9777 task=12.6323 ppl_loss=6.9074 ppl=1205.05
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 350 | joint=12.9714 task=12.6257 ppl_loss=6.9129 ppl=1197.06
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 400 | joint=12.9167 task=12.5700 ppl_loss=6.9346 ppl=1222.55
# [PEZ λ=0.05 NON-ADV] Epoch 5/5 | joint=12.9572 task=12.6108 ppl_loss=6.9268 ppl=1203.36 val_loss=21.7122 val_acc=0.3783 prompt_ppl=772.52
# Prompt: compoziti suprafetefotograf zic translate mananc galbenUploaded VarietyuploadsSmithseid gradiniromânii apariti senzati compoziti gradinideci gradini manancmânt gradinideciholzê nebun pretulfreivettejudeţul incadr sunetplaît bebelus bacteriiuploads expoziți apucpertaining gradinibetween proaspat pastraieux prevazut senzatiotwithstanding senzativeticorrect gradini gradiniöhl prevazut rosii senzati bă senzati frumoasa:// senzati inlocui senzatiluster gradini superioara paharopteddestin comenzi machiaj judetînd Vezi compoziti bebelus bebelus senzatiTIM neamnicijudeţul verzichtencarbon Sinai senzati senzati sarbatori mananc intelege2). paharcativa gradini gradini confortabil
# λ=0.05: best_val_acc=0.3979, final_val_acc=0.3783, prompt_ppl=772.52
#
# --- Testing λ=0.1 ---
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 50 | joint=13.6085 task=12.9087 ppl_loss=6.9982 ppl=1214.71
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 100 | joint=13.2741 task=12.5773 ppl_loss=6.9675 ppl=1158.60
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 150 | joint=13.5090 task=12.8158 ppl_loss=6.9319 ppl=1150.20
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 200 | joint=13.5978 task=12.9047 ppl_loss=6.9311 ppl=1190.43
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 250 | joint=13.5610 task=12.8671 ppl_loss=6.9392 ppl=1211.52
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 300 | joint=13.4610 task=12.7670 ppl_loss=6.9402 ppl=1209.71
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 350 | joint=13.4818 task=12.7874 ppl_loss=6.9443 ppl=1221.76
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 400 | joint=13.5204 task=12.8258 ppl_loss=6.9458 ppl=1213.40
# [PEZ λ=0.1 NON-ADV] Epoch 1/5 | joint=13.4948 task=12.7980 ppl_loss=6.9675 ppl=1240.52 val_loss=11.9199 val_acc=0.3783 prompt_ppl=1122.62
# Prompt: suprafete incercat rosiicît sticla sticlaeille Iisus:// pretul suprafete Spania Timișoara prevazutheld prevazutiscus spalat intreb urmaricîtbooroach cumpara suprafete bolt vizualological suprafete translate intellectual gradini whil proaspatoncesunteti gradini Iaşiajungigardinen Laurie”).kap Constanța Stadi vazut sticlaiolo Desprespatele vizualWS gradini sticla împărat plajcît superioara societaticît usturoiaparatuleklagtepletecît
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 50 | joint=12.6427 task=11.9569 ppl_loss=6.8579 ppl=1039.12
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 100 | joint=12.5860 task=11.8922 ppl_loss=6.9378 ppl=1156.71
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 150 | joint=12.7637 task=12.0672 ppl_loss=6.9649 ppl=1301.24
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 200 | joint=12.9263 task=12.2270 ppl_loss=6.9928 ppl=1332.18
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 250 | joint=12.9612 task=12.2644 ppl_loss=6.9686 ppl=1291.54
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 300 | joint=12.9734 task=12.2764 ppl_loss=6.9693 ppl=1275.99
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 350 | joint=12.9061 task=12.2077 ppl_loss=6.9842 ppl=1286.67
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 400 | joint=12.9236 task=12.2249 ppl_loss=6.9871 ppl=1306.60
# [PEZ λ=0.1 NON-ADV] Epoch 2/5 | joint=12.9808 task=12.2821 ppl_loss=6.9864 ppl=1300.77 val_loss=5.3403 val_acc=0.3783 prompt_ppl=1583.50
# Prompt: haudierefullyflüge reteta ingrijirecît summarize compozitideparted mananc vietiiasta depasi gradinilandais Județeantravelled niciodata argint increderebeneficiar”). gradina desfasoculoarea dărui sunet jpl Furglerels bebelus desfaso aveti malariaOricumuploads 04/2 machiaj psihoDatoritacelulconsiderare proaspatmetributed proaspat machiajtreu Emp vietii diferentaussiEnergi cladiri imunitar parinti gradinantino Gewerbegmail proaspat aluat machiaj Sfant nebunforeseeablefigured senzati gradinaquette Football summarizenectslatedbai orasului diferenta translatemunicipiulurl
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 50 | joint=13.0071 task=12.3108 ppl_loss=6.9626 ppl=1239.71
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 100 | joint=13.2781 task=12.5817 ppl_loss=6.9640 ppl=1225.70
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 150 | joint=13.5068 task=12.8090 ppl_loss=6.9784 ppl=1239.43
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 200 | joint=13.5805 task=12.8814 ppl_loss=6.9901 ppl=1246.74
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 250 | joint=13.3082 task=12.6105 ppl_loss=6.9774 ppl=1216.99
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 300 | joint=13.2979 task=12.5993 ppl_loss=6.9854 ppl=1249.12
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 350 | joint=13.2297 task=12.5313 ppl_loss=6.9845 ppl=1242.86
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 400 | joint=13.1967 task=12.4986 ppl_loss=6.9803 ppl=1239.22
# [PEZ λ=0.1 NON-ADV] Epoch 3/5 | joint=13.2183 task=12.5202 ppl_loss=6.9804 ppl=1247.72 val_loss=9.8025 val_acc=0.3789 prompt_ppl=1250.57
# Prompt: frunze/19 cunoaste poze suprafete peine linguri eternity suprafeteUNItophovvasesulescu tava Parcheteklagteyes proaspat prevazut sticla inspirat superioara rosii suprafete clientilor simti incadr suprafete obsolete spatiu Dumnezeu gradinibucuria suprafete somnwikipediaArg incadrdeal varstaembreivi gradini suprafete suprafete dumneavoastraouette poatinevitablyprezintacărui gradinimila ganduri cătTeatrul ThinkProduseleLaugh
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 50 | joint=12.9602 task=12.2626 ppl_loss=6.9764 ppl=1227.44
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 100 | joint=13.2714 task=12.5749 ppl_loss=6.9656 ppl=1223.50
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 150 | joint=13.3535 task=12.6573 ppl_loss=6.9615 ppl=1234.55
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 200 | joint=13.3352 task=12.6362 ppl_loss=6.9900 ppl=1273.26
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 250 | joint=13.4177 task=12.7185 ppl_loss=6.9921 ppl=1304.91
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 300 | joint=13.3664 task=12.6675 ppl_loss=6.9890 ppl=1301.86
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 350 | joint=13.3536 task=12.6555 ppl_loss=6.9812 ppl=1280.82
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 400 | joint=13.4063 task=12.7089 ppl_loss=6.9744 ppl=1269.38
# [PEZ λ=0.1 NON-ADV] Epoch 4/5 | joint=13.3551 task=12.6568 ppl_loss=6.9827 ppl=1273.71 val_loss=19.8584 val_acc=0.3783 prompt_ppl=528.50
# Prompt: gardinen gradini BrazilAsociația asfalt proaspat adevarat taiat taiat calorii placeboßen_ taiat reckon parties machiaj summarizeDatorita proaspathtmldevédit preot taiat vizualiz repos asfaltversiune taiatpres contemporan EminescuAsociația foloseste proaspat taiatnsel converside incadr phyto proaspat taiat foloseste translateconsromânii solutie translate proaspatpres repos foloseste pl gradini0.00 rendezfolgenden zahar usoara senzati formularul răc wh bio interpret proaspat gradini taiatmpf senzati paharschadenprovideeuer suprafetelusennemi compoziti gradinimetri adica reproducOpti taiatezimalgol niciodata exterioar Giurgiu compoziti varfmehr solutiiDatorita
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 50 | joint=13.3782 task=12.6798 ppl_loss=6.9847 ppl=1287.31
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 100 | joint=13.3577 task=12.6583 ppl_loss=6.9933 ppl=1256.95
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 150 | joint=13.4062 task=12.7027 ppl_loss=7.0353 ppl=1322.27
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 200 | joint=13.4322 task=12.7286 ppl_loss=7.0366 ppl=1330.51
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 250 | joint=13.3732 task=12.6721 ppl_loss=7.0114 ppl=1299.37
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 300 | joint=13.3035 task=12.6037 ppl_loss=6.9980 ppl=1273.81
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 350 | joint=13.3101 task=12.6109 ppl_loss=6.9922 ppl=1262.96
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 400 | joint=13.3523 task=12.6534 ppl_loss=6.9894 ppl=1255.49
# [PEZ λ=0.1 NON-ADV] Epoch 5/5 | joint=13.3957 task=12.6970 ppl_loss=6.9871 ppl=1247.78 val_loss=5.9434 val_acc=0.3783 prompt_ppl=2119.53
# Prompt: varsta gradinisuntetiuploads mananccîtTeatrul machiaj suprafeteanciesKaufentscheidungWhether yes proaspatuploads suprafeteculoarea imunitar suprafete transcript adica rosii anytime masina caldura pretul Receiv achiziti usturoi vazut turnover iesitkli obese cautare descarc ramasDrive gradini gradiniviteză suprafeteluj frigider teatru didactic gradinitirenam bucati machiaj tavapolita etaj gradini gasi
# λ=0.1: best_val_acc=0.3789, final_val_acc=0.3783, prompt_ppl=2119.53
#
# --- Testing λ=0.25 ---
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 50 | joint=14.4583 task=12.6873 ppl_loss=7.0839 ppl=1387.27
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 100 | joint=14.5099 task=12.7522 ppl_loss=7.0308 ppl=1302.18
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 150 | joint=14.5732 task=12.8310 ppl_loss=6.9687 ppl=1270.69
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 200 | joint=14.7055 task=12.9598 ppl_loss=6.9828 ppl=1300.74
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 250 | joint=14.6418 task=12.8967 ppl_loss=6.9806 ppl=1285.03
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 300 | joint=14.5983 task=12.8490 ppl_loss=6.9974 ppl=1322.72
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 350 | joint=14.5653 task=12.8170 ppl_loss=6.9932 ppl=1303.54
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 400 | joint=14.6073 task=12.8611 ppl_loss=6.9848 ppl=1280.28
# [PEZ λ=0.25 NON-ADV] Epoch 1/5 | joint=14.5696 task=12.8207 ppl_loss=6.9955 ppl=1288.26 val_loss=6.2289 val_acc=0.3783 prompt_ppl=1086.34
# Prompt: soir machiajcessionPCRatlantic linguriSubmitted adanc herbanstalt proaspat incadr proaspatlomb descarcritaSfântulturm translateerfolg gasest coupleswrongful organizatori proaspatbeneficiarfrem cautare incadritaladevar pretul machiajPurchasing Favoralaturi pana pacate aveti diferenta proaspat povești proaspatsynchron diferentaurmatoarelecrezicul constructii spalat proaspatpremise query blur contextpremise
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 50 | joint=14.2075 task=12.4841 ppl_loss=6.8936 ppl=1087.42
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 100 | joint=14.3927 task=12.6488 ppl_loss=6.9755 ppl=1199.99
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 150 | joint=14.4435 task=12.6983 ppl_loss=6.9810 ppl=1235.54
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 200 | joint=14.5365 task=12.7944 ppl_loss=6.9686 ppl=1221.92
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 250 | joint=14.5485 task=12.8080 ppl_loss=6.9622 ppl=1220.88
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 300 | joint=14.4902 task=12.7492 ppl_loss=6.9641 ppl=1238.15
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 350 | joint=14.5410 task=12.8004 ppl_loss=6.9625 ppl=1253.86
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 400 | joint=14.4775 task=12.7353 ppl_loss=6.9686 ppl=1277.06
# [PEZ λ=0.25 NON-ADV] Epoch 2/5 | joint=14.4242 task=12.6851 ppl_loss=6.9564 ppl=1255.27 val_loss=5.2454 val_acc=0.3896 prompt_ppl=973.04
# Prompt: abonament bebelus proaspattuftjudeţul culminat bebelus abonamenthereby proaspat adica senzati incadr ceilalti machiaj retetaoffresvremea proaspat incadr ganduri Stoff moalealaya Popescu Claus Eminescupears abonamentajungi proaspat machiaj aluat sticlaDatorita machiaj pamantuploads Encyclopedia suprafeteajungi foloseste nebunuoussunteti machiajerfolgIntocît intoarcesiliDatorita Domnuluibeneficiar senzati Thronesgardinen superioara compoziti4%judging formularul nebun multumesc verde functie query nebun?” context urmeazaMuzeul situatii diferentalogue incadrcîtcic cunoaste diferenta cumpara proaspat sticla
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 50 | joint=13.8206 task=12.0826 ppl_loss=6.9518 ppl=1193.73
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 100 | joint=14.3968 task=12.6506 ppl_loss=6.9849 ppl=1246.18
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 150 | joint=14.4719 task=12.7206 ppl_loss=7.0053 ppl=1315.16
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 200 | joint=14.5294 task=12.7795 ppl_loss=6.9996 ppl=1318.32
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 250 | joint=14.4186 task=12.6755 ppl_loss=6.9722 ppl=1274.45
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 300 | joint=14.3770 task=12.6340 ppl_loss=6.9718 ppl=1261.57
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 350 | joint=14.3697 task=12.6256 ppl_loss=6.9761 ppl=1256.70
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 400 | joint=14.3905 task=12.6485 ppl_loss=6.9681 ppl=1249.20
# [PEZ λ=0.25 NON-ADV] Epoch 3/5 | joint=14.4410 task=12.6967 ppl_loss=6.9771 ppl=1261.23 val_loss=7.7651 val_acc=0.3783 prompt_ppl=1465.99
# Prompt: prezinta suprafeteuploads Kranken gradini intelectualagespore prevazut vazut bebelus suprafete diferit cătEVER Constanța abonament ganduri mirosaparut asfalturmatoarele placeholdermonies senzati taiatDatoritatell loadedrylgoldficialfinalistsWestfalenwildly piele bebelusomia spalat census Cinemaphocaroraflakesionism fisier Kickstarter Proceednumarulhaudierecarora Salvador suprafete fotografii fișier clientii absolven ganduri traditiNapoca miere
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 50 | joint=14.9620 task=13.1871 ppl_loss=7.0997 ppl=1384.96
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 100 | joint=14.7175 task=12.9559 ppl_loss=7.0463 ppl=1326.79
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 150 | joint=14.5283 task=12.7743 ppl_loss=7.0160 ppl=1289.08
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 200 | joint=14.4802 task=12.7336 ppl_loss=6.9862 ppl=1250.03
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 250 | joint=14.5370 task=12.7935 ppl_loss=6.9739 ppl=1241.80
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 300 | joint=14.5127 task=12.7742 ppl_loss=6.9541 ppl=1216.86
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 350 | joint=14.5592 task=12.8209 ppl_loss=6.9535 ppl=1213.97
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 400 | joint=14.5862 task=12.8492 ppl_loss=6.9480 ppl=1204.98
# [PEZ λ=0.25 NON-ADV] Epoch 4/5 | joint=14.5533 task=12.8193 ppl_loss=6.9360 ppl=1197.75 val_loss=15.1621 val_acc=0.3780 prompt_ppl=1105.19
# Prompt: simo compozitighi suprafete gasicarora niciodata foloseste SuceavaBiserica suprafete clientilor mancare superioara adicaulevard prevazut gasest Magnseară senzati adicastattet hypothesisvineèvreexistent senzati suprafete linguri Ber dărui piatraNo clientilorlohntbodied gag PNL solutii proaspat urmari franchi faceti suprafete inlocui citiöhr facetishortest suprafete noapte totusi senzaticît miscare inlocuilexic nuntacoveted botez adica suprafete mecanic senzatieutic Hobb distant senzatitemp mancare citesc inlocui sarbatoricît usoara diferenta ferr obtinut bebeluscît suprafete gradiniculoarea etajinfringement linistit apariti etcDimensiuniambogia psiho Encyclopediaurmatoarele ganduri crushedzilla ingrijirecompatiblenox
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 50 | joint=14.5538 task=12.8307 ppl_loss=6.8927 ppl=1143.98
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 100 | joint=14.2701 task=12.5440 ppl_loss=6.9046 ppl=1160.81
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 150 | joint=14.3931 task=12.6631 ppl_loss=6.9202 ppl=1183.34
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 200 | joint=14.4577 task=12.7222 ppl_loss=6.9422 ppl=1208.56
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 250 | joint=14.6059 task=12.8607 ppl_loss=6.9810 ppl=1269.76
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 300 | joint=14.5409 task=12.7935 ppl_loss=6.9894 ppl=1289.26
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 350 | joint=14.5832 task=12.8372 ppl_loss=6.9842 ppl=1289.97
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 400 | joint=14.5515 task=12.8063 ppl_loss=6.9806 ppl=1280.42
# [PEZ λ=0.25 NON-ADV] Epoch 5/5 | joint=14.4903 task=12.7461 ppl_loss=6.9767 ppl=1270.79 val_loss=20.4926 val_acc=0.3783 prompt_ppl=818.42
# Prompt: cătnote suprafeteBisericaGoldfait senzati gradini bebelus gradini avetiDatorita lingurichan gasit feat gradini senzati senzati creier cătromâniimunicipiul Londraicillin sticla patrol bebelus foloseste sanatos gradini gradini asfalt intrebari senzati odata Eminescuéanmoins bebelus summarize suprafete imunitar cunoastecarora cunoaste vanzare pamant inaltime intrebcosting suprafete footsteps ISBN invata gradina Giurgiu etajmnului incadr galbenescence incercat pacient gradini suprafetenicivousimpotriva suprafete clientilor suprafete ediți senzati suprafete dimineatasuntetirmând translatelungul machiajunauthorized pielii Disclosure diferenta mananc suprafete unchanged Inspectorcontinuarecontinuare trandafirclin contulsuntetiNapoca contemporan psiho Craciun prevazut
# λ=0.25: best_val_acc=0.3896, final_val_acc=0.3783, prompt_ppl=818.42
#
# --- Testing λ=0.5 ---
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 50 | joint=16.2749 task=12.8017 ppl_loss=6.9464 ppl=1240.97
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 100 | joint=16.0415 task=12.5274 ppl_loss=7.0282 ppl=1325.83
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 150 | joint=16.0231 task=12.5332 ppl_loss=6.9798 ppl=1261.08
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 200 | joint=16.1122 task=12.6202 ppl_loss=6.9839 ppl=1272.37
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 250 | joint=16.2035 task=12.7168 ppl_loss=6.9734 ppl=1268.11
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 300 | joint=16.2352 task=12.7463 ppl_loss=6.9777 ppl=1265.50
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 350 | joint=16.2016 task=12.7105 ppl_loss=6.9822 ppl=1268.35
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 400 | joint=16.2341 task=12.7420 ppl_loss=6.9842 ppl=1274.19
# [PEZ λ=0.5 NON-ADV] Epoch 1/5 | joint=16.2140 task=12.7194 ppl_loss=6.9893 ppl=1278.08 val_loss=10.4810 val_acc=0.3780 prompt_ppl=823.28
# Prompt: stattet incearca compozitisuntetigasesc senzati incadr foloseste abonament proaspatijk proaspatciv abonament suprafete picior proaspat Hristos proaspat gradini proaspatographerwhitening proaspatcompatible iubitcît bebelus abonament bebelus abonament sanatatermândethyleneister lunarurban bebelus spalatstattet hypothesisbodied proaspatIndiferentrmândpvc Eminescustattet spalatiding senzatistattet pieliicontinuare rendezmpf franchineuveniste proaspat gasestrmândcîtstattet Eminescuotwithstanding caci Romaniauber primavaraemper summarize translate somniggle Romania Eiuntarmândigglermând cladirineig moale Romania somn Romania multumesc Romaniarab Romania @ query summarize Romania Romania German summarize Romania German
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 50 | joint=16.1053 task=12.6244 ppl_loss=6.9618 ppl=1146.47
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 100 | joint=16.2419 task=12.7699 ppl_loss=6.9440 ppl=1148.34
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 150 | joint=16.2763 task=12.7908 ppl_loss=6.9711 ppl=1236.99
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 200 | joint=16.2617 task=12.7657 ppl_loss=6.9921 ppl=1245.11
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 250 | joint=16.2428 task=12.7475 ppl_loss=6.9906 ppl=1243.06
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 300 | joint=16.2598 task=12.7622 ppl_loss=6.9952 ppl=1273.50
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 350 | joint=16.2281 task=12.7364 ppl_loss=6.9835 ppl=1267.20
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 400 | joint=16.2432 task=12.7560 ppl_loss=6.9744 ppl=1270.36
# [PEZ λ=0.5 NON-ADV] Epoch 2/5 | joint=16.1617 task=12.6733 ppl_loss=6.9768 ppl=1275.99 val_loss=25.4737 val_acc=0.3783 prompt_ppl=329.09
# Prompt: ommagetialcoveted hypothesis senzati gradini gradini senzati gradini clientilor clientiloronné senzati rosii Craiova asteapta senzati mananc senzatiTeatrul suprafete adicacît suprafete adica suprafete 04/2ón senzatiatul zahar compoziti bebelus taiatdatorita senzaticît senzati sănătos cautare cuptor borders proaspat senzati județ senzati senzati prevazut frumoasa raspunde gradiniöleffectintreaga asteaptaromânii clientilorvârambogiavâr medicul senzati rosii senzati Gemüse Congoinvites gradinisphereeutic proaspat LGBTQ compozitiharm Sfantconfortul gradini Constanța raspunde gradini masina gradini joculcredhitter senzatiständ linistit senzatihydroxy Timişoarauploadscosting suprafete formularul
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 50 | joint=15.9604 task=12.4955 ppl_loss=6.9298 ppl=1134.36
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 100 | joint=15.9029 task=12.4152 ppl_loss=6.9752 ppl=1182.28
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 150 | joint=16.1561 task=12.6778 ppl_loss=6.9565 ppl=1153.78
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 200 | joint=16.2629 task=12.7834 ppl_loss=6.9591 ppl=1173.88
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 250 | joint=16.2526 task=12.7814 ppl_loss=6.9424 ppl=1160.89
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 300 | joint=16.2328 task=12.7580 ppl_loss=6.9495 ppl=1176.53
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 350 | joint=16.2513 task=12.7740 ppl_loss=6.9545 ppl=1187.40
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 400 | joint=16.3259 task=12.8499 ppl_loss=6.9520 ppl=1187.06
# [PEZ λ=0.5 NON-ADV] Epoch 3/5 | joint=16.3687 task=12.8906 ppl_loss=6.9562 ppl=1191.77 val_loss=11.0680 val_acc=0.4303 prompt_ppl=1679.90
# Prompt: bebeluscîtalthoughrcis gasestext Dortmund gradini iluminatDatoritaeverLOSphrotagged Bloombergmounted Stundepas rugam potiestival masini senzati linistit vietiiTagetch/09/uleiul poatyou incadr asfalt spum replyetch arbeitetcosting=" Algeria porumb superioara botezeueracco vanzarimoi inlocui solutie vorbemoi linguriälfte gradinigardinenuréprezinta competițiându disinfectètegoutte gradinijudețulneig gradiniadevar gradini raspundeTélécharger iarna:// proprietati mancare descarc aplicatiiănămnului 04/2 psihologchezicism senzatithankauf incadr pereche formularul suprafete suprafete suprafete gradiniDAC stomacpartenerii bebelus turquoiseWestfalencît
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 50 | joint=15.9263 task=12.5009 ppl_loss=6.8507 ppl=1085.56
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 100 | joint=16.3192 task=12.8774 ppl_loss=6.8836 ppl=1170.02
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 150 | joint=16.1460 task=12.7041 ppl_loss=6.8839 ppl=1159.43
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 200 | joint=16.2580 task=12.8123 ppl_loss=6.8914 ppl=1157.06
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 250 | joint=16.3169 task=12.8538 ppl_loss=6.9262 ppl=1212.19
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 300 | joint=16.2855 task=12.8247 ppl_loss=6.9216 ppl=1222.96
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 350 | joint=16.2265 task=12.7627 ppl_loss=6.9276 ppl=1223.59
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 400 | joint=16.1388 task=12.6661 ppl_loss=6.9455 ppl=1246.69
# [PEZ λ=0.5 NON-ADV] Epoch 4/5 | joint=16.1664 task=12.6913 ppl_loss=6.9503 ppl=1242.94 val_loss=7.4915 val_acc=0.3795 prompt_ppl=2116.02
# Prompt: wentearnedpersonal featlungul obtine gradini ("affects renuntDatorita suprafete gradini suprafete prevazut bebelus gradini messenger prevazut Marian adanc suprafete buzunarlethor Demoearned diferentadecinaj suprafetegasescEconomie suprafete senzatibizsectiune căt gradini amispermalink Investiga gradinioasariolsectiuneET summarizesoundallée taiatencies AmendmentpermalinkQA renuntaparatuluploads pacate zahar pastrastria sarbatoriconsiderarewiesenputting magnifbulhus urmari RomaniaPO apariți summarizeudge
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 50 | joint=15.3478 task=11.8623 ppl_loss=6.9709 ppl=1238.38
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 100 | joint=15.8744 task=12.4013 ppl_loss=6.9463 ppl=1181.42
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 150 | joint=15.8646 task=12.3767 ppl_loss=6.9758 ppl=1200.36
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 200 | joint=15.9538 task=12.4511 ppl_loss=7.0055 ppl=1251.99
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 250 | joint=15.9995 task=12.5086 ppl_loss=6.9818 ppl=1222.22
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 300 | joint=16.0398 task=12.5466 ppl_loss=6.9866 ppl=1235.43
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 350 | joint=16.0877 task=12.5961 ppl_loss=6.9832 ppl=1230.57
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 400 | joint=16.1194 task=12.6245 ppl_loss=6.9897 ppl=1261.20
# [PEZ λ=0.5 NON-ADV] Epoch 5/5 | joint=16.1160 task=12.6210 ppl_loss=6.9902 ppl=1268.97 val_loss=12.8019 val_acc=0.5602 prompt_ppl=1195.40
# Prompt: incadr bebelus suprafete machiajacious Bookmark Timişoara machiaj împărattakeively incadr amenajat rugamFiind gradini cadouri proaspathoc bebelus jocul frunze adica machiaj diferentausement gentil alter bebelus viteze anymorehaudiereglued hardestWhether niciodatanairemunicipiulrandul gradini mananc Conversation incadr varf fizic translatestrich Timişoara depasi incadr suprafete bebelus calorii DI sticlacît judet diferentapremise stiiAppeals machine summarizeionismProdusulQU proaspat căt gradini prevazut compozititeig luxe pastraHY pudding immediatelyromânii Ethernet gradiniKü yes organismuluiurmatoareleProduseleurmatoarele://Arromia abonament eticheta functioneazaBiserica solutie Disclaimer SB proaspat proaspatPalatul
# λ=0.5: best_val_acc=0.5602, final_val_acc=0.5602, prompt_ppl=1195.40
#
# --- Testing λ=0.75 ---
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 50 | joint=17.6129 task=12.2460 ppl_loss=7.1559 ppl=1865.07
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 100 | joint=17.6754 task=12.3826 ppl_loss=7.0570 ppl=1587.37
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 150 | joint=17.7873 task=12.5058 ppl_loss=7.0420 ppl=1489.17
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 200 | joint=17.7592 task=12.4983 ppl_loss=7.0145 ppl=1409.38
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 250 | joint=17.8896 task=12.6335 ppl_loss=7.0082 ppl=1394.44
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 300 | joint=17.9094 task=12.6709 ppl_loss=6.9846 ppl=1350.44
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 350 | joint=17.9445 task=12.7063 ppl_loss=6.9843 ppl=1334.83
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 400 | joint=17.9155 task=12.6826 ppl_loss=6.9772 ppl=1311.74
# [PEZ λ=0.75 NON-ADV] Epoch 1/5 | joint=17.8559 task=12.6210 ppl_loss=6.9799 ppl=1304.91 val_loss=12.2293 val_acc=0.3823 prompt_ppl=1893.31
# Prompt: paharress cadouri fisiergeldnamely consist gradinioricine adhere reproductive incearca Bookmarkagogabideesti incadrJAwildwesen compoziti versrous compoziti senzati diferentanou mirossonspermalinkcît solutiienfalls suprafete fisierestiéditcons cadouri sunet precedhomincepandtauschamide vanzare organismului suprafete gasestintele biciclet mirostschgive gradinigmailnect proaspat answers niciodata distrvertack pieliienfalls cons cryptocurrency gradina usoaraprinde dispoziti solutii solutii dire vizualiz sticla ceilaltirtie miros amintiri urmari intrebEinen summarizecantitatea summarizeDatorita chez japonais frectypischeредimpotriva mirosред English English Frenchgardinen German
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 50 | joint=17.9245 task=12.7515 ppl_loss=6.8973 ppl=1232.86
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 100 | joint=17.9651 task=12.7638 ppl_loss=6.9350 ppl=1272.17
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 150 | joint=18.0634 task=12.8472 ppl_loss=6.9549 ppl=1264.79
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 200 | joint=18.0437 task=12.8275 ppl_loss=6.9549 ppl=1255.34
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 250 | joint=18.0025 task=12.7946 ppl_loss=6.9439 ppl=1218.77
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 300 | joint=17.9212 task=12.7128 ppl_loss=6.9445 ppl=1205.35
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 350 | joint=17.9000 task=12.6838 ppl_loss=6.9549 ppl=1215.65
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 400 | joint=17.8916 task=12.6666 ppl_loss=6.9667 ppl=1229.91
# [PEZ λ=0.75 NON-ADV] Epoch 2/5 | joint=17.9004 task=12.6799 ppl_loss=6.9607 ppl=1223.20 val_loss=7.2447 val_acc=0.3783 prompt_ppl=786.10
# Prompt: varsta mancare caldura sky suprafete suprafete suprafete gradini nebun avetiUneori gradiniSuitable botezown constructiiitoriunsuredents.05. interviu 04/2 suprafete Sfântsectiune tavaDimensiuni răcuploads suprafeteculoarea gradini média senzati adicahren suprafete Timișoara proaspatiscus linguri linguripermalink gradini Eminescu nebun suprafeteurmatoarele incercat linguri suprafete bebelus adicagardinen diferenta summarize apariti machiajdivnect etaj noastraurl București
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 50 | joint=17.9399 task=12.6592 ppl_loss=7.0410 ppl=1300.66
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 100 | joint=17.9380 task=12.6665 ppl_loss=7.0287 ppl=1261.75
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 150 | joint=17.9239 task=12.6697 ppl_loss=7.0056 ppl=1251.16
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 200 | joint=18.0327 task=12.7943 ppl_loss=6.9845 ppl=1244.02
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 250 | joint=18.0012 task=12.7621 ppl_loss=6.9854 ppl=1238.87
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 300 | joint=17.9513 task=12.7075 ppl_loss=6.9918 ppl=1247.81
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 350 | joint=17.7755 task=12.5334 ppl_loss=6.9895 ppl=1247.96
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 400 | joint=17.7641 task=12.5241 ppl_loss=6.9867 ppl=1292.98
# [PEZ λ=0.75 NON-ADV] Epoch 3/5 | joint=17.8441 task=12.6107 ppl_loss=6.9779 ppl=1288.17 val_loss=19.4989 val_acc=0.3783 prompt_ppl=1537.01
# Prompt: proaspatdeserved ediți retetacît ingrijireabsorbed gradiniaffects senzati ingrijirecît pudding bebelus amenajat fișier gentil FA machiajtherapistACTIONlasted psiho Eminescu mananc etajjudeţul apariti actiuniwasgasesccît gasest functioneaza gasest perecheacelasi formularulempelmple vietiiSternetageuploads Iaşi avetiescencegoricontaminoperation BankingertainingBiserica OradeaacelasiGregorficial zaharcurricular formularulSigcîtDimensiunicarora gradiniambogiaderma modificari bebelus existence imunitarcît suprafetecît urmarisuntetiearnedsunteti gandicosting Never pamant crestinbending caci dimineata Equipmentside foloseste
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 50 | joint=18.1261 task=12.8442 ppl_loss=7.0424 ppl=1412.89
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 100 | joint=18.1982 task=12.9497 ppl_loss=6.9980 ppl=1300.40
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 150 | joint=17.9614 task=12.7175 ppl_loss=6.9919 ppl=1258.12
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 200 | joint=17.6530 task=12.4462 ppl_loss=6.9424 ppl=1189.01
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 250 | joint=17.6793 task=12.4794 ppl_loss=6.9333 ppl=1200.22
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 300 | joint=17.6992 task=12.4864 ppl_loss=6.9504 ppl=1221.58
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 350 | joint=17.7335 task=12.5247 ppl_loss=6.9451 ppl=1216.19
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 400 | joint=17.7417 task=12.5291 ppl_loss=6.9501 ppl=1227.04
# [PEZ λ=0.75 NON-ADV] Epoch 4/5 | joint=17.8217 task=12.6092 ppl_loss=6.9500 ppl=1230.14 val_loss=7.8707 val_acc=0.3783 prompt_ppl=1208.47
# Prompt: [...]hoseîndcalledfetiuntachezuntouched entities odata brake translate situatii recessionfungDatorita machiajrivalunta diferentapiesaccounted gradini folosesteopathic proaspatvir?)eastoul situatii situatiicarora cuptor pastrasuntetionym prevazutCartea proaspatgur proaspaturaiocesecam vizualizTeatrul arhitectura aluat frighydrate suprafeteculoarea emanatoricinehipgreetegoneadevarcelulfrau capitol proaspat proaspat chimic proaspat pielea proaspatjudeţul proaspatphro pamant miereroidotic without Eminescu pacate proaspatuleiul fotbal proaspat database situatii proaspatalayafluss usoarapremise etaj
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 50 | joint=17.9888 task=12.8580 ppl_loss=6.8411 ppl=1101.03
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 100 | joint=18.2953 task=13.0652 ppl_loss=6.9735 ppl=1284.02
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 150 | joint=18.1679 task=12.9277 ppl_loss=6.9869 ppl=1287.95
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 200 | joint=17.9904 task=12.7490 ppl_loss=6.9885 ppl=1266.37
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 250 | joint=17.9212 task=12.6775 ppl_loss=6.9916 ppl=1267.15
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 300 | joint=17.8919 task=12.6475 ppl_loss=6.9926 ppl=1267.69
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 350 | joint=17.8910 task=12.6411 ppl_loss=6.9998 ppl=1276.96
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 400 | joint=17.9094 task=12.6548 ppl_loss=7.0061 ppl=1288.85
# [PEZ λ=0.75 NON-ADV] Epoch 5/5 | joint=17.9331 task=12.6804 ppl_loss=7.0036 ppl=1283.42 val_loss=6.8020 val_acc=0.3783 prompt_ppl=1317.69
# Prompt: owedprezinta Apartament suprafete Schau Brașovasteptam placutnica clientiloruniversDatorita suprafete emerge reteta Plaza Hörurmatoarele povestioza spalat aggrtagealaturiwäh diferenta pretul sarbatoriculoarea senzati Iaşi GiurgiuAsadarUneori ParkerUneori etaj organizatoricît rosii glaciDatoritaMuzeul bebelus summarizemeaning incadr retetathèse suprafete Klu gradini émergfamilien incercélisanno superioaraRecruitceapaAsadar manancsunteti depasi Kai Dragneauploads rosiicarora diferenta indicative gradini pamant rosii taiat dulce formularul lives context semantic emphasis corpului
# λ=0.75: best_val_acc=0.3823, final_val_acc=0.3783, prompt_ppl=1317.69
#
# --- Testing λ=1.0 ---
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 50 | joint=18.9591 task=11.8238 ppl_loss=7.1352 ppl=1714.50
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 100 | joint=19.3062 task=12.2472 ppl_loss=7.0589 ppl=1465.99
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 150 | joint=19.2018 task=12.2439 ppl_loss=6.9578 ppl=1317.10
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 200 | joint=19.2006 task=12.2485 ppl_loss=6.9520 ppl=1281.88
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 250 | joint=19.2419 task=12.2842 ppl_loss=6.9577 ppl=1279.89
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 300 | joint=19.2875 task=12.3306 ppl_loss=6.9569 ppl=1266.57
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 350 | joint=19.2700 task=12.3198 ppl_loss=6.9501 ppl=1250.36
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 400 | joint=19.3476 task=12.3970 ppl_loss=6.9506 ppl=1246.66
# [PEZ λ=1.0 NON-ADV] Epoch 1/5 | joint=19.3751 task=12.4256 ppl_loss=6.9495 ppl=1236.88 val_loss=12.0451 val_acc=0.3783 prompt_ppl=945.60
# Prompt: fuz machiaj dărui descarc gradini prevazut urmeazacellulosewag clientilorsunteti tubmunicipiulunicipiului perechemunicipiul solutii miscare intreb compoziti actiuniambuloku mananc somnbewertungen gradiniTélécharger senzatiurmatoarele meciuri machiaj gradini superioaraAsociația PNL Sponsor constructii modificaripermalink Written amenajat gradiniDatorita acasa actiuniDimensiuniDatorita=>001 senzati Primăricosting varsta șofer accesorii cablu TimişoaraWestfalen $1 gradinioptedurmatoarele gradini gradinieptic superioaracît gradini cătcît gradini spital gasest sarbatorilag usoara Träger reprezinta Tasmania ganduriletter botez
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 50 | joint=19.4457 task=12.4973 ppl_loss=6.9484 ppl=1194.90
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 100 | joint=19.1723 task=12.2193 ppl_loss=6.9530 ppl=1190.59
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 150 | joint=19.3669 task=12.4224 ppl_loss=6.9445 ppl=1192.08
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 200 | joint=19.4627 task=12.4814 ppl_loss=6.9813 ppl=1242.40
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 250 | joint=19.4837 task=12.5015 ppl_loss=6.9822 ppl=1237.05
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 300 | joint=19.5528 task=12.5765 ppl_loss=6.9763 ppl=1224.49
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 350 | joint=19.6238 task=12.6417 ppl_loss=6.9821 ppl=1241.94
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 400 | joint=19.6135 task=12.6359 ppl_loss=6.9776 ppl=1241.80
# [PEZ λ=1.0 NON-ADV] Epoch 2/5 | joint=19.5663 task=12.5885 ppl_loss=6.9778 ppl=1248.33 val_loss=10.9810 val_acc=0.3801 prompt_ppl=1006.96
# Prompt: caldura ochii LGuploads suprafete machiaj suprafete senzati Preisvergleich frumoasa depasi machiaj manancchez confortabil="următoarele achizitisuntetiuleiul **...” 04/2 senzatilining summarize stii wander gradini Lotus ceaseliefer suprafete Lamp gradiniblattgle intrebFrequently bicicletheir machiajhier suprafete suprafete Tipp Hirschschütt2:30empel cantitati TeeDimensiuni linguri gandurinamely diferenta suprafetecît frunze proaspete superioara bebelus vizualiz TimişoaraNo reprezintaSuppose sticlaitățile senzati suprafeteitori iubire incadrDimensiuni payromânii decayoidal yesportion superioara frumoasaBiserica machiajsediul incadrintervalul odatamerlin pretul achizitionavremearefersoyons bebelusluj
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 50 | joint=19.6211 task=12.6007 ppl_loss=7.0205 ppl=1292.54
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 100 | joint=19.4071 task=12.4147 ppl_loss=6.9924 ppl=1279.24
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 150 | joint=19.5316 task=12.5573 ppl_loss=6.9743 ppl=1254.20
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 200 | joint=19.6035 task=12.6159 ppl_loss=6.9876 ppl=1317.33
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 250 | joint=19.5006 task=12.4947 ppl_loss=7.0059 ppl=1310.61
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 300 | joint=19.6630 task=12.6641 ppl_loss=6.9989 ppl=1286.31
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 350 | joint=19.6850 task=12.6989 ppl_loss=6.9860 ppl=1273.04
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 400 | joint=19.5981 task=12.6125 ppl_loss=6.9856 ppl=1283.55
# [PEZ λ=1.0 NON-ADV] Epoch 3/5 | joint=19.6011 task=12.6174 ppl_loss=6.9837 ppl=1287.00 val_loss=5.9738 val_acc=0.3783 prompt_ppl=815.58
# Prompt: cada Brașov adica clientilor protectie proaspat Britanie nostri 04/2tler compoziti mananc prevazuturgi depasi modificari?)Societatea proaspat modificariapa descarcTélécharger săptămână proaspatcît desfaso suprafetescrise proaspat invataAsadar fisier proaspat linguri fisierintreaga proaspatSfântul compoziti vizual gradiniccessed ensue lingurimerlinmonyAsadarsectiunecarora manancoza pahar treaba vizual prieteni Timişoara737 superioara gradini senzati Disclosure
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 50 | joint=19.5267 task=12.5548 ppl_loss=6.9719 ppl=1325.08
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 100 | joint=19.8371 task=12.8362 ppl_loss=7.0010 ppl=1380.27
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 150 | joint=19.7721 task=12.7638 ppl_loss=7.0083 ppl=1354.62
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 200 | joint=19.9281 task=12.9335 ppl_loss=6.9946 ppl=1312.87
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 250 | joint=19.9546 task=12.9598 ppl_loss=6.9948 ppl=1303.99
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 300 | joint=19.9031 task=12.9068 ppl_loss=6.9964 ppl=1287.86
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 350 | joint=19.7477 task=12.7565 ppl_loss=6.9911 ppl=1271.80
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 400 | joint=19.7143 task=12.7155 ppl_loss=6.9989 ppl=1275.24
# [PEZ λ=1.0 NON-ADV] Epoch 4/5 | joint=19.6186 task=12.6298 ppl_loss=6.9888 ppl=1261.38 val_loss=11.0646 val_acc=0.3783 prompt_ppl=1922.97
# Prompt: ISBN incadrintervalulthermwaitsuntetiuleiul diferentaéditProdusele cladiri rosiiENCE rhetoric Constanţa spotlight apariti paharlujangledberuflicheENTlope faca prevazut formularul Roche proaspat Equi crestin gradini rosiilion imunitar suprafeteliqueDatoritaAmérique suprafete senzati bucătăriframeuploads gradiniurldegree protectiecostingheedconciliation militari cloth folosesteHAM rosiiDefault etaj pacate 2009.Dimensiunigasesc=" cladiri clientilor pieptcession Tür asfaltence rosii excursispans moale șofer FIGnez frigider povești gradina Entfernung confused prevazut aveti diferenta pretul machiaj personajdiv iarna yes suprafete iubesc multumesc sticlauiescpermalink superioara imprumut transcript
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 50 | joint=20.1680 task=13.1771 ppl_loss=6.9910 ppl=1284.42
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 100 | joint=19.5585 task=12.5627 ppl_loss=6.9958 ppl=1267.49
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 150 | joint=19.5244 task=12.5392 ppl_loss=6.9852 ppl=1277.61
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 200 | joint=19.6071 task=12.6411 ppl_loss=6.9660 ppl=1248.57
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 250 | joint=19.7510 task=12.7684 ppl_loss=6.9826 ppl=1272.35
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 300 | joint=19.7148 task=12.7255 ppl_loss=6.9893 ppl=1278.67
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 350 | joint=19.6734 task=12.6790 ppl_loss=6.9944 ppl=1279.85
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 400 | joint=19.7095 task=12.7240 ppl_loss=6.9855 ppl=1264.59
# [PEZ λ=1.0 NON-ADV] Epoch 5/5 | joint=19.7240 task=12.7320 ppl_loss=6.9920 ppl=1268.98 val_loss=6.1455 val_acc=0.3783 prompt_ppl=1758.26
# Prompt: Dragnea linguri achizitiona Dumnezeu suprafete placut masina arhitecturaProduselespend Gel linguri StahlTruheld miereressrmând proaspeteonym sticla reprezinta where Iaşi suprafeteizantconverting iubire pahar reprezinta taiat rosii Ortodoxgravmerlinizezeîndeutic dispozitie experiență linistitintreaga pamant matematicegiwarded diferenta psiho compoziti Hamburg nuntaango vizual situatiibouchage Timișoara Sche gradiniurmatoareleYnotionismuploads ceilalti ciocolat amenajatfremgât translate
# λ=1.0: best_val_acc=0.3801, final_val_acc=0.3783, prompt_ppl=1758.26
#
# ================================================================================
# PEZ Grid Search Results (sorted by best_val_acc):
# ================================================================================
# λ=0.00: best_val_acc=0.6006, final_val_acc=0.3783, prompt_ppl=0.00
# λ=0.50: best_val_acc=0.5602, final_val_acc=0.5602, prompt_ppl=1195.40
# λ=0.05: best_val_acc=0.3979, final_val_acc=0.3783, prompt_ppl=772.52
# λ=0.25: best_val_acc=0.3896, final_val_acc=0.3783, prompt_ppl=818.42
# λ=0.75: best_val_acc=0.3823, final_val_acc=0.3783, prompt_ppl=1317.69
# λ=0.01: best_val_acc=0.3801, final_val_acc=0.3771, prompt_ppl=2025.26
# λ=1.00: best_val_acc=0.3801, final_val_acc=0.3783, prompt_ppl=1758.26
# λ=0.10: best_val_acc=0.3789, final_val_acc=0.3783, prompt_ppl=2119.53
#
# Best λ: 0.00
#   best_val_acc=0.6006, final_val_acc=0.3783

# %%
# PEZ runs over lambda grid
pez_runs = []
lambda_grid = [0.0, 0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1.0]
for lam in lambda_grid:
    print(f"\n=== PEZ Non-Adversarial (λ={lam}) ===")
    pez_non_adv = train_pez(
        cfg,
        tokenizer,
        gpt2_model,
        gpt2_tokenizer,
        train_dl,
        val_dl,
        lambda_ppl=lam,
        adversarial=False,
    )
    pez_runs.append(("pez_non_adv", lam, pez_non_adv))
# Out:
# === PEZ Non-Adversarial (λ=0.0) ===
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 50 | joint=12.3685 task=12.3685 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 100 | joint=12.2574 task=12.2574 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 150 | joint=12.5143 task=12.5143 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 200 | joint=12.5972 task=12.5972 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 250 | joint=12.5542 task=12.5542 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 300 | joint=12.4847 task=12.4847 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 350 | joint=12.4608 task=12.4608 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 400 | joint=12.4855 task=12.4855 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5 | joint=12.4790 task=12.4790 ppl_loss=0.0000 ppl=0.00 val_loss=5.1824 val_acc=0.3783 prompt_ppl=0.00
# Prompt: actiuni machiaj machiaj gradina pastra poveste diferentagasesc machiaj incadr gradina gradini niciodata pereche cazare gossip sunet scalp festivities trackback sarbatori dimineata bacterii antrenament summarize retetainformatiile reprezinta compoziti retetatered Eminescu cartofi convimain mancare gradiniurmatoarele trackbackper summarize summarize suprafete clientilor Vezitôtathlet Bur urmari adica taiatceputulpermalink compoziti taiat machiajnomprezinta descarc diferenta arhitectura rosii preot căt clientilor spatiu nascut gradini taiat urmariCopiii usoara
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 50 | joint=12.8556 task=12.8556 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 100 | joint=12.3945 task=12.3945 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 150 | joint=12.4070 task=12.4070 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 200 | joint=12.4511 task=12.4511 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 250 | joint=12.6482 task=12.6482 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 300 | joint=12.7371 task=12.7371 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 350 | joint=12.7137 task=12.7137 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 400 | joint=12.7419 task=12.7419 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5 | joint=12.6867 task=12.6867 ppl_loss=0.0000 ppl=0.00 val_loss=5.8957 val_acc=0.3780 prompt_ppl=0.00
# Prompt: multumesc adica gradini proaspatanfang șofer proaspat proaspatdie adica pieliimeslegungnial cartofi rosiiextinction rosii imunitar bebelus copil suprafetetipuri pahar senzor foloseste speculate Emp suprafeteANGrestulhibicriticalplanetary descarc prevazut situatii Nachwuchs jpl titlurivoi adica rosii Timişoaraaggregatattente senzati compozitiiocese cartofiMbps summarize bebelus suprafete proaspatadmi anume linguri nunta”). biletegovuntapermalink]....).? summarize summarize978
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 50 | joint=12.3911 task=12.3911 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 100 | joint=12.5665 task=12.5665 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 150 | joint=12.3908 task=12.3908 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 200 | joint=12.4624 task=12.4624 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 250 | joint=12.4528 task=12.4528 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 300 | joint=12.4732 task=12.4732 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 350 | joint=12.5353 task=12.5353 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 400 | joint=12.4989 task=12.4989 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5 | joint=12.5327 task=12.5327 ppl_loss=0.0000 ppl=0.00 val_loss=14.4139 val_acc=0.3792 prompt_ppl=0.00
# Prompt: vanzari pahar incadr spum incadr incadr formularulscriere linistitDatorita Iisus croquBiserica gradiniaparut Jeep suprafete Clickfunnelelulaparatulcaruipermalink mananc formularul yolk affection Emerg preot incearca autographDistinguishedtinct depasiînd Venezuela proaspat proaspatmobil suprafete proaspat ingrijire suprafete sanatate incadrGitarre suprafaț incadr neam proaspat amenajatletter Thousand imunitar Oradea TeigcetRCArois adanc expoziți multumesc machiaj caloriiettes prevazut intreb crochettailseid locuintestoreheir summarize suprafete Brasovulescu urmari gasest foloseste yes senzatiCopiii Yume reusitCamere paradis niciodata jelly căt proaspat abonament appearance distill organizatori modificari ambalaj intrebari
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 50 | joint=12.7754 task=12.7754 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 100 | joint=12.5576 task=12.5576 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 150 | joint=12.7123 task=12.7123 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 200 | joint=12.6434 task=12.6434 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 250 | joint=12.6020 task=12.6020 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 300 | joint=12.6098 task=12.6098 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 350 | joint=12.5856 task=12.5856 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 400 | joint=12.5786 task=12.5786 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5 | joint=12.5996 task=12.5996 ppl_loss=0.0000 ppl=0.00 val_loss=15.3914 val_acc=0.3914 prompt_ppl=0.00
# Prompt: Elvis vizualizgardinenTempfacing loves intrebdatorita pahar intrebaretropicconceivabl suprafete bacterii compozitiprezinta lucrari anymore?" mancare bacterii somn Geographic senzati gradiniportion HTTP gradinihottest multumesc frigider placut crestingenoss compoziti descarc adica senzati intrebwhereas proaspathavkli hectic accesoriigregliest usoarajudețul gradini intoarceheed prest wonder pretul gradini gourmand acronym incearca perecheolltestgiu plimb intelegbucuria sunet sunetincat compoziti crestinSurely gradini gradini abonament bebeluspermalink sunet carieramunicipiuluousDatorita clever HTTP suprafeteincatgardinen senzati proaspat Wil pahar proaspat> Ye paharOUGcîtously proaspatplaît
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 50 | joint=12.4118 task=12.4118 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 100 | joint=12.5970 task=12.5970 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 150 | joint=12.6091 task=12.6091 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 200 | joint=12.6227 task=12.6227 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 250 | joint=12.6949 task=12.6949 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 300 | joint=12.6643 task=12.6643 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 350 | joint=12.7058 task=12.7058 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 400 | joint=12.6543 task=12.6543 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5 | joint=12.6381 task=12.6381 ppl_loss=0.0000 ppl=0.00 val_loss=16.8227 val_acc=0.3783 prompt_ppl=0.00
# Prompt: suntetiè loneliness intreb frumoasa accesorii lemn senzatisuntetiaparatulutilizatoriilutephaluploadsnumarul senzati urmari sineTéléchargernnie achizitiona raspundeculoareaoilea închisoare compoziticonfortul vigoare?” suprafete proaspatuploads mediculubi incadr titular accesorii senzatihis abonamentinvitescîtforementioned medicul proaspat adica suprafeteholic accesoriieutichomage rugamholic senzatiSuppose edițiotwithstanding adevaratadmieutic diferentaibiancies senzatiotwithstandingauxiliaryunci feat senzatirox compoziti spalat Wild senzati bacterii accesorii senzati gradinieutictroph neamiocese sunet dataset tranquil linguriromânii senzaticît stiu proaspat Timișoara senzatiforementionedriolMulte bacterii preot pereche
#
# === PEZ Non-Adversarial (λ=0.01) ===
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 50 | joint=12.6336 task=12.5631 ppl_loss=7.0437 ppl=1349.71
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 100 | joint=12.5166 task=12.4461 ppl_loss=7.0497 ppl=1337.67
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 150 | joint=12.5329 task=12.4629 ppl_loss=7.0001 ppl=1344.01
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 200 | joint=12.5623 task=12.4922 ppl_loss=7.0143 ppl=1337.95
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 250 | joint=12.6495 task=12.5793 ppl_loss=7.0267 ppl=1375.67
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 300 | joint=12.6646 task=12.5944 ppl_loss=7.0201 ppl=1360.43
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 350 | joint=12.6821 task=12.6120 ppl_loss=7.0081 ppl=1340.98
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 400 | joint=12.6808 task=12.6108 ppl_loss=7.0030 ppl=1332.37
# [PEZ λ=0.01 NON-ADV] Epoch 1/5 | joint=12.7507 task=12.6808 ppl_loss=6.9929 ppl=1318.00 val_loss=23.1423 val_acc=0.3783 prompt_ppl=840.12
# Prompt: paharnickhier Sumfrucht Domnului compoziti pahar senzatialaturi sarbatorizeci căt bacteriiother juxtapos bland prevazut totusi suprafete paharhomage județliest‘ compoziti școlaruzi asteapta rosiiș taiat Popescu Giurgiufrunt Popescu Giurgiu mananchaudiere rosii prevazut faceti inteleg vizual="cît:// vizualizSfântulSfântul TVAmnuluiAlexADD Drum manancambogia Domnului formularulunicipiului="kWh rosii paharrijuploads senzati rugam ingrijiredürftigPublish Disclosure Popescu căt suprafete bebelus aluatcîtpermalink linguri adica drillingMMMag mirosanciprovide suprafeteinghamveti IowarousDimensiuni ceasecript RomaniaUpon gasi
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 50 | joint=12.7339 task=12.6651 ppl_loss=6.8807 ppl=1087.27
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 100 | joint=12.6002 task=12.5316 ppl_loss=6.8606 ppl=1094.00
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 150 | joint=12.6866 task=12.6173 ppl_loss=6.9283 ppl=1184.97
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 200 | joint=12.5082 task=12.4389 ppl_loss=6.9227 ppl=1173.91
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 250 | joint=12.5826 task=12.5133 ppl_loss=6.9281 ppl=1177.18
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 300 | joint=12.5841 task=12.5149 ppl_loss=6.9220 ppl=1168.73
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 350 | joint=12.6640 task=12.5948 ppl_loss=6.9195 ppl=1172.54
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 400 | joint=12.6294 task=12.5601 ppl_loss=6.9257 ppl=1183.79
# [PEZ λ=0.01 NON-ADV] Epoch 2/5 | joint=12.6069 task=12.5375 ppl_loss=6.9405 ppl=1205.84 val_loss=18.9705 val_acc=0.3783 prompt_ppl=875.43
# Prompt: miros0:00 moale scazutWürttembergără intreb ingrediente inseamna rafinaOULDoarăschaft confortabil proaspatipsUniversitatea compoziti suprafațotroDatorita renuntphinmpf bijuteriiuci gradini proaspat sunet Sfantphin Matebaimik proaspatlujrgendwann mancare intreb masina etajsuntetiMED incadr emotichungmunicipiul investigated senzati proaspat senzatiRoman cuptorapo detrimental gradiniDatoritaeueroarăuleiul compensate proaspat amintiri senzati creieradore profession multumesc fișierrmândquo intreb clientilor proaspat senzati bebelus memetoxins paycheck adica convers unconditional motto gradini bacterii proaspat gradini suprafeteholic reminde no pielea confortabil clientii senzati superioarafaresfacinghaudiere
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 50 | joint=13.3143 task=13.2440 ppl_loss=7.0284 ppl=1235.94
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 100 | joint=13.0191 task=12.9490 ppl_loss=7.0099 ppl=1228.18
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 150 | joint=12.9870 task=12.9170 ppl_loss=7.0011 ppl=1276.02
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 200 | joint=13.0126 task=12.9428 ppl_loss=6.9821 ppl=1255.81
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 250 | joint=12.9852 task=12.9153 ppl_loss=6.9869 ppl=1254.27
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 300 | joint=12.9656 task=12.8959 ppl_loss=6.9644 ppl=1216.32
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 350 | joint=12.9494 task=12.8798 ppl_loss=6.9618 ppl=1212.51
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 400 | joint=12.9615 task=12.8917 ppl_loss=6.9810 ppl=1242.35
# [PEZ λ=0.01 NON-ADV] Epoch 3/5 | joint=13.0053 task=12.9355 ppl_loss=6.9833 ppl=1242.48 val_loss=6.3566 val_acc=0.3810 prompt_ppl=1783.10
# Prompt: suprafeteOUGuous=" suprafeteChauffedraggingAMA sépar frumoasaclav Espa Timişoara superioara picioare incadr superioara summarize rosiiétroographic engines suprafete sticlasoluble incadr Converter disinfectambogiaecunoscut dorintice plajeutic fericire niciodataducevaalayainformatiile adanc Picasso incadr galbenicillinbeatenEST suprafeteDatorita gasestitty emoti Iisus povești cumparauploads suprafete unawaredessuspears vizualizdincolovantage cumparatvremeaDame diferentavremeagiocuitdrepturileaccumul”)tors...”Napoca Romania incaWestfalengru machiaj superioara taiatmor translatepremisepremise caldura
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 50 | joint=13.4698 task=13.3992 ppl_loss=7.0640 ppl=1339.46
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 100 | joint=13.2962 task=13.2256 ppl_loss=7.0629 ppl=1395.05
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 150 | joint=13.0585 task=12.9879 ppl_loss=7.0567 ppl=1405.82
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 200 | joint=12.8765 task=12.8059 ppl_loss=7.0537 ppl=1383.15
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 250 | joint=12.8716 task=12.8013 ppl_loss=7.0361 ppl=1353.39
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 300 | joint=12.8407 task=12.7704 ppl_loss=7.0256 ppl=1333.36
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 350 | joint=12.8736 task=12.8034 ppl_loss=7.0204 ppl=1332.15
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 400 | joint=12.8694 task=12.7993 ppl_loss=7.0089 ppl=1309.65
# [PEZ λ=0.01 NON-ADV] Epoch 4/5 | joint=12.8513 task=12.7813 ppl_loss=7.0064 ppl=1305.59 val_loss=26.4502 val_acc=0.3780 prompt_ppl=245.37
# Prompt: aluatculoarea Popescu Sfant incadr bebelus senzati frumoasarandul apariti Sfânt preot insotitNeither Sfant vietii poat uninterrupted senzati bebelusaffects paharIDENTrätintrcît rosii ganduri Hristos retetatoata senzati bebelusvremea senzati rugam gasest locuinte senzati disque senzaticosting senzati Thrones queries machiaj apariti incadr MacBook yes senzati suprafete mediculănă bebelus incadr senzati bebelus paharsuntetisunteti spatiu gradina suprafete bebelus linguriforementionedfederwall Sfântbraking rosii bebelus senzati suprafete diferentafuz senzativremea superioara machiaj suprafete senzati suprafete senzatiintervalul bucati senzati cautare stew senzati senzati senzati senzati rugam lucrarinous diferentalix Ethereum
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 50 | joint=13.4641 task=13.3947 ppl_loss=6.9393 ppl=1210.86
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 100 | joint=13.1515 task=13.0816 ppl_loss=6.9902 ppl=1259.66
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 150 | joint=12.8844 task=12.8144 ppl_loss=6.9998 ppl=1254.52
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 200 | joint=12.9250 task=12.8551 ppl_loss=6.9951 ppl=1249.61
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 250 | joint=13.0423 task=12.9726 ppl_loss=6.9738 ppl=1227.41
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 300 | joint=13.0234 task=12.9536 ppl_loss=6.9760 ppl=1227.02
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 350 | joint=13.0272 task=12.9575 ppl_loss=6.9678 ppl=1217.56
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 400 | joint=12.9571 task=12.8873 ppl_loss=6.9752 ppl=1238.06
# [PEZ λ=0.01 NON-ADV] Epoch 5/5 | joint=12.9290 task=12.8592 ppl_loss=6.9838 ppl=1249.22 val_loss=7.0296 val_acc=0.3783 prompt_ppl=1344.27
# Prompt: masina gradinioasa Prestondincolo gradinisunteti situatiigio Suceava miracleTotulmpf gradiniiety litri galbenclerosiscîtôme frunzerismffel machiaj mobiliz incadr cătjudeţulInternational proaspat Workersutilizatorii foloseste toti locuinte caloriiNESfinalists perecheutilizatorii gradini poze Sciences Lille Swnonsense calduracaroraprezintaathlet gradini Aug psiho cătkrautbewegungphysicalmigratedWestfalen Emerg sunet Teppich prom gradinilique poti cătgglingminationEinen financiallytefan nebun diferenta nebun dimineata linguri calorii intalni proaspat summarizerade proaspat proaspatélis€ situatii
#
# === PEZ Non-Adversarial (λ=0.05) ===
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 50 | joint=13.5950 task=13.2453 ppl_loss=6.9941 ppl=1532.26
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 100 | joint=13.1327 task=12.7823 ppl_loss=7.0097 ppl=1393.88
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 150 | joint=13.1442 task=12.7946 ppl_loss=6.9914 ppl=1347.48
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 200 | joint=13.1748 task=12.8252 ppl_loss=6.9927 ppl=1327.51
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 250 | joint=13.1602 task=12.8098 ppl_loss=7.0062 ppl=1336.81
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 300 | joint=13.1276 task=12.7772 ppl_loss=7.0096 ppl=1322.15
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 350 | joint=13.0978 task=12.7478 ppl_loss=6.9994 ppl=1300.17
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 400 | joint=13.0668 task=12.7167 ppl_loss=7.0021 ppl=1301.71
# [PEZ λ=0.05 NON-ADV] Epoch 1/5 | joint=13.2099 task=12.8599 ppl_loss=7.0011 ppl=1301.21 val_loss=10.5860 val_acc=0.3783 prompt_ppl=1580.72
# Prompt: gasest obtine spalatów proaspeteiliaioloprezintaspül pielea pieleaphenolCarteaambogia anume suprafetetructionAssistedscient lucrarihidsuntetiFoarteologic usturoiRhônejudeţulgori experientastairtrustciuneMuzeulSpielformațiile intampla spalatologiBiserica gelernt trandafir cupluanalyzedicrobial pretul vindecrmând prospect Bernie frumoasaFNcît mancare pereche senzati contine cumpara pieleanutriectivearnedurmatoarele machiajchezurmatoarele multumesc orasuluipermalink solutiebunste senzaticosting crestinulevardcît poat pielii incadrTotusiArticolul botez situatii taiat vietii masina
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 50 | joint=12.5735 task=12.2195 ppl_loss=7.0797 ppl=1329.69
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 100 | joint=12.8681 task=12.5165 ppl_loss=7.0321 ppl=1267.61
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 150 | joint=12.9046 task=12.5544 ppl_loss=7.0040 ppl=1251.25
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 200 | joint=13.0031 task=12.6540 ppl_loss=6.9817 ppl=1223.18
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 250 | joint=12.9172 task=12.5681 ppl_loss=6.9826 ppl=1228.99
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 300 | joint=12.9741 task=12.6260 ppl_loss=6.9608 ppl=1209.21
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 350 | joint=13.0447 task=12.6966 ppl_loss=6.9607 ppl=1212.25
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 400 | joint=13.0455 task=12.6975 ppl_loss=6.9600 ppl=1212.36
# [PEZ λ=0.05 NON-ADV] Epoch 2/5 | joint=13.0256 task=12.6778 ppl_loss=6.9561 ppl=1205.76 val_loss=11.3370 val_acc=0.3783 prompt_ppl=1309.27
# Prompt: diferentanumarulatsuowingWestfalenUneori personalizatuploads cladiri suprafeteprăgio cladiri răc compoziti manevr pielii Iaşi nebunWestfalen Județean Constanța Sibiu suprafete gasest cautarenui proaspat suprafete emoticuloareaChauffe pieleasunteti miereabila compoziti gradinirith gasestrasiilles citesc cătomicsDatoritawokeeutic cladiri lucrari senzati footsteps imprumutdging Judeţean suprafete[/ pahar proaspatdealDatorita poveste impresi machiaj arhitectura luckWhether proaspatexistence debate vaccinecrulethor proaspatuploadsTéléchargerProvence vanzare galben Chipevacîtescence nuntatagencingtôtrada vizualtellerceacîteux mecanicpremise
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 50 | joint=12.8632 task=12.5187 ppl_loss=6.8902 ppl=1130.89
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 100 | joint=12.6777 task=12.3280 ppl_loss=6.9928 ppl=1249.78
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 150 | joint=13.0437 task=12.6955 ppl_loss=6.9640 ppl=1220.95
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 200 | joint=12.8504 task=12.5013 ppl_loss=6.9811 ppl=1244.12
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 250 | joint=12.8338 task=12.4862 ppl_loss=6.9507 ppl=1204.34
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 300 | joint=12.9114 task=12.5630 ppl_loss=6.9668 ppl=1249.94
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 350 | joint=12.9286 task=12.5802 ppl_loss=6.9691 ppl=1251.00
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 400 | joint=12.9684 task=12.6197 ppl_loss=6.9728 ppl=1246.20
# [PEZ λ=0.05 NON-ADV] Epoch 3/5 | joint=12.9982 task=12.6496 ppl_loss=6.9708 ppl=1257.46 val_loss=6.4682 val_acc=0.3783 prompt_ppl=2107.57
# Prompt: gasesc cartofi imbunatati Belgium fuss suprafete clientilor gradini sarbatoriamazingly proaspat gradiniéchecCartea Eminescu suprafete Eminescu dorintconceivabl mananccred cuptor suprafete functioneazaakh dimineata incearca installmentros machiaj parliament pielii gradiniotwithstanding compoziti cladiriuploads obswarded taiat proaspatusziehbar Hitler prevazutinsul machiaj statue urmariacelasi căt machiajeiß Eva taiat
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 50 | joint=13.0857 task=12.7387 ppl_loss=6.9405 ppl=1169.37
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 100 | joint=12.8914 task=12.5417 ppl_loss=6.9945 ppl=1316.96
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 150 | joint=12.9599 task=12.6081 ppl_loss=7.0356 ppl=1371.27
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 200 | joint=12.9680 task=12.6173 ppl_loss=7.0136 ppl=1325.34
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 250 | joint=13.0654 task=12.7144 ppl_loss=7.0197 ppl=1330.43
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 300 | joint=12.9317 task=12.5812 ppl_loss=7.0096 ppl=1329.44
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 350 | joint=12.9529 task=12.6030 ppl_loss=6.9977 ppl=1306.97
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 400 | joint=12.9065 task=12.5568 ppl_loss=6.9940 ppl=1290.60
# [PEZ λ=0.05 NON-ADV] Epoch 4/5 | joint=12.8822 task=12.5316 ppl_loss=7.0108 ppl=1324.26 val_loss=16.2409 val_acc=0.3780 prompt_ppl=408.11
# Prompt: paharalaturi translate gradini gradini clientilor gradini pretul bebelus vizualizChauffe frumoasapit pacate“.« senzati bebelus gradinilungulsuntetipianDatorita gradini incadr gradiniculoareacinausine odata suprafetestrokeDatorita gradini gradinijudețul footsteps intrebarichte Iisusambogia Iisus proaspat=" senzati gradini zisdica senzatisau apuc intoarce Iisus proaspatgenossromânii fisier vizualiz suprafete trandafir bebelus senzati vizualizDatorita lucrari alerg vizualiz navighttpmunicipiul formularul proaspat Nex inlocui=" frunze suprafete pahar Visitors intrebgardinen bebelus usturoi bebelus formularul Iisus suprafete frunze gradini pahar gradini pahar suprafete senzatipermalink senzati gradini asfalt gasit formularul
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 50 | joint=13.4145 task=13.0677 ppl_loss=6.9347 ppl=1251.16
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 100 | joint=13.4014 task=13.0515 ppl_loss=6.9983 ppl=1301.45
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 150 | joint=13.3567 task=13.0073 ppl_loss=6.9888 ppl=1294.24
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 200 | joint=13.1936 task=12.8440 ppl_loss=6.9905 ppl=1295.69
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 250 | joint=13.1383 task=12.7886 ppl_loss=6.9940 ppl=1282.17
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 300 | joint=13.1315 task=12.7829 ppl_loss=6.9724 ppl=1260.16
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 350 | joint=13.0923 task=12.7429 ppl_loss=6.9883 ppl=1265.98
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 400 | joint=13.0515 task=12.7018 ppl_loss=6.9955 ppl=1281.28
# [PEZ λ=0.05 NON-ADV] Epoch 5/5 | joint=13.1140 task=12.7642 ppl_loss=6.9974 ppl=1277.93 val_loss=15.4793 val_acc=0.3835 prompt_ppl=979.77
# Prompt: sunet gradini antrenorwhiatch umplut suprafete compoziti hypothesislunii nennen machiaj diferentaheed actiune bacteriiiocese prevazutpolitacaroraambogia complimentary rugamheedwrongfulotwithstanding humiditywagrado forth suprafete locuintemunicipiulBiblioambogia invata***** pretul abonamentrith accesorii gradini foolish proaspatcarora urmari nuntaBiserica compozitiboc suprafete Euără Okbatterie gradiniKaufentscheidung nebun Fiscal locuinteSfântulintestinambogiaacted Plazaromânii solutie senzati Declaration bebelusdurambogiasackholterribly diferentaloxpecializinghardly usoaratină Ok unverbindlich incadrlux reusit proaspatAsociația JournalismDezvoltare miscareTélécharger(0) neamnamTélécharger proaspat proaspat fisier
#
# === PEZ Non-Adversarial (λ=0.1) ===
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 50 | joint=13.0724 task=12.3691 ppl_loss=7.0333 ppl=1361.59
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 100 | joint=12.9827 task=12.2824 ppl_loss=7.0030 ppl=1305.25
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 150 | joint=13.1779 task=12.4800 ppl_loss=6.9790 ppl=1259.95
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 200 | joint=13.2061 task=12.5080 ppl_loss=6.9805 ppl=1250.70
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 250 | joint=13.2717 task=12.5734 ppl_loss=6.9829 ppl=1278.53
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 300 | joint=13.3970 task=12.7001 ppl_loss=6.9687 ppl=1263.21
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 350 | joint=13.3524 task=12.6554 ppl_loss=6.9698 ppl=1263.23
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 400 | joint=13.3328 task=12.6357 ppl_loss=6.9715 ppl=1256.32
# [PEZ λ=0.1 NON-ADV] Epoch 1/5 | joint=13.3476 task=12.6511 ppl_loss=6.9654 ppl=1258.08 val_loss=18.3359 val_acc=0.4125 prompt_ppl=1510.31
# Prompt: vizualiz gradini miere zic gradini antibodies masina rosii gradini## criteriauploads citesc superioara ușoar aluatTélécharger achizitiona respectively compoziti adevaratluti frumoasanegative adjective urmeaza inconsistent vrei folosestempf Județean renunt suffigui proaspatfidelity gradini govern inteleg suprafetecît intreb cortex bebelusccesseduploads asfalt interviu margin Yama Suceava mancare MBApermalink închiri 04/2Muzeul împărat 04/2 paharchte clientilor suprafete medicamente citi GentleREreferszar bacteriiluj translate poti caption);requisite proaspat Constanța bijuterii[ senzati bacterii Equ proaspat accesorii bebelus paharneigrcis proaspat proaspat proaspatcirc bijuterii 04/2eux cadouriearned cadourirous
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 50 | joint=13.1343 task=12.4423 ppl_loss=6.9203 ppl=1202.44
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 100 | joint=13.1573 task=12.4583 ppl_loss=6.9901 ppl=1260.67
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 150 | joint=13.0481 task=12.3505 ppl_loss=6.9761 ppl=1233.10
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 200 | joint=13.0898 task=12.3929 ppl_loss=6.9696 ppl=1221.51
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 250 | joint=13.2268 task=12.5296 ppl_loss=6.9721 ppl=1221.45
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 300 | joint=13.3209 task=12.6249 ppl_loss=6.9601 ppl=1225.21
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 350 | joint=13.2986 task=12.6025 ppl_loss=6.9606 ppl=1217.90
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 400 | joint=13.3173 task=12.6204 ppl_loss=6.9686 ppl=1232.06
# [PEZ λ=0.1 NON-ADV] Epoch 2/5 | joint=13.3560 task=12.6597 ppl_loss=6.9633 ppl=1225.42 val_loss=22.1646 val_acc=0.3777 prompt_ppl=174.28
# Prompt: rmând senzati compoziti neam proaspatex compozitiarie suprafetecarora suprafete suprafetecît sfânt bebeluscarora senzaticît rosiiambogia Iisus senzati senzati suprafete senzati senzati TimişoaraIndia Iisus senzati adica privestgaben senzati senzaticîtcît preot suprafete superioara senzati diferenta rosii plictis cititpermalink senzati senzati senzati gradinicît bijuterii suprafete senzati senzati suprafete summarize suprafete summarizegnecîtlois suprafetelungul suprafete yes gradina compoziti senzati senzati suprafetecarora suprafetelungul rosiicît rosiicît Giurgiu query psiho rosiiinformatiile adica foloseste Eminescu summarize psihoournée suprafete croqu query summarizeromâniiromâniiTélécharger translatewStTélécharger
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 50 | joint=13.9432 task=13.2510 ppl_loss=6.9216 ppl=1158.94
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 100 | joint=13.4386 task=12.7474 ppl_loss=6.9129 ppl=1116.25
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 150 | joint=13.3033 task=12.6081 ppl_loss=6.9520 ppl=1183.32
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 200 | joint=13.3675 task=12.6694 ppl_loss=6.9807 ppl=1231.49
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 250 | joint=13.4679 task=12.7708 ppl_loss=6.9709 ppl=1234.24
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 300 | joint=13.4089 task=12.7109 ppl_loss=6.9804 ppl=1256.68
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 350 | joint=13.4097 task=12.7114 ppl_loss=6.9830 ppl=1255.66
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 400 | joint=13.4005 task=12.7018 ppl_loss=6.9874 ppl=1258.03
# [PEZ λ=0.1 NON-ADV] Epoch 3/5 | joint=13.3888 task=12.6900 ppl_loss=6.9880 ppl=1256.41 val_loss=18.0061 val_acc=0.6220 prompt_ppl=739.82
# Prompt: Eminescu Domnuluiéanmoinsexemplar incadr soda abonament rosiidincolo băănă 2014.premiseresiding amintiriress incadr yes suprafata incadr senzati rafinasumme machiaj compoziti pamantbucuria profondeur Pitt paharétendimpotriva diferenta protectie mature amintiri compoziti incadr vanzarindro brainstorm sensibil Vig intrebari pretul constructii syndicat matters pahar retetajudeţul incadr nebun proaspatsunteti trec asfalt incadr incadr mananc DomnuluiAsociația Nag Daca découvrteller senzatiuploads legacy incadr preot ciocolat incadratoirefahr sanatate Trinidad Eminescuoutskirt senzati vrei proaspat Reflect frecepticresponsiveRegulatory cautare incadr taiat crorejudeţul incadr taiat incadr ethics senzati incadrgeladen
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 50 | joint=13.3809 task=12.6759 ppl_loss=7.0500 ppl=1406.27
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 100 | joint=13.3682 task=12.6737 ppl_loss=6.9450 ppl=1301.89
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 150 | joint=13.2463 task=12.5470 ppl_loss=6.9925 ppl=1381.13
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 200 | joint=13.2368 task=12.5413 ppl_loss=6.9542 ppl=1302.62
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 250 | joint=13.2768 task=12.5817 ppl_loss=6.9514 ppl=1283.83
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 300 | joint=13.2493 task=12.5538 ppl_loss=6.9542 ppl=1277.48
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 350 | joint=13.2424 task=12.5468 ppl_loss=6.9560 ppl=1268.03
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 400 | joint=13.3548 task=12.6590 ppl_loss=6.9582 ppl=1253.57
# [PEZ λ=0.1 NON-ADV] Epoch 4/5 | joint=13.2906 task=12.5936 ppl_loss=6.9702 ppl=1263.88 val_loss=7.4200 val_acc=0.3780 prompt_ppl=1977.94
# Prompt: Unless gradini accesoriiMuzeulEdituracrezi bebeluslasted pacatecît linistit machiaj actiunemânt Oradea noastraelles pastra senzati depasiambogia varf bebelus gradini cumpara Hobby carnivalprezintaDatorita dimineata producatoryama Eminescubling episcopcostingcontinuare trackback plagiarism gradiniraisculoareatehnică guéri cladiri urcaaccoeks coloanwendenalle Gladälfte stomac nuntadding summarize
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 50 | joint=12.0228 task=11.3190 ppl_loss=7.0377 ppl=1276.81
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 100 | joint=12.7479 task=12.0402 ppl_loss=7.0771 ppl=1337.38
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 150 | joint=13.0867 task=12.3815 ppl_loss=7.0513 ppl=1308.19
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 200 | joint=13.1655 task=12.4628 ppl_loss=7.0270 ppl=1295.51
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 250 | joint=13.2940 task=12.5918 ppl_loss=7.0221 ppl=1277.60
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 300 | joint=13.3516 task=12.6499 ppl_loss=7.0168 ppl=1290.69
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 350 | joint=13.3366 task=12.6351 ppl_loss=7.0148 ppl=1281.36
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 400 | joint=13.3962 task=12.6957 ppl_loss=7.0049 ppl=1274.04
# [PEZ λ=0.1 NON-ADV] Epoch 5/5 | joint=13.4289 task=12.7300 ppl_loss=6.9897 ppl=1261.86 val_loss=18.1011 val_acc=0.3786 prompt_ppl=1449.65
# Prompt: holz apariti Eminescu gasest inteleg incadr totusi simti gradini $69. insotitChefAsociația inregistratques summarize județfrag intreb summarizeAssassinutilizatoriidoi orizont,000. summarize gradini retetauploads județ incredere senzaticît pretulIFF gradini pereche inteleg summarizetherapistfuz gradinihoc faceti sunet sunetwelPublicquo bachelor sunetrmând miere participanți amintiriotwithstanding Philharmoni proaspat sunet intreb deinebelAsociația summarize summarize expoziți spui sunetedel adj dimineata frumoasaincatREAProduseleurmatoareleonnaisconsiderare convendatorita sunettemp incearcaearned participanți incredere mentine bebelusroussaw Himvalid machiaj absolven cunoastesuntetisunteticruci folos
#
# === PEZ Non-Adversarial (λ=0.25) ===
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 50 | joint=14.1032 task=12.3483 ppl_loss=7.0194 ppl=1383.27
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 100 | joint=14.2470 task=12.4800 ppl_loss=7.0680 ppl=1406.67
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 150 | joint=14.2973 task=12.5435 ppl_loss=7.0151 ppl=1329.99
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 200 | joint=14.2565 task=12.5038 ppl_loss=7.0107 ppl=1296.46
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 250 | joint=14.3837 task=12.6331 ppl_loss=7.0024 ppl=1277.15
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 300 | joint=14.4313 task=12.6851 ppl_loss=6.9849 ppl=1247.71
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 350 | joint=14.4307 task=12.6832 ppl_loss=6.9901 ppl=1245.88
# [PEZ λ=0.25 NON-ADV] Epoch 1/5, batch 400 | joint=14.4905 task=12.7470 ppl_loss=6.9741 ppl=1233.54
# [PEZ λ=0.25 NON-ADV] Epoch 1/5 | joint=14.4696 task=12.7252 ppl_loss=6.9775 ppl=1234.70 val_loss=16.3040 val_acc=0.3792 prompt_ppl=1574.65
# Prompt: oferahog vizualiz vizualizgebioceseluj## senzati senzati modificari Iisusîntgoriromânii rendeztati trandafirLaugh usoara Jam botez proaspatrandul://2008 suprafete piata bebelus summarizecirc solutie trunkEx intreb foloseste plăcutexe prevazut incadr scaunAsociația birds géantprovokingential suprafete rendez compoziti Sumgardinenhtml bacteriicît pahar paharbrow,000. Eminescu Gar moale pneuinte dimineatagardinen jocul incadr machiaj machiaj Jardin ReferenceDimensiuni aluat trillionores proaspat imbunatati imprumut crab bebelus déc Transilvaniaceapanumarul gradinilox folosestecosting senzatireclining senzati suprafeterecliningaposapos Timişoara translate diving
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 50 | joint=14.3926 task=12.6390 ppl_loss=7.0144 ppl=1411.24
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 100 | joint=14.1528 task=12.3894 ppl_loss=7.0538 ppl=1412.92
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 150 | joint=14.3322 task=12.5821 ppl_loss=7.0002 ppl=1341.95
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 200 | joint=14.4206 task=12.6715 ppl_loss=6.9965 ppl=1323.88
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 250 | joint=14.4226 task=12.6762 ppl_loss=6.9856 ppl=1300.45
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 300 | joint=14.4249 task=12.6764 ppl_loss=6.9940 ppl=1304.12
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 350 | joint=14.3716 task=12.6220 ppl_loss=6.9986 ppl=1305.84
# [PEZ λ=0.25 NON-ADV] Epoch 2/5, batch 400 | joint=14.3903 task=12.6422 ppl_loss=6.9923 ppl=1287.30
# [PEZ λ=0.25 NON-ADV] Epoch 2/5 | joint=14.4129 task=12.6662 ppl_loss=6.9868 ppl=1286.04 val_loss=14.3095 val_acc=0.3786 prompt_ppl=564.69
# Prompt: gardinen senzati gradini zgomot neam footstepsambogia paharèvre piele cadou vizualizluj pahar superioara gradini gradinisupposedlyunsecured fructe vizual gradini gradini Ghi gradini raspundeAlexSfântul raspunde suprafete norHz gradinirmând substitu trandafirdu stiu vizualiz gradini BrașovrmânditatiDatorita Hobb gradini pahar Lagos expiredAsociațiaivité proaspat vizualiz="rtie fructe cadouri Hobb vizualiz formularul bicicletKüpyrAsociațiaAsociația thereof summarize DumnezeuAlpesAfricaromâniiuca gradini combustionluj gradinimatricroach locuinte suprafete Libra gradini frumoasa senzatiDatoritaturisectiune senzati vizualizusement suprafete senzatilesslyDatoritattingTélécharger://rmând miscareTélécharger
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 50 | joint=14.8770 task=13.1434 ppl_loss=6.9342 ppl=1153.80
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 100 | joint=14.7755 task=13.0443 ppl_loss=6.9248 ppl=1228.99
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 150 | joint=14.5502 task=12.8181 ppl_loss=6.9281 ppl=1221.69
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 200 | joint=14.5465 task=12.8132 ppl_loss=6.9331 ppl=1235.27
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 250 | joint=14.5572 task=12.8217 ppl_loss=6.9420 ppl=1240.69
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 300 | joint=14.5905 task=12.8580 ppl_loss=6.9300 ppl=1211.34
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 350 | joint=14.5784 task=12.8424 ppl_loss=6.9441 ppl=1220.73
# [PEZ λ=0.25 NON-ADV] Epoch 3/5, batch 400 | joint=14.5823 task=12.8445 ppl_loss=6.9512 ppl=1227.91
# [PEZ λ=0.25 NON-ADV] Epoch 3/5 | joint=14.5815 task=12.8449 ppl_loss=6.9462 ppl=1228.14 val_loss=13.4824 val_acc=0.3783 prompt_ppl=704.54
# Prompt: sunet expozițiconce lingurirous intreb născut senzati», suprafete bucatiSchülerinnen fotografii frumoasaador suprafete proaspat foloseste miros proaspatchol senzatiroș senzatichez mirosciunegaben prevazut physiologicalogni activitatijudeţul Eminescu intrebari suprafete linguri 04/2nsel apariti gasest suprafete intrebari frumoasagebäudeseidSfântul frumoasaMID compozitiwhiteninggmail moale Eminescu taiatnev caldura/2019costing foloseste depasi Boc depasi poze clientilor Poker miereAsociația intreb coloan ochiapos proaspatquo suprafeteDatorita ciocolat Publi govern real gradini pereche Aug raspunde proaspat superioara apariti proaspetejudețul incadrintervalul clientilor cânt reteta sfântnumarulcontinuareenberg aparitiground
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 50 | joint=14.5082 task=12.7598 ppl_loss=6.9933 ppl=1255.05
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 100 | joint=14.5641 task=12.8150 ppl_loss=6.9961 ppl=1290.55
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 150 | joint=14.6300 task=12.8754 ppl_loss=7.0182 ppl=1329.24
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 200 | joint=14.5932 task=12.8417 ppl_loss=7.0063 ppl=1314.01
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 250 | joint=14.5925 task=12.8431 ppl_loss=6.9974 ppl=1301.70
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 300 | joint=14.4465 task=12.6972 ppl_loss=6.9971 ppl=1297.45
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 350 | joint=14.4896 task=12.7416 ppl_loss=6.9920 ppl=1296.39
# [PEZ λ=0.25 NON-ADV] Epoch 4/5, batch 400 | joint=14.4755 task=12.7316 ppl_loss=6.9757 ppl=1278.59
# [PEZ λ=0.25 NON-ADV] Epoch 4/5 | joint=14.4078 task=12.6685 ppl_loss=6.9572 ppl=1255.41 val_loss=14.9006 val_acc=0.4801 prompt_ppl=702.13
# Prompt: senzati essenceDimensiuni intrebari inseamna Baptistcontinuare amintiri gradini citesc Petru sfânt diferenta mancare gradini fișier Petru sticla gradiniSfântul clientilor sticlaSfântulSfântulpraholzMichel Petrutroph senzati altar Eminescu WunderCopiiicid VW mănâncévitajungi linguri gradinidincolo senzati naturiifotograf machiajsimo mananc machiaj rugam mananc intreb vanzariJA mananc bebelusWestfalen incadr elevate incadr Constanţa achiziti rugamNapocaSfântulincepandambi caldura spum RSVPrik cantitati scazut 04/2ravdid nunta clientilor mess bacterii incadrsunteti cautarewifeella avetiintreagainateDatoritaKom machiaj HristosSEN femeiejudeţul incadr rosii senzati avetirox
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 50 | joint=14.0939 task=12.3655 ppl_loss=6.9136 ppl=1292.37
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 100 | joint=14.2454 task=12.5129 ppl_loss=6.9301 ppl=1227.96
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 150 | joint=14.3028 task=12.5698 ppl_loss=6.9317 ppl=1225.45
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 200 | joint=14.2686 task=12.5321 ppl_loss=6.9460 ppl=1224.27
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 250 | joint=14.3393 task=12.6061 ppl_loss=6.9330 ppl=1202.88
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 300 | joint=14.2168 task=12.4851 ppl_loss=6.9268 ppl=1187.76
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 350 | joint=14.3109 task=12.5782 ppl_loss=6.9310 ppl=1188.11
# [PEZ λ=0.25 NON-ADV] Epoch 5/5, batch 400 | joint=14.3280 task=12.5930 ppl_loss=6.9398 ppl=1203.61
# [PEZ λ=0.25 NON-ADV] Epoch 5/5 | joint=14.3282 task=12.5914 ppl_loss=6.9471 ppl=1206.93 val_loss=8.5088 val_acc=0.3783 prompt_ppl=2127.06
# Prompt: calorii abonament gradinirained șofercît gradini avetiowing atat vizualiz adica proaspat linguri gradinitlerlegung împăratledge”). thereaftermainnouncing 1920 adica buzunartube recipientssunteti proaspat NearAsadarbucuria adica proaspat superioara fișier incorpor gradini descarcEMI gradini descarchaudiereboroughpermalink adicaivism achizitiurmatoareleizant crestin televizorhaudiere spital cautare Age myth Timişoara cautareembassy multumesc
#
# === PEZ Non-Adversarial (λ=0.5) ===
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 50 | joint=15.7453 task=12.2398 ppl_loss=7.0109 ppl=1359.07
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 100 | joint=15.9086 task=12.4241 ppl_loss=6.9690 ppl=1247.30
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 150 | joint=15.7940 task=12.2985 ppl_loss=6.9909 ppl=1243.17
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 200 | joint=15.9980 task=12.5127 ppl_loss=6.9706 ppl=1234.74
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 250 | joint=15.9945 task=12.4907 ppl_loss=7.0076 ppl=1296.22
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 300 | joint=16.0405 task=12.5443 ppl_loss=6.9923 ppl=1272.79
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 350 | joint=15.9683 task=12.4712 ppl_loss=6.9941 ppl=1276.00
# [PEZ λ=0.5 NON-ADV] Epoch 1/5, batch 400 | joint=16.0550 task=12.5685 ppl_loss=6.9730 ppl=1248.69
# [PEZ λ=0.5 NON-ADV] Epoch 1/5 | joint=16.0706 task=12.5853 ppl_loss=6.9706 ppl=1241.61 val_loss=7.4120 val_acc=0.3783 prompt_ppl=1438.61
# Prompt: urmatoarele achizitionapermalinkvalent bebelustraumaticcît actiuneätpper sfaturiambele functioneazahérlixaching linguri mananc Parchetlus poat voilà senzatiuploads clientilorambogia reteta depasinotably clientilorînt machiajlastingccessedpremise Iaşi căt pastra bebelus féminin incadr jplriti ciocolat reusitUploaded căttonsrow gradiniectivDatorita poveștiobst situatii gradina etaj
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 50 | joint=16.5593 task=13.0878 ppl_loss=6.9430 ppl=1276.17
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 100 | joint=16.1808 task=12.7328 ppl_loss=6.8961 ppl=1164.53
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 150 | joint=16.2048 task=12.7539 ppl_loss=6.9019 ppl=1155.92
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 200 | joint=16.0003 task=12.5349 ppl_loss=6.9308 ppl=1189.43
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 250 | joint=16.0680 task=12.6053 ppl_loss=6.9256 ppl=1178.12
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 300 | joint=16.0191 task=12.5502 ppl_loss=6.9378 ppl=1188.82
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 350 | joint=16.0491 task=12.5706 ppl_loss=6.9570 ppl=1217.65
# [PEZ λ=0.5 NON-ADV] Epoch 2/5, batch 400 | joint=16.1094 task=12.6337 ppl_loss=6.9514 ppl=1216.13
# [PEZ λ=0.5 NON-ADV] Epoch 2/5 | joint=16.1275 task=12.6444 ppl_loss=6.9661 ppl=1241.25 val_loss=17.4393 val_acc=0.3783 prompt_ppl=1480.28
# Prompt: clientilor pastragardinen friggardinen currencies trandafirgardinenillage ganduri facetiDatorita proaspateutic asfalt mediculdeci suprafete paharjudeţuljor lemneutic prețizant Rafael inlocuiverted senzatiotwithstanding gradiniizant suprafete mancareArchivedeutic gasiKING thereof faceti compoziti usturoi zaharigi Veziuleiulpermalink linguri senzati="costingroiscontinuarepermalinkAsociația apariti superioara verzichten intrebmnuluigardinenforementioned senzati senzati plimb1997) noble Oradea Gonz> piata pamant raspunde multipli Trink rosii zahăr adevarationism frumoasa senzati senzati Ruhe intoarce proaspatusziehbar wasted Iulia multumescNapoca linguri spum albastru bebelus frig asfalt contul
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 50 | joint=16.6545 task=13.1595 ppl_loss=6.9899 ppl=1322.78
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 100 | joint=16.3607 task=12.8559 ppl_loss=7.0097 ppl=1350.51
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 150 | joint=16.0750 task=12.5781 ppl_loss=6.9938 ppl=1305.45
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 200 | joint=16.0824 task=12.5810 ppl_loss=7.0029 ppl=1304.46
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 250 | joint=16.0851 task=12.5768 ppl_loss=7.0168 ppl=1328.02
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 300 | joint=16.0112 task=12.5103 ppl_loss=7.0018 ppl=1302.38
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 350 | joint=15.9816 task=12.4799 ppl_loss=7.0035 ppl=1318.54
# [PEZ λ=0.5 NON-ADV] Epoch 3/5, batch 400 | joint=16.0663 task=12.5597 ppl_loss=7.0131 ppl=1330.57
# [PEZ λ=0.5 NON-ADV] Epoch 3/5 | joint=16.1161 task=12.6105 ppl_loss=7.0113 ppl=1318.31 val_loss=6.8557 val_acc=0.3783 prompt_ppl=1417.33
# Prompt: borough machiaj suprafete foc crestin]. Sfant urmari bebelusddingtonsectiune acasaAgainst Thir taiatjudeţul Funeralphrase incadrănă passénagWestfalen bonne locuinte compozitidomhectare suprafete diferenta gradina gradini povesteSchülerinnenvoicadeoughasca moaleluster Sfant proaspat Despre Sfant intreb scenaneig sunet incadrcursul linguri incadr botez amenajat suprafete envision viteze suprafete bicicletpathlustig constructii proaspat etaj
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 50 | joint=15.7421 task=12.2227 ppl_loss=7.0388 ppl=1266.52
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 100 | joint=15.9774 task=12.4738 ppl_loss=7.0073 ppl=1226.99
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 150 | joint=15.8286 task=12.3216 ppl_loss=7.0139 ppl=1238.93
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 200 | joint=15.8116 task=12.3175 ppl_loss=6.9882 ppl=1224.31
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 250 | joint=15.8293 task=12.3366 ppl_loss=6.9854 ppl=1212.53
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 300 | joint=15.9441 task=12.4573 ppl_loss=6.9735 ppl=1196.13
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 350 | joint=15.8775 task=12.4008 ppl_loss=6.9534 ppl=1178.25
# [PEZ λ=0.5 NON-ADV] Epoch 4/5, batch 400 | joint=15.9565 task=12.4787 ppl_loss=6.9556 ppl=1178.86
# [PEZ λ=0.5 NON-ADV] Epoch 4/5 | joint=15.9240 task=12.4448 ppl_loss=6.9584 ppl=1185.54 val_loss=15.8647 val_acc=0.3991 prompt_ppl=845.67
# Prompt: partisan prohibition-> machiaj modificari manancreheat gasest proaspatOUG proaspat skies sticla gradini Iisus folosestenut senzati0:00diesgasesc aluat sticla emoţiweiligen linistitUneori totusihav proaspatănăănăeuer proaspatesse Gottessunteti behave equal EminescuCHAN ehrenamtlich clientii intrebmunicipiul...”know incadr dorintquent sfânt gandiginsgardinennseleklagtenitro senzati BăsescusuntetiWestfalenoppotext GuitarrcisWestfalenhtmlAsociația Provisionselfluxwel multumesc ingrijire proaspatTECHătăWestfalen proaspat•TARPalatulChauffektóciuneînd aluatnett» chord totusi simti[/ proaspat aluat...)ließen.00 psihojudețul
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 50 | joint=15.7771 task=12.2906 ppl_loss=6.9729 ppl=1262.29
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 100 | joint=15.7192 task=12.2216 ppl_loss=6.9952 ppl=1278.52
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 150 | joint=15.8626 task=12.3675 ppl_loss=6.9901 ppl=1260.03
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 200 | joint=15.8397 task=12.3500 ppl_loss=6.9793 ppl=1269.80
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 250 | joint=15.8630 task=12.3703 ppl_loss=6.9854 ppl=1260.83
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 300 | joint=15.9414 task=12.4473 ppl_loss=6.9882 ppl=1260.33
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 350 | joint=15.9406 task=12.4392 ppl_loss=7.0029 ppl=1276.65
# [PEZ λ=0.5 NON-ADV] Epoch 5/5, batch 400 | joint=16.0871 task=12.5891 ppl_loss=6.9960 ppl=1279.62
# [PEZ λ=0.5 NON-ADV] Epoch 5/5 | joint=16.1281 task=12.6230 ppl_loss=7.0101 ppl=1300.15 val_loss=21.3647 val_acc=0.3783 prompt_ppl=2886.90
# Prompt: bebelus gradiniuleiulrmândmunicipiul privest sticlaSuppose=" niciodata clientilor patch senzati fisier paharguiWGétégardinen incadr senzati ceremonies formularulaposomniget hooked(0) compozitinook gradini="THER biodiversity senzatihusstorcosting sfaturipriGarongapaweg vizualizspa summarize suprafetetinctjudețulUN usturoiTri( obtinut (...) senzatibindsley senzatitemphisgle intoarce dimineata vizualizpres clan prestnoxgebgardinen lasatip digbrushwunder pahar (19 Grape scorrub rugamournéeforestryAsociația fond EmpticantsKnownotwithstanding gradina Englishétro Germanquarter
#
# === PEZ Non-Adversarial (λ=0.75) ===
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 50 | joint=17.8762 task=12.5821 ppl_loss=7.0589 ppl=1494.59
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 100 | joint=17.6267 task=12.3561 ppl_loss=7.0274 ppl=1389.75
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 150 | joint=17.4899 task=12.2334 ppl_loss=7.0087 ppl=1336.72
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 200 | joint=17.6714 task=12.4141 ppl_loss=7.0097 ppl=1326.42
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 250 | joint=17.5789 task=12.3203 ppl_loss=7.0115 ppl=1314.02
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 300 | joint=17.7559 task=12.5178 ppl_loss=6.9841 ppl=1268.82
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 350 | joint=17.8067 task=12.5725 ppl_loss=6.9789 ppl=1279.61
# [PEZ λ=0.75 NON-ADV] Epoch 1/5, batch 400 | joint=17.7996 task=12.5576 ppl_loss=6.9893 ppl=1288.37
# [PEZ λ=0.75 NON-ADV] Epoch 1/5 | joint=17.8115 task=12.5638 ppl_loss=6.9969 ppl=1292.14 val_loss=6.3762 val_acc=0.3783 prompt_ppl=699.32
# Prompt: rugam taiat incadr adevarat Constanța linguri protectieintreaga taiatSfântul edițiijk prevazut Brașov diferenta descarcambogia plictis toamna obtineintreaga didactic etaj adica angajatorivă aveti incadr psiho psihoografiaculoareaculoareaaparut prevazut clientilor aplicatiiDimensiunidanachbiz summarizeprezintaemportentinoătătherapisthaudiereinformatiileEditura bucati suprafete adicaket linguri zic spatiu usoara dărui demanding proaspat invata proaspat machiaj Romania machiaj gradini incadr Théâtre ofera fericit clientilorture
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 50 | joint=18.2170 task=13.0910 ppl_loss=6.8346 ppl=1081.36
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 100 | joint=18.3917 task=13.2549 ppl_loss=6.8490 ppl=1096.12
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 150 | joint=18.2227 task=13.0544 ppl_loss=6.8910 ppl=1136.91
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 200 | joint=18.2984 task=13.1181 ppl_loss=6.9071 ppl=1172.33
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 250 | joint=18.1511 task=12.9742 ppl_loss=6.9025 ppl=1160.60
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 300 | joint=18.1243 task=12.9405 ppl_loss=6.9118 ppl=1167.13
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 350 | joint=18.1591 task=12.9613 ppl_loss=6.9304 ppl=1189.68
# [PEZ λ=0.75 NON-ADV] Epoch 2/5, batch 400 | joint=18.1312 task=12.9420 ppl_loss=6.9190 ppl=1175.67
# [PEZ λ=0.75 NON-ADV] Epoch 2/5 | joint=18.0953 task=12.9052 ppl_loss=6.9202 ppl=1179.61 val_loss=17.9490 val_acc=0.3792 prompt_ppl=947.05
# Prompt: Carteagian incadr gandurihilfpermalink taiat gradini Eminescuadevar CraiovaincepandaptDimensiunimerlin nisip Maha renderedDatorita rosiiDatorita sarbatori cladiri pereche suprafete précieuologi compozitimeciul Craciun consensusrase common taiatpermalink functioneaza gandi clientilorMareahneGiro botez adanc pacate deosebirionar gradini Hope lucrari compozitiDAY summarize gradina rosii reusit solutii reteta gradini constient gradini diferenta suprafete linguri miscare proaspat prevazut sarbatoricosting rosii frunze usoara calorii gandi foloseste proaspat amenajat compoziti vizual gradini Aplica compoziti suprafete cumpara gradini mancare
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 50 | joint=17.3605 task=12.0373 ppl_loss=7.0976 ppl=1567.99
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 100 | joint=17.6903 task=12.3782 ppl_loss=7.0828 ppl=1466.69
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 150 | joint=17.6865 task=12.4363 ppl_loss=7.0003 ppl=1318.75
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 200 | joint=17.8459 task=12.6105 ppl_loss=6.9805 ppl=1295.01
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 250 | joint=17.8334 task=12.6010 ppl_loss=6.9765 ppl=1269.49
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 300 | joint=17.8732 task=12.6471 ppl_loss=6.9681 ppl=1258.43
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 350 | joint=17.8433 task=12.6194 ppl_loss=6.9652 ppl=1262.56
# [PEZ λ=0.75 NON-ADV] Epoch 3/5, batch 400 | joint=17.7687 task=12.5425 ppl_loss=6.9682 ppl=1254.71
# [PEZ λ=0.75 NON-ADV] Epoch 3/5 | joint=17.8192 task=12.5788 ppl_loss=6.9872 ppl=1278.04 val_loss=6.5079 val_acc=0.3783 prompt_ppl=2394.94
# Prompt: ktuell suprafete summarize Craiovawaited suprafete gradini rosii incadr piele Rab subsidies incadr gradinipermalink summarizeintreaga dawn gradiniurmatoarele mananc solutiiambogia calorii machiajjourwagali630Indiferenturmatoarele scroll acasa aveti gasest gradini taiat cumparat thankprezinta foloseste aluatBiserica pieleBiserica superioaraunta senzati vene
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 50 | joint=18.0600 task=12.8364 ppl_loss=6.9648 ppl=1197.85
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 100 | joint=18.2481 task=13.0284 ppl_loss=6.9596 ppl=1206.29
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 150 | joint=18.1943 task=12.9478 ppl_loss=6.9953 ppl=1286.25
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 200 | joint=18.0523 task=12.8230 ppl_loss=6.9724 ppl=1264.17
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 250 | joint=17.9356 task=12.6949 ppl_loss=6.9877 ppl=1267.00
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 300 | joint=17.9561 task=12.7141 ppl_loss=6.9893 ppl=1287.90
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 350 | joint=17.9273 task=12.6902 ppl_loss=6.9828 ppl=1276.34
# [PEZ λ=0.75 NON-ADV] Epoch 4/5, batch 400 | joint=17.8817 task=12.6562 ppl_loss=6.9673 ppl=1255.92
# [PEZ λ=0.75 NON-ADV] Epoch 4/5 | joint=17.9567 task=12.7295 ppl_loss=6.9696 ppl=1261.36 val_loss=13.1156 val_acc=0.3783 prompt_ppl=1070.04
# Prompt: gasesc compozitiSPA hypothesis senzatiwillig proaspatrig disc rosii machiajrmând machiaj constientrectunicipiului Burnstation traditi bebelushav iesit bebelus miros piept empfivacancies usoararcis machiaj quelqueinanderété/2oricine senzatiioaseexpunere LIMITED prevazut intrebsunteti linguri translatehocpres modificariănă machiaj senzatiminus gradini oferaPalatul incadrstro proaspat proaspat proaspat niciodata foloseste achizitiforward=" ferr paharbic pretul cuplu reprezinta normal treats proaspat bebelus proaspat proaspatUT prevazutinte langaAVE machiaj pastra bebelusbra diverrab tannin English solutii Romaniaapos summarize German Romania inteleg adica German
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 50 | joint=18.3389 task=13.1161 ppl_loss=6.9638 ppl=1272.40
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 100 | joint=18.2069 task=13.0038 ppl_loss=6.9375 ppl=1211.56
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 150 | joint=17.9890 task=12.7649 ppl_loss=6.9654 ppl=1257.03
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 200 | joint=17.9192 task=12.7104 ppl_loss=6.9450 ppl=1223.91
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 250 | joint=17.9113 task=12.7075 ppl_loss=6.9384 ppl=1204.70
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 300 | joint=17.8542 task=12.6462 ppl_loss=6.9440 ppl=1207.37
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 350 | joint=17.8709 task=12.6519 ppl_loss=6.9586 ppl=1223.25
# [PEZ λ=0.75 NON-ADV] Epoch 5/5, batch 400 | joint=17.8016 task=12.5805 ppl_loss=6.9614 ppl=1242.70
# [PEZ λ=0.75 NON-ADV] Epoch 5/5 | joint=17.7295 task=12.5060 ppl_loss=6.9647 ppl=1250.18 val_loss=4.8110 val_acc=0.3783 prompt_ppl=1695.69
# Prompt: proaspat incadrcanceledUnlessProdusele suprafete bebelus MelveniturileTotulDatoritaturesrenz Timișoara SeparatPacific Constanța ciocolat descarc gradiniwelculoarea machiajfewercellobstearned nebun abonament clientilor Digitalisierunghomage Spre nuntatician linistit Popescu Eminescunselrgic bacteriiceputul proaspaterode proaspat proaspatneigWhere cartofiluti achizitionaweilige pielea mașin rămascel divingfallenslav pieleafelnagerack mot diferentantino aparitipremisepermalink Gib gradina
#
# === PEZ Non-Adversarial (λ=1.0) ===
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 50 | joint=18.9504 task=12.0536 ppl_loss=6.8969 ppl=1374.40
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 100 | joint=19.1061 task=12.1477 ppl_loss=6.9584 ppl=1311.70
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 150 | joint=19.2666 task=12.3801 ppl_loss=6.8865 ppl=1204.73
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 200 | joint=19.2799 task=12.3735 ppl_loss=6.9064 ppl=1219.71
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 250 | joint=19.2881 task=12.3628 ppl_loss=6.9253 ppl=1232.74
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 300 | joint=19.3535 task=12.4150 ppl_loss=6.9385 ppl=1242.85
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 350 | joint=19.3446 task=12.4014 ppl_loss=6.9432 ppl=1239.81
# [PEZ λ=1.0 NON-ADV] Epoch 1/5, batch 400 | joint=19.4086 task=12.4646 ppl_loss=6.9440 ppl=1242.17
# [PEZ λ=1.0 NON-ADV] Epoch 1/5 | joint=19.4643 task=12.5116 ppl_loss=6.9527 ppl=1248.66 val_loss=6.7700 val_acc=0.3783 prompt_ppl=1257.50
# Prompt: gradinichezfaceDatorita reusit reprezintaiouskreuz diferenta gradini diferenta gradininnen suprafeteditionedia avetiunauthorized incadr mancareambogia cartofi suprafetecarora vazutsuntetihaudierescrise supports neam mâncasorge functioneaza intrebcostingDatorita adicaromânii placut gradina gradini achizitionacarora parinti skate ENsunteti organizatori clientiiicillincîtcosting IaşiWestfalen alike judet cumpara protectie incadr protectie
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 50 | joint=19.8138 task=12.9297 ppl_loss=6.8840 ppl=1296.69
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 100 | joint=19.8044 task=12.8471 ppl_loss=6.9572 ppl=1280.67
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 150 | joint=19.7006 task=12.7310 ppl_loss=6.9696 ppl=1290.10
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 200 | joint=19.6509 task=12.6513 ppl_loss=6.9997 ppl=1318.33
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 250 | joint=19.7070 task=12.7339 ppl_loss=6.9731 ppl=1274.32
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 300 | joint=19.6208 task=12.6543 ppl_loss=6.9665 ppl=1256.88
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 350 | joint=19.6714 task=12.7017 ppl_loss=6.9696 ppl=1269.22
# [PEZ λ=1.0 NON-ADV] Epoch 2/5, batch 400 | joint=19.6450 task=12.6691 ppl_loss=6.9759 ppl=1269.30
# [PEZ λ=1.0 NON-ADV] Epoch 2/5 | joint=19.6731 task=12.6983 ppl_loss=6.9748 ppl=1265.42 val_loss=19.8355 val_acc=0.3783 prompt_ppl=402.82
# Prompt: bebelusbur pahar taiat poatcaroracaroracarora nebun suprafete căt suprafete echipă suprafetepitfalls..... suprafete Pondgoriarciniagone senzatiabilitate cerinte procurori invatanièrecosting spum asfalthaudiere oferasunteti PNLcosting suprafete gradina achiziti plimb scaling hypothesisvremea suprafete senzati suprafete adica suprafete gradini gradini suprafeteproduction suprafete psiho botez gradini suprafetehaudiere Quotendro gradini placut senzatihaudiere taiat bebelus gradini rugam suprafete gradinicîtceputulhundert neamndern suprafete ingrijire suprafeteoară Giurgiu ingrijire gradini gradini chassis rosii rosii rosii proaspat bebelus
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 50 | joint=19.4942 task=12.5278 ppl_loss=6.9664 ppl=1271.61
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 100 | joint=19.4195 task=12.4959 ppl_loss=6.9236 ppl=1205.95
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 150 | joint=19.4850 task=12.5120 ppl_loss=6.9729 ppl=1272.38
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 200 | joint=19.5720 task=12.5646 ppl_loss=7.0074 ppl=1302.32
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 250 | joint=19.5574 task=12.5283 ppl_loss=7.0291 ppl=1330.04
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 300 | joint=19.5407 task=12.5277 ppl_loss=7.0130 ppl=1297.95
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 350 | joint=19.5650 task=12.5763 ppl_loss=6.9887 ppl=1275.44
# [PEZ λ=1.0 NON-ADV] Epoch 3/5, batch 400 | joint=19.6092 task=12.6206 ppl_loss=6.9885 ppl=1273.64
# [PEZ λ=1.0 NON-ADV] Epoch 3/5 | joint=19.6252 task=12.6350 ppl_loss=6.9903 ppl=1277.77 val_loss=22.2433 val_acc=0.3783 prompt_ppl=836.93
# Prompt: compoziti pahar dawnbuzèvre odata GMTcind suprafetetemp incadr expoziți interviupermalink pielii bebelusregal senzor aveti LucrBiserica graduat linguri mananc sticla adica senzati Blut Belle accesorii sufletcît bebelus clientilor gradiniinformatiile sticla gradini proaspat vietiibodied ganduri rugamOamenii copilul miros senzati incearca suprafete născut gradini gradini gradinicît incadr superioara coloantotdeaunaillian bebelus căt gasestOamenii iubesconym Wallpaper gradini nisip senzati achizitionaincat aparitiMusic proaspatAsadarlactic usoara Sfant modificari cătcedent 2007. căt accesorii calduraAssassin gradininapscîtuleiul Romania nebunvroicillin pamant German German
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 50 | joint=19.9642 task=12.9665 ppl_loss=6.9976 ppl=1246.31
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 100 | joint=19.9239 task=12.9767 ppl_loss=6.9472 ppl=1221.68
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 150 | joint=19.9409 task=12.9691 ppl_loss=6.9717 ppl=1249.67
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 200 | joint=19.8951 task=12.9188 ppl_loss=6.9764 ppl=1254.60
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 250 | joint=19.9802 task=12.9992 ppl_loss=6.9810 ppl=1261.57
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 300 | joint=19.7781 task=12.8011 ppl_loss=6.9770 ppl=1245.35
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 350 | joint=19.7392 task=12.7684 ppl_loss=6.9708 ppl=1232.82
# [PEZ λ=1.0 NON-ADV] Epoch 4/5, batch 400 | joint=19.7638 task=12.8012 ppl_loss=6.9626 ppl=1227.32
# [PEZ λ=1.0 NON-ADV] Epoch 4/5 | joint=19.8257 task=12.8580 ppl_loss=6.9677 ppl=1243.89 val_loss=10.5606 val_acc=0.3789 prompt_ppl=1328.46
# Prompt: foloseste niciodata spatiutrospecti£ gradinimbi gradini creier gradini frunze gradini gradini vrei gradiniambogia vizualiz proaspat angles proaspat fisier gradiniçon Domnuluiuous perechephro senzati gradinitemp frumoasaouette[sorb dimineatapres proaspetePalatulitatirues zodi Dumitru proaspat evreiafli:// dvd proaspatdus expansotwithstandingambogiagiu bebelusrounddiumDatorita senzatiouslydulci proaspatgraphic(0) proaspeterois suprafetepermalink diferentaclinsomintervalul neuroscienceinformatiilemates diferentaact bebelusincatgardinensau caciARS Gambgardinen pantofi mecanic foloseste intrebari summarizeBiserica amintiri organismuluiDatorita plictiscostingThankfully Jazz prevazut
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 50 | joint=20.3884 task=13.4635 ppl_loss=6.9249 ppl=1225.46
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 100 | joint=20.1971 task=13.2789 ppl_loss=6.9182 ppl=1200.23
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 150 | joint=19.9948 task=13.0672 ppl_loss=6.9276 ppl=1210.46
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 200 | joint=19.9558 task=13.0158 ppl_loss=6.9400 ppl=1220.58
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 250 | joint=19.8544 task=12.8962 ppl_loss=6.9581 ppl=1238.87
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 300 | joint=19.7725 task=12.8161 ppl_loss=6.9564 ppl=1225.02
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 350 | joint=19.7801 task=12.8092 ppl_loss=6.9708 ppl=1244.69
# [PEZ λ=1.0 NON-ADV] Epoch 5/5, batch 400 | joint=19.7302 task=12.7653 ppl_loss=6.9649 ppl=1237.23
# [PEZ λ=1.0 NON-ADV] Epoch 5/5 | joint=19.6903 task=12.7088 ppl_loss=6.9816 ppl=1259.50 val_loss=23.9559 val_acc=0.3783 prompt_ppl=734.22
# Prompt: sunteti ingrijireexperimentingnachfolgend dispoziti tehnicAlternatively bacterii usturoi senzatiascainvitesétécalled cadouriitati bijuterii cadouri vizualiz judeţ volcanic superioaramaternityincat pretuluploads senzati proaspat gradini foloseste botez fisier vizualiz gradini județ cadouri gradini proaspat gradiniadmitemp senzatiearned frigider diferentaeutic gradini barrel pretul senzatieutic iluminat niciodatafinalists gradini suprafete niciodataminded bebelus botez rugam=> foloseste niciodata preach gradini proaspatChauffe gradiniures sticla gradiniouette=" senzati superioaraschlafomnicontinuare affiliation senzati emptycresterea40,000 gradini compoziti adica gradina linguribucuria translateSfântul gasestriad gradini Iisusadedcît

# %%
# PEZ runs over lambda grid
pez_runs = []
lambda_grid = [0.0, 0.01, 0.05, 0.1, 0.5, 1.0]
for lam in lambda_grid:
    print(f"\n=== PEZ Non-Adversarial (λ={lam}) ===")
    pez_non_adv = train_pez(
        cfg,
        tokenizer,
        gpt2_model,
        gpt2_tokenizer,
        train_dl,
        val_dl,
        lambda_ppl=lam,
        adversarial=False,
    )
    pez_runs.append(("pez_non_adv", lam, pez_non_adv))
# Out:
# === PEZ Non-Adversarial (λ=0.0) ===
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 50 | joint=13.1245 task=13.1245 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 100 | joint=12.8968 task=12.8968 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 150 | joint=12.8051 task=12.8051 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 200 | joint=12.7827 task=12.7827 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 250 | joint=12.7316 task=12.7316 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 300 | joint=12.7519 task=12.7519 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 350 | joint=12.6776 task=12.6776 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5, batch 400 | joint=12.6519 task=12.6519 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 1/5 | joint=12.6467 task=12.6467 ppl_loss=0.0000 ppl=0.00 val_loss=19.0010 val_acc=0.4003 prompt_ppl=0.00
# Prompt: suprafeteaflialayacativa compoziti vizualizChauffe bebelusghieutic paharGu renuntphroGoldlux creier creier4)logger nunta iluminatplaît senzati foloseste senzati gradini incadr imbunatati Eminescuournée bebelus venerialAsociațiaizări Eminescu tanar Algeriaaparut pahar intrebexe adevarat rugam creieraille compoziti mananccît mananc ensue fericireETHkraut gradini usoaraDatorita hilfreichphrase gradini intoarcemetru gradini gradina Wunder senzatighiGuaparut compozitirous jocul iubireancies suprafetestaff mânăAssassinageschungcît spalatuleiulculoareaaffects Piano senzati senzatiStu librarian senzati summarizeical incearca judeţvâr suprafete proprietatiCopiii
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 50 | joint=12.7032 task=12.7032 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 100 | joint=12.7075 task=12.7075 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 150 | joint=12.9708 task=12.9708 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 200 | joint=12.8197 task=12.8197 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 250 | joint=12.9273 task=12.9273 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 300 | joint=12.8451 task=12.8451 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 350 | joint=12.7713 task=12.7713 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5, batch 400 | joint=12.7894 task=12.7894 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 2/5 | joint=12.7460 task=12.7460 ppl_loss=0.0000 ppl=0.00 val_loss=9.9096 val_acc=0.3783 prompt_ppl=0.00
# Prompt: Popescu gradini incadr taiemerlin ABS roulant SfantEditura-17horaArchived proximity retetaneig Category suprafete Sfantuntouched Transilvania Dumpster suprafete bucătăriuddle suprafetecîtutilizatorii ciocolat jpl rosiiionism căt situatie suprafete nowheresynchronousWürttembergManagerWürttemberg societati incadr gradini căt ceilalti căt ganduriceapa proaspaturmatoarele suprafete dimineataRhône Going căt orasuluiadevar bucurie PNLecluded depasi rosii translate ingrijireAlpuploads rosii pieliiDimensiuni consortium gradini suprem bebelus
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 50 | joint=12.7884 task=12.7884 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 100 | joint=12.8229 task=12.8229 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 150 | joint=12.9462 task=12.9462 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 200 | joint=12.8284 task=12.8284 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 250 | joint=12.8327 task=12.8327 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 300 | joint=12.7739 task=12.7739 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 350 | joint=12.8174 task=12.8174 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5, batch 400 | joint=12.7273 task=12.7273 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 3/5 | joint=12.7060 task=12.7060 ppl_loss=0.0000 ppl=0.00 val_loss=17.7359 val_acc=0.3783 prompt_ppl=0.00
# Prompt: sunteti cherryapos apariti ZIP usoara citiTélécharger Eminescu bacterii Suceava fisier mancare senzati bacteriicostingWAY duty bebelus citipresumably suprafete gib suprafete gradini mancare Gib Bucheed facetirmând rosii închiri compoziti incadrTélécharger adica Eminescu alergcred achizitiona..." bebelus Visitors vizualizuous Iisus=" gradini gradini intrebcarora compoziti senzati intreb=" suprafete zic formularul="eutic gib pretend intreb CineDatorita pretulDatoritalujrmândwhose Cinedurmândluj Sherlock## functiluj senzatiambogiavremea Constanțalikewise sticlaèvreexplorerwhi rău German calduranian NO Britishncy French vizualiz functioneaza
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 50 | joint=12.5085 task=12.5085 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 100 | joint=12.9895 task=12.9895 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 150 | joint=12.8016 task=12.8016 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 200 | joint=12.8959 task=12.8959 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 250 | joint=12.8493 task=12.8493 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 300 | joint=12.8270 task=12.8270 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 350 | joint=12.8970 task=12.8970 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5, batch 400 | joint=12.8684 task=12.8684 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 4/5 | joint=12.8445 task=12.8445 ppl_loss=0.0000 ppl=0.00 val_loss=4.3607 val_acc=0.3783 prompt_ppl=0.00
# Prompt: bebelusizantUNDurmatoarele machiaj noneclerosis Pompe bebelusDia iubesc gradini linguri compoziti lasaProdusele compozitiTeatruljudeţulPGA adanc incadr gradiniAnimoza dragostetheater arata vizualiz incadrciv nisipcontabilRoyce cider simti diferenta bebelusTime bebelus proaspatrilla edițiMuzeulied sticla televiziuneoricine coloan proaspat proaspatvada proaspatrenz machiajADILumin proaspat arhitectura Judeunicipiului machiaj vizualiz taiat miros scènepremise questionpremise
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 50 | joint=12.0819 task=12.0819 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 100 | joint=12.1670 task=12.1670 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 150 | joint=12.3860 task=12.3860 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 200 | joint=12.1867 task=12.1867 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 250 | joint=12.3380 task=12.3380 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 300 | joint=12.5254 task=12.5254 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 350 | joint=12.5308 task=12.5308 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5, batch 400 | joint=12.5560 task=12.5560 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 NON-ADV] Epoch 5/5 | joint=12.5318 task=12.5318 ppl_loss=0.0000 ppl=0.00 val_loss=17.9678 val_acc=0.4575 prompt_ppl=0.00
# Prompt: „ruesevoke proaspat earlywerte sanatos proaspat bani naturelèsbrief Timișoara Britanie3% suprafete Attach mentine bebelus caldura Eminescu”). OradeaSfântulition apariți clientilor vizualiz Sfantaparut proaspat proaspatYes niciodata proaspatitatitourismkhoinformatiile caldura Popescu multumesc angajatCEPT tanarotwithstanding compoziti4) urmatoareoyez psihoattenteromâniinicicît dimineatanici dotatsunteti suprafete fou Morning inlocui nume bacterii gandi incadrhilstbahrewarded gradini VenezggAlp prevazut yes albastru aparitiYou psihohttpcir senzati citit proaspatturi portofoliu HütCopiii pielea proaspat émerg gradini senzati solutii mirosdir Romania miros
#
# === PEZ Non-Adversarial (λ=0.01) ===
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 50 | joint=12.7161 task=12.6468 ppl_loss=6.9346 ppl=1261.66
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 100 | joint=12.5153 task=12.4457 ppl_loss=6.9526 ppl=1283.83
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 150 | joint=12.5139 task=12.4444 ppl_loss=6.9477 ppl=1237.41
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 200 | joint=12.6839 task=12.6145 ppl_loss=6.9452 ppl=1216.79
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 250 | joint=12.5828 task=12.5132 ppl_loss=6.9546 ppl=1214.72
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 300 | joint=12.7108 task=12.6411 ppl_loss=6.9661 ppl=1241.37
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 350 | joint=12.7151 task=12.6453 ppl_loss=6.9741 ppl=1249.58
# [PEZ λ=0.01 NON-ADV] Epoch 1/5, batch 400 | joint=12.7951 task=12.7253 ppl_loss=6.9798 ppl=1252.86
# [PEZ λ=0.01 NON-ADV] Epoch 1/5 | joint=12.8109 task=12.7409 ppl_loss=6.9938 ppl=1272.61 val_loss=24.4040 val_acc=0.3969 prompt_ppl=805.77
# Prompt: școli gradini bacteriieuticaujourd invata botez senzati galben bacterii Judeţean crore proaspat senzati botezoza unity bilete cătturn asistent DCminuslângă incadrtaxablefidelityvolunteered Suceava 04/2 skippeheymnului senzaticostingiocese incadrrtzNapoca incadr suprafete Sfantceapa suprafete incadr dragostecontinuare gandi senzati școlar footsteps mananc deviation senzati bebelus mancare gasest senzati superioara intrebare accesorii dăruiness aluat gasest senzati summarize incadr Veziintreaga algae vitamin sfânt senzatiopathyNeu summarize invalid gradina urmatoare Județean diferenta Suceavastance frumosivismalter Compensation senzati proaspat Male crestinmunicipiuljavaculoarea senzati amenajatromânii psiho
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 50 | joint=13.0171 task=12.9472 ppl_loss=6.9934 ppl=1230.04
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 100 | joint=12.9105 task=12.8408 ppl_loss=6.9699 ppl=1273.34
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 150 | joint=12.8258 task=12.7560 ppl_loss=6.9797 ppl=1293.40
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 200 | joint=12.7583 task=12.6885 ppl_loss=6.9740 ppl=1279.66
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 250 | joint=12.7655 task=12.6955 ppl_loss=6.9947 ppl=1318.32
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 300 | joint=12.8077 task=12.7379 ppl_loss=6.9841 ppl=1289.14
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 350 | joint=12.7841 task=12.7142 ppl_loss=6.9853 ppl=1292.21
# [PEZ λ=0.01 NON-ADV] Epoch 2/5, batch 400 | joint=12.7328 task=12.6630 ppl_loss=6.9801 ppl=1290.48
# [PEZ λ=0.01 NON-ADV] Epoch 2/5 | joint=12.7503 task=12.6807 ppl_loss=6.9643 ppl=1266.09 val_loss=6.7338 val_acc=0.3783 prompt_ppl=1698.10
# Prompt: gradiniSeverin gradini viteze intreb Monitoringologists pregnancy clasicbiz organizatoriaparut suprafete antrenor vietii nunta urmatoareEinenCopiii reusit unconscious adevarat suprafete Ambassadorinformatiile descarcIMObic inteleg TranslatTek intrebcît teoreticcît solutieCERTloyerpronounced obtine crestinrenz cartofi ciocolatopathieEnsure oferanumarulromânii finanziell situatiicaroraconceivabl senzati spatiu incadrdeutschland suprafete intelegeneeded functioneazaomicssunteti instabilityvier diferentaiscus feasibilityhabitant spalat spatiu teoreticBIT societati Dumnezeu scaun clasic machiaj
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 50 | joint=12.7286 task=12.6592 ppl_loss=6.9385 ppl=1177.28
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 100 | joint=12.6226 task=12.5527 ppl_loss=6.9904 ppl=1233.43
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 150 | joint=12.5032 task=12.4334 ppl_loss=6.9785 ppl=1216.88
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 200 | joint=12.6707 task=12.6011 ppl_loss=6.9553 ppl=1185.36
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 250 | joint=12.7326 task=12.6630 ppl_loss=6.9534 ppl=1184.07
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 300 | joint=12.8562 task=12.7867 ppl_loss=6.9446 ppl=1175.59
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 350 | joint=12.8419 task=12.7725 ppl_loss=6.9420 ppl=1177.90
# [PEZ λ=0.01 NON-ADV] Epoch 3/5, batch 400 | joint=12.8030 task=12.7336 ppl_loss=6.9413 ppl=1174.98
# [PEZ λ=0.01 NON-ADV] Epoch 3/5 | joint=12.7912 task=12.7217 ppl_loss=6.9418 ppl=1173.47 val_loss=16.0665 val_acc=0.3783 prompt_ppl=1164.80
# Prompt: Muzicspans moaleusziehbarläufe proaspatTK prevazut diferenta superioarapears adicacalled gradini inseamnachurch compoziti gradiniuleiulionism gradinivalorileProdusele miscare fructegoricărui inaltime adicalungulobscur gradini proaspat fișier rosiiYes etaj gradinichezkers sticlacada bebelus varsta imunitar bebelusRoyce summarize Hoptralfensivnzo superioarameciul plajlângă clientilor plaj senzor foloseste proaspatunicipiuluicostingbottled amenajat gradini culoare machiajtuftedcît pahartotdeaunaindividualized langa translate mancare situatiiNapoca niciodatafares caldura Brunswick apariti aparitirang proaspat diferenta
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 50 | joint=11.8956 task=11.8258 ppl_loss=6.9847 ppl=1195.18
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 100 | joint=12.6620 task=12.5922 ppl_loss=6.9846 ppl=1174.07
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 150 | joint=12.6951 task=12.6252 ppl_loss=6.9920 ppl=1226.95
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 200 | joint=12.5901 task=12.5205 ppl_loss=6.9616 ppl=1222.37
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 250 | joint=12.6499 task=12.5801 ppl_loss=6.9731 ppl=1232.88
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 300 | joint=12.7195 task=12.6498 ppl_loss=6.9746 ppl=1255.57
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 350 | joint=12.6492 task=12.5795 ppl_loss=6.9748 ppl=1257.86
# [PEZ λ=0.01 NON-ADV] Epoch 4/5, batch 400 | joint=12.6268 task=12.5571 ppl_loss=6.9691 ppl=1248.44
# [PEZ λ=0.01 NON-ADV] Epoch 4/5 | joint=12.6448 task=12.5750 ppl_loss=6.9804 ppl=1257.86 val_loss=8.4458 val_acc=0.3783 prompt_ppl=1085.67
# Prompt: rosii splend mananc linistit reusit linguri gradiniversecosting povești suprafete gradini depasi prevazut bebelus machiaj linguriliquid clientiloruploads gradini disinfect suprafete rugam dimineatascended noastra căt machiajuleiul clientilor machiajportée cérémonie Dragneaceapa trackback paharCharteredcît diferentahaudierecîtriad machiajărăuploadscarora gradini machiajoptimisation suprafete actiuneambogia vizual dimineataDatoritacarora pacate intrebari
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 50 | joint=12.5428 task=12.4726 ppl_loss=7.0167 ppl=1351.73
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 100 | joint=12.3142 task=12.2444 ppl_loss=6.9838 ppl=1277.88
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 150 | joint=12.4935 task=12.4237 ppl_loss=6.9782 ppl=1304.34
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 200 | joint=12.5814 task=12.5113 ppl_loss=7.0148 ppl=1354.12
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 250 | joint=12.5075 task=12.4373 ppl_loss=7.0187 ppl=1346.10
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 300 | joint=12.4853 task=12.4152 ppl_loss=7.0091 ppl=1315.88
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 350 | joint=12.5231 task=12.4532 ppl_loss=6.9843 ppl=1280.14
# [PEZ λ=0.01 NON-ADV] Epoch 5/5, batch 400 | joint=12.5841 task=12.5140 ppl_loss=7.0046 ppl=1300.97
# [PEZ λ=0.01 NON-ADV] Epoch 5/5 | joint=12.5394 task=12.4694 ppl_loss=6.9975 ppl=1300.86 val_loss=11.0437 val_acc=0.3783 prompt_ppl=460.64
# Prompt: județul imbunatati intreb neam suprafetedur proaspat proaspatbakpermalink clienți proaspat gradiniDimensiuni gradini mele gradini proaspat=" suprafete proaspatPracticrith protectie proaspat gradini căt gradini proaspat ciocolatChauffeluminaAsociațiaresemble=> suprafete gradini gradini intelegtoxicKaufentscheidungmunicipiululeiulincat ediți plimb accesorii imprumut incadr gradiniAntiApotheke niciodataDatoritalixlujChauffe accesorii niciodata adica cătambogiaGymnasium bebelus gradinibucuria senzaticomb niciodata pielea suprafete prevazutHôtel gradinilox proaspat senzati somnd:// sanatosjudeţul gradinieutic senzatiPrehaz gradini compozitiuousoidalyahoo], suprafetegasescaffectsolar
#
# === PEZ Non-Adversarial (λ=0.05) ===
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 50 | joint=13.3724 task=13.0208 ppl_loss=7.0335 ppl=1336.20
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 100 | joint=13.1540 task=12.8020 ppl_loss=7.0394 ppl=1368.57
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 150 | joint=13.0887 task=12.7395 ppl_loss=6.9845 ppl=1286.13
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 200 | joint=13.0416 task=12.6925 ppl_loss=6.9826 ppl=1266.88
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 250 | joint=13.0506 task=12.7015 ppl_loss=6.9820 ppl=1265.86
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 300 | joint=13.0673 task=12.7182 ppl_loss=6.9819 ppl=1262.11
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 350 | joint=13.0789 task=12.7300 ppl_loss=6.9784 ppl=1262.14
# [PEZ λ=0.05 NON-ADV] Epoch 1/5, batch 400 | joint=13.0427 task=12.6932 ppl_loss=6.9894 ppl=1278.54
# [PEZ λ=0.05 NON-ADV] Epoch 1/5 | joint=13.0130 task=12.6632 ppl_loss=6.9960 ppl=1279.95 val_loss=6.8089 val_acc=0.3783 prompt_ppl=1402.87
# Prompt: functioneaza cartofi suprafete rosii proaspatither suprafete gradini cautare galben apariti caloriiProduselepong bebelus gradini adica bacterii compozitiambogia gradini gradini ingrijirepoți gradina otherwise gradini trackbackddle linguriOLI proaspat gradini GibsonKK gradini pielii urmeazacîtlângăceputul imunitarhapucc raspuns
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 50 | joint=12.7399 task=12.3887 ppl_loss=7.0227 ppl=1337.12
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 100 | joint=12.6525 task=12.3014 ppl_loss=7.0231 ppl=1282.85
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 150 | joint=12.8529 task=12.5001 ppl_loss=7.0564 ppl=1322.51
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 200 | joint=13.0184 task=12.6647 ppl_loss=7.0729 ppl=1386.71
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 250 | joint=12.9298 task=12.5757 ppl_loss=7.0804 ppl=1388.05
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 300 | joint=12.8802 task=12.5275 ppl_loss=7.0554 ppl=1346.34
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 350 | joint=12.9144 task=12.5613 ppl_loss=7.0624 ppl=1349.23
# [PEZ λ=0.05 NON-ADV] Epoch 2/5, batch 400 | joint=12.9004 task=12.5479 ppl_loss=7.0504 ppl=1337.04
# [PEZ λ=0.05 NON-ADV] Epoch 2/5 | joint=12.8930 task=12.5410 ppl_loss=7.0390 ppl=1332.07 val_loss=16.4382 val_acc=0.4862 prompt_ppl=927.04
# Prompt: odata șoferntsprechend nebunmpf incadrémi creier neam proaspatlujbushes suprafete societati plimbrmândrmând adica bani machiaj proaspat mirosçon freceur intrebari Eminescu cumpara aluat taiatbotcompatible proaspatluti fructelute genunchi dorint răc mananc bebelus suprafetermândchirurgie adica reprezintaend suprafeteException senzatiGästenMuzeul dotatlixtherapeutrmândlujvetiizari gradina sanatatewürwür ramane compoziti nostriweichenatoire proaspatSpr vietii proaspatspüleux Eminescurous societati bacterii biciclet inferioar pastra compozitioir incadr fructe scaun russe senzatilujignongresesel frumoasapoți totusiinformatiilenehmen bleachdurconfig
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 50 | joint=12.7679 task=12.4235 ppl_loss=6.8866 ppl=1120.10
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 100 | joint=13.0028 task=12.6575 ppl_loss=6.9062 ppl=1142.30
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 150 | joint=13.0851 task=12.7391 ppl_loss=6.9201 ppl=1206.41
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 200 | joint=13.0208 task=12.6741 ppl_loss=6.9333 ppl=1197.33
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 250 | joint=12.9078 task=12.5610 ppl_loss=6.9370 ppl=1206.13
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 300 | joint=12.8196 task=12.4731 ppl_loss=6.9300 ppl=1187.20
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 350 | joint=12.9129 task=12.5662 ppl_loss=6.9345 ppl=1188.96
# [PEZ λ=0.05 NON-ADV] Epoch 3/5, batch 400 | joint=12.9579 task=12.6104 ppl_loss=6.9514 ppl=1216.56
# [PEZ λ=0.05 NON-ADV] Epoch 3/5 | joint=12.8990 task=12.5516 ppl_loss=6.9484 ppl=1208.20 val_loss=18.3884 val_acc=0.4560 prompt_ppl=1726.80
# Prompt: iezmale intreb diferenta vizualiztinăoricine nave Veziinformatiilefidelityanimationnacmunicipiul ieftin frumoaseCopiiiAsociația=" Elvis machiajgazgmail emoțiizanteuticatory adevarat termicfrac aggrgardinen incadr Believe suprafete gasineig neam=> solutiiaciailleimmer locuintevalent ciocolat pielii diferenta sunetfuz nebun poêladorjudețul accesorii Bro tauoricine yesuploadssimo joy senzati sunethrs compoziti senzati bingo adjective Pub Inspiration diferenta botezoresknowpli preot goodness zodiouille sunetroclveshreneuticmentalchou obtinutcatcher lucrarikrautcît abonament senzatitory(0) frumoasavideo aluat sarbatori
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 50 | joint=12.0364 task=11.6969 ppl_loss=6.7900 ppl=1005.80
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 100 | joint=12.7816 task=12.4378 ppl_loss=6.8758 ppl=1198.74
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 150 | joint=12.7795 task=12.4360 ppl_loss=6.8686 ppl=1161.26
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 200 | joint=12.8310 task=12.4859 ppl_loss=6.9019 ppl=1198.94
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 250 | joint=12.7440 task=12.3979 ppl_loss=6.9219 ppl=1231.09
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 300 | joint=12.7368 task=12.3896 ppl_loss=6.9453 ppl=1241.73
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 350 | joint=12.8415 task=12.4940 ppl_loss=6.9495 ppl=1248.26
# [PEZ λ=0.05 NON-ADV] Epoch 4/5, batch 400 | joint=12.8629 task=12.5149 ppl_loss=6.9599 ppl=1261.28
# [PEZ λ=0.05 NON-ADV] Epoch 4/5 | joint=12.8631 task=12.5150 ppl_loss=6.9624 ppl=1257.85 val_loss=13.4888 val_acc=0.3810 prompt_ppl=1865.24
# Prompt: frunze ($where immunity gradini proaspattanzmonies compoziti Stadi gasestÜbungen proaspattial obtine Lernpost machiajcongratulatlungulcosm niciodatapreferably prevazut Organis circulatiincatoubliapa poatjudețulost gasestturnedcontinuareurmatoareleesquermând gaming modificariwe rafina cadouri imprumutsigsunteti niciodata vindec proaspat organismuluiFERRAFcosy heatingrepairing achizitiforestrymonies syn apart bebeluscomb imprumutBiserica suprafete bebeluswohl senzati senzati gradini manancIV cautarezam German cuir diferenta Particular Instead Efficiency compoziti stii senzati foloseste centuries linguri sarbatoriabsolu://Generally constructiiBiserica undertakinguous aplicatii incadrcryptocurrencies GST Sell
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 50 | joint=13.4756 task=13.1255 ppl_loss=7.0014 ppl=1262.77
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 100 | joint=13.3299 task=12.9818 ppl_loss=6.9615 ppl=1211.74
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 150 | joint=13.2374 task=12.8875 ppl_loss=6.9969 ppl=1271.62
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 200 | joint=13.2381 task=12.8878 ppl_loss=7.0048 ppl=1272.76
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 250 | joint=13.2067 task=12.8573 ppl_loss=6.9897 ppl=1254.48
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 300 | joint=13.1885 task=12.8384 ppl_loss=7.0026 ppl=1267.30
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 350 | joint=13.0800 task=12.7297 ppl_loss=7.0063 ppl=1270.81
# [PEZ λ=0.05 NON-ADV] Epoch 5/5, batch 400 | joint=12.9794 task=12.6293 ppl_loss=7.0013 ppl=1263.64
# [PEZ λ=0.05 NON-ADV] Epoch 5/5 | joint=12.9820 task=12.6320 ppl_loss=6.9995 ppl=1259.65 val_loss=5.9348 val_acc=0.3783 prompt_ppl=879.63
# Prompt: gradiniănă pamant abonamentoane aplicatii taiattriggering pretul geltenudierfolg constructii achizitiona Dumnezeu suprafete Graflucreazaambogia aveti siguranta iarnă căt functioneazaakt linguri Eminescu clientilor taiat Constanțacarorahâtechette cumpara aluatuga Timișoaramonetiz Brașovbeneficiar footstepsgardinendatele galben Brașovrith usoara piept diferenta praguffectedbucuria medicul multumesc incadr taiat rugam înscrislism duminicaDatorita bumbaculeiultină clientii
#
# === PEZ Non-Adversarial (λ=0.1) ===
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 50 | joint=13.3760 task=12.6915 ppl_loss=6.8452 ppl=1139.21
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 100 | joint=13.3735 task=12.6786 ppl_loss=6.9490 ppl=1198.39
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 150 | joint=13.3955 task=12.7014 ppl_loss=6.9409 ppl=1206.06
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 200 | joint=13.3434 task=12.6499 ppl_loss=6.9348 ppl=1194.08
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 250 | joint=13.2547 task=12.5609 ppl_loss=6.9377 ppl=1196.34
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 300 | joint=13.2221 task=12.5262 ppl_loss=6.9587 ppl=1231.98
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 350 | joint=13.2328 task=12.5383 ppl_loss=6.9455 ppl=1208.45
# [PEZ λ=0.1 NON-ADV] Epoch 1/5, batch 400 | joint=13.1883 task=12.4918 ppl_loss=6.9648 ppl=1237.23
# [PEZ λ=0.1 NON-ADV] Epoch 1/5 | joint=13.2085 task=12.5116 ppl_loss=6.9693 ppl=1242.22 val_loss=15.5990 val_acc=0.5312 prompt_ppl=1540.84
# Prompt: contemporan invataCHE șoferHK chimic proaspat linguriMuzeulseid tablou gasest proaspat incadrphro gradiniktion lucrari proaspat formularul Sfant intreb ieftinchez Shark sunetcate yes RadiçonSocietatea suprafetetek gradini psihocîtopicursOrice caldura proaspat gradini cadouri proaspat gradini Ghi gradiniajungiolltestflammApothekelustintuitatori diferentasmelling sunetchtelucreazajudeţulirkcaroraCopiiirtzKönnentiti proaspathtml bebelusUI linguri Multumesc Citraisonswohl renuntGGcatenius societati prevazut compoziti linguri incadr vein miroschezxxlucht bebelus incadr vizual moalecili inaltime incadrinformatiile renunt DeclaTélécharger
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 50 | joint=13.3922 task=12.6858 ppl_loss=7.0645 ppl=1403.96
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 100 | joint=13.4435 task=12.7448 ppl_loss=6.9867 ppl=1267.27
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 150 | joint=13.6017 task=12.9013 ppl_loss=7.0031 ppl=1259.22
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 200 | joint=13.5312 task=12.8334 ppl_loss=6.9780 ppl=1243.04
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 250 | joint=13.5709 task=12.8729 ppl_loss=6.9807 ppl=1247.91
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 300 | joint=13.4902 task=12.7913 ppl_loss=6.9887 ppl=1249.09
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 350 | joint=13.4953 task=12.7954 ppl_loss=6.9989 ppl=1279.18
# [PEZ λ=0.1 NON-ADV] Epoch 2/5, batch 400 | joint=13.4053 task=12.7066 ppl_loss=6.9871 ppl=1264.45
# [PEZ λ=0.1 NON-ADV] Epoch 2/5 | joint=13.4393 task=12.7401 ppl_loss=6.9919 ppl=1277.93 val_loss=6.4125 val_acc=0.3832 prompt_ppl=592.92
# Prompt: compoziti viata prevazutintreaga amintiri neam proaspat spuihren vietii societati incadrturm belonggrantingSocietateatôtcîtprouvé spalat mărturianii clientilorPalatul mancare adica rememberedDimensiuni vitezeismegardinenvestcît aluatDimensiunieldrip diferenta proaspatDimensiuni reprezinta proaspat suprafete botez pieliigetiatadisplakeDatoritaTotusivada cladiriNOVA Sfant proaspat proaspat compoziti societati locuintegues @ Neo lucrarirennen suprafeteceputul niciodata urmariPublic răc cablu metalic query privestcîtDimensiuni proaspat proaspat diferenta sticla
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 50 | joint=13.0967 task=12.3979 ppl_loss=6.9886 ppl=1262.70
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 100 | joint=13.0111 task=12.3112 ppl_loss=6.9988 ppl=1248.50
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 150 | joint=12.9707 task=12.2694 ppl_loss=7.0133 ppl=1296.82
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 200 | joint=13.1140 task=12.4120 ppl_loss=7.0203 ppl=1506.47
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 250 | joint=13.2133 task=12.5119 ppl_loss=7.0144 ppl=1452.44
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 300 | joint=13.2187 task=12.5171 ppl_loss=7.0158 ppl=1414.57
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 350 | joint=13.3296 task=12.6305 ppl_loss=6.9914 ppl=1371.41
# [PEZ λ=0.1 NON-ADV] Epoch 3/5, batch 400 | joint=13.3322 task=12.6331 ppl_loss=6.9913 ppl=1364.60
# [PEZ λ=0.1 NON-ADV] Epoch 3/5 | joint=13.3634 task=12.6646 ppl_loss=6.9881 ppl=1342.67 val_loss=6.3571 val_acc=0.3783 prompt_ppl=1001.17
# Prompt: sticla Neg suprafeteicillin căt incadr gasest suprafete prevazut strings usorceputulinformatiile Eminescu galben personalizatProdusele adica compoziti sticlancing functioneazaWEurmatoarele spalat bebelusveux cătKaufentscheidung bebelus proceedings député situatii inaltime taiat spalatrefundable rosiimputation gradini solutieops spalat poaturmatoarele spalat raspunsCopiiiunta căt desfaso aveti linguri accesorii vizualiz taiatSymptom Iaşi masina mănânc gradinichal:// bebelusgone psihogasesc summarize niciodata incredere summarize Eminescu Romaniaioceseeanu gradini suprafetecît Clujlubzugreifen ingrijire
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 50 | joint=13.4179 task=12.7218 ppl_loss=6.9616 ppl=1237.70
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 100 | joint=13.1951 task=12.4990 ppl_loss=6.9616 ppl=1211.21
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 150 | joint=13.2541 task=12.5582 ppl_loss=6.9589 ppl=1202.67
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 200 | joint=13.2985 task=12.6023 ppl_loss=6.9617 ppl=1209.48
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 250 | joint=13.2261 task=12.5301 ppl_loss=6.9598 ppl=1203.60
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 300 | joint=13.2665 task=12.5712 ppl_loss=6.9537 ppl=1190.67
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 350 | joint=13.2612 task=12.5649 ppl_loss=6.9626 ppl=1219.53
# [PEZ λ=0.1 NON-ADV] Epoch 4/5, batch 400 | joint=13.2695 task=12.5734 ppl_loss=6.9616 ppl=1220.94
# [PEZ λ=0.1 NON-ADV] Epoch 4/5 | joint=13.2971 task=12.6013 ppl_loss=6.9577 ppl=1217.69 val_loss=13.1684 val_acc=0.3783 prompt_ppl=1350.69
# Prompt: archiveneuve diferentaajungiaison compozitivregioVal scenabourgeoisouette urmeaza TimișoaraParjudeţul foloseste prevazut traduc arhitect Giurgiu urmeazabildung proprietati compozitirote Vezi Pla paharafli formularuloxyaggregatifies senzatidouceur multumescchten ofera paralelverhalten incercat meciurigasescmacherclerosisarchitecte incercatyes taiat9001inne(0) sustine caci proaspatflore vizualiz injustice senzatiwesengmailliga rêve incadr Eminescu jumatate caldurahov trackback reconsider mananc amortizierungulescu echorackartă praf manevr restart Task spalat proaspat2010oileaidineOnlineOh iluminat prevazuttinăWürttembergRIT ISBNRie autoHIoileaefectuare
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 50 | joint=13.3653 task=12.6665 ppl_loss=6.9880 ppl=1254.72
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 100 | joint=13.6022 task=12.9070 ppl_loss=6.9524 ppl=1181.86
# [PEZ λ=0.1 NON-ADV] Epoch 5/5, batch 150 | joint=13.5511 task=12.8557 ppl_loss=6.9541 ppl=1207.55

# %%
# PEZ runs over lambda grid
pez_runs_adv = []
for lam in [0.0, 0.01, 0.05, 0.1, 0.5, 1.0]:
    print(f"\n=== PEZ Adversarial (λ={lam}) ===")
    pez_adv = train_pez(
        cfg,
        tokenizer,
        gpt2_model,
        gpt2_tokenizer,
        train_dl,
        val_dl,
        lambda_ppl=lam,
        adversarial=True,
    )
    pez_runs_adv.append(("pez_adv", lam, pez_adv))
# Out:
# === PEZ Adversarial (λ=0.0) ===
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 50 | joint=-15.9456 task=15.9456 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 100 | joint=-16.0638 task=16.0638 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 150 | joint=-16.0170 task=16.0170 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 200 | joint=-16.0154 task=16.0154 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 250 | joint=-16.0629 task=16.0629 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 300 | joint=-16.1652 task=16.1652 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 350 | joint=-16.1052 task=16.1052 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 400 | joint=-16.1009 task=16.1009 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 450 | joint=-16.1133 task=16.1133 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 500 | joint=-16.0776 task=16.0776 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3, batch 550 | joint=-16.0229 task=16.0229 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 1/3 | joint=-15.9772 task=15.9772 ppl_loss=0.0000 ppl=0.00 val_loss=18.8572 val_acc=0.5719 prompt_ppl=0.00
# Prompt: chezSfântul incadr rosii formularulnectgardinen suprafeteiscuspremise
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 50 | joint=-15.6779 task=15.6779 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 100 | joint=-16.0625 task=16.0625 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 150 | joint=-16.0266 task=16.0266 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 200 | joint=-16.1443 task=16.1443 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 250 | joint=-16.0124 task=16.0124 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 300 | joint=-16.0798 task=16.0798 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 350 | joint=-16.0677 task=16.0677 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 400 | joint=-16.0319 task=16.0319 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 450 | joint=-16.0071 task=16.0071 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 500 | joint=-15.9788 task=15.9788 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3, batch 550 | joint=-15.9786 task=15.9786 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 2/3 | joint=-15.9576 task=15.9576 ppl_loss=0.0000 ppl=0.00 val_loss=19.0621 val_acc=0.3875 prompt_ppl=0.00
# Prompt: arna Observatory footstepsNapoca bebelus amintiri raspunsign herself suprafata
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 50 | joint=-16.0574 task=16.0574 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 100 | joint=-16.1859 task=16.1859 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 150 | joint=-16.0040 task=16.0040 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 200 | joint=-16.0446 task=16.0446 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 250 | joint=-15.9915 task=15.9915 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 300 | joint=-16.0067 task=16.0067 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 350 | joint=-15.9941 task=15.9941 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 400 | joint=-15.9968 task=15.9968 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 450 | joint=-16.0034 task=16.0034 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 500 | joint=-16.0480 task=16.0480 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3, batch 550 | joint=-16.0650 task=16.0650 ppl_loss=0.0000 ppl=0.00
# [PEZ λ=0.0 ADV] Epoch 3/3 | joint=-16.0744 task=16.0744 ppl_loss=0.0000 ppl=0.00 val_loss=18.6065 val_acc=0.4168 prompt_ppl=0.00
# Prompt: costing căt Famous sticla?" suprafete Plastic totusi unlike emoți
#
# === PEZ Adversarial (λ=0.01) ===
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 50 | joint=-15.7346 task=15.8226 ppl_loss=8.8027 ppl=9354.15
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 100 | joint=-15.9781 task=16.0650 ppl_loss=8.6903 ppl=8945.33
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 150 | joint=-15.7811 task=15.8688 ppl_loss=8.7716 ppl=10221.94
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 200 | joint=-15.8223 task=15.9100 ppl_loss=8.7677 ppl=11800.06
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 250 | joint=-15.8292 task=15.9171 ppl_loss=8.7888 ppl=11343.65
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 300 | joint=-15.9795 task=16.0671 ppl_loss=8.7668 ppl=11046.54
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 350 | joint=-15.9688 task=16.0563 ppl_loss=8.7500 ppl=10750.82
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 400 | joint=-15.8393 task=15.9270 ppl_loss=8.7767 ppl=10837.64
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 450 | joint=-15.8755 task=15.9631 ppl_loss=8.7654 ppl=10964.21
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 500 | joint=-15.8361 task=15.9238 ppl_loss=8.7726 ppl=10814.03
# [PEZ λ=0.01 ADV] Epoch 1/3, batch 550 | joint=-15.8584 task=15.9460 ppl_loss=8.7578 ppl=10711.41
# [PEZ λ=0.01 ADV] Epoch 1/3 | joint=-15.9007 task=15.9882 ppl_loss=8.7475 ppl=11473.50 val_loss=19.6278 val_acc=0.3976 prompt_ppl=4024.64
# Prompt: termicscriereTélécharger expoziți compoziti Lauderdalerest Charge torchnce
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 50 | joint=-15.3195 task=15.4074 ppl_loss=8.7945 ppl=11483.20
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 100 | joint=-15.5680 task=15.6551 ppl_loss=8.7113 ppl=11209.59
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 150 | joint=-15.6107 task=15.6970 ppl_loss=8.6257 ppl=10200.87
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 200 | joint=-15.7281 task=15.8142 ppl_loss=8.6184 ppl=10440.83
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 250 | joint=-15.9329 task=16.0192 ppl_loss=8.6372 ppl=10270.07
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 300 | joint=-15.9558 task=16.0427 ppl_loss=8.6925 ppl=10824.88
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 350 | joint=-15.9291 task=16.0159 ppl_loss=8.6849 ppl=10547.01
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 400 | joint=-15.9070 task=15.9937 ppl_loss=8.6658 ppl=10130.82
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 450 | joint=-15.8952 task=15.9820 ppl_loss=8.6835 ppl=10161.47
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 500 | joint=-15.9226 task=16.0094 ppl_loss=8.6813 ppl=9928.98
# [PEZ λ=0.01 ADV] Epoch 2/3, batch 550 | joint=-15.9245 task=16.0113 ppl_loss=8.6811 ppl=10086.30
# [PEZ λ=0.01 ADV] Epoch 2/3 | joint=-15.9195 task=16.0063 ppl_loss=8.6717 ppl=9929.87 val_loss=20.4659 val_acc=0.3801 prompt_ppl=1056.78
# Prompt: senzati imunitar senzati senzati achizitiuploads gradini cunoastecît senzati
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 50 | joint=-15.9345 task=16.0227 ppl_loss=8.8179 ppl=9575.67
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 100 | joint=-16.0757 task=16.1630 ppl_loss=8.7392 ppl=9163.12
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 150 | joint=-15.9681 task=16.0553 ppl_loss=8.7192 ppl=9246.52
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 200 | joint=-15.8798 task=15.9669 ppl_loss=8.7057 ppl=9186.45
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 250 | joint=-15.8851 task=15.9720 ppl_loss=8.6880 ppl=9062.72
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 300 | joint=-15.8425 task=15.9295 ppl_loss=8.7032 ppl=9159.63
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 350 | joint=-15.9139 task=16.0011 ppl_loss=8.7231 ppl=9767.15
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 400 | joint=-15.8457 task=15.9330 ppl_loss=8.7238 ppl=9805.80
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 450 | joint=-15.8598 task=15.9467 ppl_loss=8.6890 ppl=9632.19
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 500 | joint=-15.8209 task=15.9080 ppl_loss=8.7072 ppl=9661.47
# [PEZ λ=0.01 ADV] Epoch 3/3, batch 550 | joint=-15.7961 task=15.8833 ppl_loss=8.7146 ppl=9665.61
# [PEZ λ=0.01 ADV] Epoch 3/3 | joint=-15.7930 task=15.8802 ppl_loss=8.7168 ppl=9678.61 val_loss=18.2684 val_acc=0.3783 prompt_ppl=2189.04
# Prompt: praf prevazut gradini caldura clientilor clientilor pastraone totirival
#
# === PEZ Adversarial (λ=0.05) ===
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 50 | joint=-15.0697 task=15.5083 ppl_loss=8.7715 ppl=10956.92
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 100 | joint=-15.2260 task=15.6651 ppl_loss=8.7834 ppl=11091.13
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 150 | joint=-15.5417 task=15.9782 ppl_loss=8.7293 ppl=10800.58
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 200 | joint=-15.3962 task=15.8331 ppl_loss=8.7380 ppl=11185.09
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 250 | joint=-15.4367 task=15.8742 ppl_loss=8.7493 ppl=11123.92
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 300 | joint=-15.5853 task=16.0225 ppl_loss=8.7447 ppl=11278.48
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 350 | joint=-15.5016 task=15.9380 ppl_loss=8.7272 ppl=11163.64
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 400 | joint=-15.4474 task=15.8840 ppl_loss=8.7312 ppl=11158.74
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 450 | joint=-15.4934 task=15.9307 ppl_loss=8.7449 ppl=11132.49
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 500 | joint=-15.4797 task=15.9176 ppl_loss=8.7583 ppl=11225.81
# [PEZ λ=0.05 ADV] Epoch 1/3, batch 550 | joint=-15.4772 task=15.9152 ppl_loss=8.7608 ppl=11111.55
# [PEZ λ=0.05 ADV] Epoch 1/3 | joint=-15.4870 task=15.9244 ppl_loss=8.7483 ppl=10863.52 val_loss=17.4244 val_acc=0.3783 prompt_ppl=2147.86
# Prompt: hypothesis senzatiummingcît Covenant senzatiMuzeulDimensiuni solutie rosii
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 50 | joint=-15.0391 task=15.4708 ppl_loss=8.6344 ppl=10917.22
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 100 | joint=-15.1997 task=15.6287 ppl_loss=8.5795 ppl=9274.74
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 150 | joint=-15.3188 task=15.7488 ppl_loss=8.6006 ppl=9307.45
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 200 | joint=-15.4785 task=15.9100 ppl_loss=8.6300 ppl=9547.73
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 250 | joint=-15.4121 task=15.8441 ppl_loss=8.6400 ppl=11460.34
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 300 | joint=-15.4568 task=15.8889 ppl_loss=8.6413 ppl=11472.62
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 350 | joint=-15.4143 task=15.8449 ppl_loss=8.6120 ppl=10841.98
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 400 | joint=-15.3960 task=15.8270 ppl_loss=8.6204 ppl=10776.02
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 450 | joint=-15.3785 task=15.8089 ppl_loss=8.6087 ppl=10461.46
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 500 | joint=-15.3796 task=15.8116 ppl_loss=8.6400 ppl=10542.78
# [PEZ λ=0.05 ADV] Epoch 2/3, batch 550 | joint=-15.3786 task=15.8117 ppl_loss=8.6616 ppl=10695.38
# [PEZ λ=0.05 ADV] Epoch 2/3 | joint=-15.3981 task=15.8311 ppl_loss=8.6610 ppl=10543.13 val_loss=13.6873 val_acc=0.3893 prompt_ppl=7351.03
# Prompt: Para summarizelox lucrari sticla prevazutchir linguri camionhaudiere
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 50 | joint=-15.9252 task=16.3519 ppl_loss=8.5341 ppl=10144.90
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 100 | joint=-15.9095 task=16.3370 ppl_loss=8.5502 ppl=9099.61
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 150 | joint=-16.0951 task=16.5218 ppl_loss=8.5339 ppl=8779.98
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 200 | joint=-15.8415 task=16.2687 ppl_loss=8.5451 ppl=9034.06
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 250 | joint=-15.7845 task=16.2128 ppl_loss=8.5667 ppl=8981.10
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 300 | joint=-15.7028 task=16.1328 ppl_loss=8.6000 ppl=9681.55
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 350 | joint=-15.7468 task=16.1761 ppl_loss=8.5868 ppl=9386.30
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 400 | joint=-15.6932 task=16.1237 ppl_loss=8.6086 ppl=9561.06
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 450 | joint=-15.6609 task=16.0912 ppl_loss=8.6067 ppl=9522.95
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 500 | joint=-15.6497 task=16.0801 ppl_loss=8.6080 ppl=9429.24
# [PEZ λ=0.05 ADV] Epoch 3/3, batch 550 | joint=-15.6528 task=16.0828 ppl_loss=8.5999 ppl=9352.40
# [PEZ λ=0.05 ADV] Epoch 3/3 | joint=-15.6132 task=16.0439 ppl_loss=8.6146 ppl=9396.86 val_loss=20.4120 val_acc=0.4456 prompt_ppl=16442.28
# Prompt: stunnedney compozitiApplicantsreclining**dial Leicestercyangrav
#
# === PEZ Adversarial (λ=0.1) ===
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 50 | joint=-14.9487 task=15.8154 ppl_loss=8.6675 ppl=10538.13
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 100 | joint=-14.9770 task=15.8453 ppl_loss=8.6830 ppl=9831.42
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 150 | joint=-15.0899 task=15.9563 ppl_loss=8.6642 ppl=9127.10
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 200 | joint=-15.0871 task=15.9611 ppl_loss=8.7405 ppl=10289.52
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 250 | joint=-15.1607 task=16.0358 ppl_loss=8.7511 ppl=10862.69
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 300 | joint=-15.1044 task=15.9816 ppl_loss=8.7715 ppl=11117.20
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 350 | joint=-15.2071 task=16.0834 ppl_loss=8.7634 ppl=11337.41
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 400 | joint=-15.1434 task=16.0182 ppl_loss=8.7487 ppl=11324.52
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 450 | joint=-15.1528 task=16.0280 ppl_loss=8.7526 ppl=11372.69
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 500 | joint=-15.1657 task=16.0428 ppl_loss=8.7715 ppl=11632.28
# [PEZ λ=0.1 ADV] Epoch 1/3, batch 550 | joint=-15.1740 task=16.0501 ppl_loss=8.7613 ppl=11499.10
# [PEZ λ=0.1 ADV] Epoch 1/3 | joint=-15.1955 task=16.0705 ppl_loss=8.7504 ppl=11505.06 val_loss=18.5422 val_acc=0.5440 prompt_ppl=4286.02
# Prompt: incadr taiat camion poêl senzati culoriIFF spumambogia Suceava
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 50 | joint=-15.3495 task=16.2175 ppl_loss=8.6800 ppl=9428.61
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 100 | joint=-15.2121 task=16.0850 ppl_loss=8.7286 ppl=10618.76
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 150 | joint=-15.3385 task=16.2130 ppl_loss=8.7450 ppl=11157.36
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 200 | joint=-15.3347 task=16.2082 ppl_loss=8.7355 ppl=10594.30
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 250 | joint=-15.2703 task=16.1446 ppl_loss=8.7431 ppl=10625.70
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 300 | joint=-15.2424 task=16.1143 ppl_loss=8.7193 ppl=10206.86
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 350 | joint=-15.2209 task=16.0931 ppl_loss=8.7218 ppl=10869.20
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 400 | joint=-15.1706 task=16.0422 ppl_loss=8.7158 ppl=10520.10
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 450 | joint=-15.2205 task=16.0896 ppl_loss=8.6907 ppl=10314.18
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 500 | joint=-15.1822 task=16.0514 ppl_loss=8.6917 ppl=10331.42
# [PEZ λ=0.1 ADV] Epoch 2/3, batch 550 | joint=-15.1643 task=16.0339 ppl_loss=8.6964 ppl=10300.84
# [PEZ λ=0.1 ADV] Epoch 2/3 | joint=-15.2062 task=16.0772 ppl_loss=8.7102 ppl=10437.52 val_loss=13.4262 val_acc=0.3786 prompt_ppl=3067.95
# Prompt: Datorita Hollow cumpara rosii fisierempre query vizual fișier proprietati
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 50 | joint=-14.6511 task=15.5439 ppl_loss=8.9279 ppl=12131.51
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 100 | joint=-14.9934 task=15.8746 ppl_loss=8.8130 ppl=12338.29
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 150 | joint=-14.9688 task=15.8402 ppl_loss=8.7140 ppl=11120.82
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 200 | joint=-14.9479 task=15.8170 ppl_loss=8.6911 ppl=10573.23
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 250 | joint=-14.8905 task=15.7598 ppl_loss=8.6928 ppl=10250.47
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 300 | joint=-14.8453 task=15.7178 ppl_loss=8.7252 ppl=10606.88
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 350 | joint=-14.8811 task=15.7570 ppl_loss=8.7588 ppl=11997.01
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 400 | joint=-14.8875 task=15.7646 ppl_loss=8.7712 ppl=12172.34
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 450 | joint=-14.9792 task=15.8544 ppl_loss=8.7512 ppl=11914.16
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 500 | joint=-14.9605 task=15.8353 ppl_loss=8.7479 ppl=11762.94
# [PEZ λ=0.1 ADV] Epoch 3/3, batch 550 | joint=-14.9884 task=15.8632 ppl_loss=8.7485 ppl=11415.01
# [PEZ λ=0.1 ADV] Epoch 3/3 | joint=-15.0242 task=15.8974 ppl_loss=8.7318 ppl=11209.18 val_loss=19.4270 val_acc=0.3979 prompt_ppl=16234.79
# Prompt: Cyber Dayscosting mancare assureddium pharmacist laboratories suprafete producator
#
# === PEZ Adversarial (λ=0.5) ===
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 50 | joint=-11.1572 task=15.5658 ppl_loss=8.8174 ppl=11501.19
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 100 | joint=-11.3129 task=15.7180 ppl_loss=8.8101 ppl=11236.19
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 150 | joint=-11.2870 task=15.7065 ppl_loss=8.8390 ppl=11156.51
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 200 | joint=-11.2247 task=15.6247 ppl_loss=8.8000 ppl=10837.26
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 250 | joint=-11.3135 task=15.7009 ppl_loss=8.7749 ppl=10589.94
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 300 | joint=-11.5271 task=15.8915 ppl_loss=8.7287 ppl=9957.82
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 350 | joint=-11.4624 task=15.8319 ppl_loss=8.7390 ppl=10127.92
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 400 | joint=-11.4991 task=15.8588 ppl_loss=8.7194 ppl=10139.06
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 450 | joint=-11.4638 task=15.8225 ppl_loss=8.7173 ppl=10474.68
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 500 | joint=-11.4489 task=15.8152 ppl_loss=8.7325 ppl=10544.03
# [PEZ λ=0.5 ADV] Epoch 1/3, batch 550 | joint=-11.4395 task=15.8133 ppl_loss=8.7478 ppl=11026.82
# [PEZ λ=0.5 ADV] Epoch 1/3 | joint=-11.4481 task=15.8294 ppl_loss=8.7626 ppl=11046.25 val_loss=19.3693 val_acc=0.3979 prompt_ppl=2671.77
# Prompt: Muzeul compoziti frigiderhänge achievable senzatikrautinformatiile prevazut updated
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 50 | joint=-11.4728 task=15.8685 ppl_loss=8.7913 ppl=36019.31
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 100 | joint=-11.4579 task=15.8139 ppl_loss=8.7121 ppl=22049.54
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 150 | joint=-11.4340 task=15.8053 ppl_loss=8.7426 ppl=18535.42
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 200 | joint=-11.4699 task=15.8203 ppl_loss=8.7008 ppl=16723.06
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 250 | joint=-11.6257 task=15.9678 ppl_loss=8.6843 ppl=15086.98
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 300 | joint=-11.5291 task=15.8894 ppl_loss=8.7207 ppl=15219.24
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 350 | joint=-11.4970 task=15.8567 ppl_loss=8.7194 ppl=14566.46
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 400 | joint=-11.5416 task=15.9102 ppl_loss=8.7372 ppl=14904.34
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 450 | joint=-11.4867 task=15.8548 ppl_loss=8.7363 ppl=14285.63
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 500 | joint=-11.5574 task=15.9144 ppl_loss=8.7141 ppl=13614.36
# [PEZ λ=0.5 ADV] Epoch 2/3, batch 550 | joint=-11.6055 task=15.9617 ppl_loss=8.7123 ppl=13412.67
# [PEZ λ=0.5 ADV] Epoch 2/3 | joint=-11.5810 task=15.9408 ppl_loss=8.7196 ppl=13372.14 val_loss=20.2654 val_acc=0.3783 prompt_ppl=1951.81
# Prompt: hoc incercatulescu ciocolatnumarul ThomsonDatoritapartenerii intreb kilogram
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 50 | joint=-12.0289 task=16.3449 ppl_loss=8.6318 ppl=8772.04
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 100 | joint=-11.6002 task=16.0079 ppl_loss=8.8153 ppl=12802.02
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 150 | joint=-11.5145 task=15.9004 ppl_loss=8.7717 ppl=11656.43
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 200 | joint=-11.6038 task=15.9711 ppl_loss=8.7347 ppl=11167.63
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 250 | joint=-11.6038 task=15.9814 ppl_loss=8.7551 ppl=11417.86
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 300 | joint=-11.7641 task=16.1318 ppl_loss=8.7354 ppl=10947.51
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 350 | joint=-11.7800 task=16.1552 ppl_loss=8.7503 ppl=11577.89
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 400 | joint=-11.7051 task=16.0800 ppl_loss=8.7497 ppl=11559.08
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 450 | joint=-11.6649 task=16.0385 ppl_loss=8.7472 ppl=11384.90
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 500 | joint=-11.7068 task=16.0773 ppl_loss=8.7411 ppl=11260.30
# [PEZ λ=0.5 ADV] Epoch 3/3, batch 550 | joint=-11.6761 task=16.0443 ppl_loss=8.7364 ppl=11511.84
# [PEZ λ=0.5 ADV] Epoch 3/3 | joint=-11.6640 task=16.0269 ppl_loss=8.7259 ppl=11341.33 val_loss=20.8760 val_acc=0.3908 prompt_ppl=8645.68
# Prompt: pan chlorinechezcône moale Falconcifra 04/2 pretulfoli
#
# === PEZ Adversarial (λ=1.0) ===
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 50 | joint=-6.7601 task=15.6565 ppl_loss=8.8964 ppl=15227.31
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 100 | joint=-6.7909 task=15.6857 ppl_loss=8.8948 ppl=13853.82
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 150 | joint=-6.9429 task=15.7644 ppl_loss=8.8215 ppl=12398.79
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 200 | joint=-6.9458 task=15.7396 ppl_loss=8.7938 ppl=12075.23
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 250 | joint=-7.0673 task=15.8810 ppl_loss=8.8137 ppl=12895.24
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 300 | joint=-7.0007 task=15.8367 ppl_loss=8.8360 ppl=12559.90
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 350 | joint=-7.0370 task=15.8523 ppl_loss=8.8153 ppl=12007.68
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 400 | joint=-7.0347 task=15.8378 ppl_loss=8.8031 ppl=11711.98
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 450 | joint=-7.0328 task=15.8309 ppl_loss=8.7981 ppl=11919.88
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 500 | joint=-7.1067 task=15.8868 ppl_loss=8.7800 ppl=11666.91
# [PEZ λ=1.0 ADV] Epoch 1/3, batch 550 | joint=-7.0846 task=15.8782 ppl_loss=8.7936 ppl=11678.08
# [PEZ λ=1.0 ADV] Epoch 1/3 | joint=-7.1249 task=15.9104 ppl_loss=8.7854 ppl=11520.28 val_loss=19.5662 val_acc=0.5917 prompt_ppl=2886.21
# Prompt: adventchalkettografickrauthoc scrisodonti incadr Eminescu
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 50 | joint=-7.0296 task=15.6978 ppl_loss=8.6682 ppl=8908.76
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 100 | joint=-7.2213 task=15.9083 ppl_loss=8.6871 ppl=9434.80
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 150 | joint=-7.3307 task=16.0217 ppl_loss=8.6910 ppl=9992.86
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 200 | joint=-7.3895 task=16.0674 ppl_loss=8.6779 ppl=10097.17
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 250 | joint=-7.2638 task=15.9608 ppl_loss=8.6970 ppl=10616.32
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 300 | joint=-7.3049 task=16.0199 ppl_loss=8.7150 ppl=11376.65
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 350 | joint=-7.3675 task=16.0746 ppl_loss=8.7071 ppl=11186.61
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 400 | joint=-7.3734 task=16.0930 ppl_loss=8.7197 ppl=11817.12
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 450 | joint=-7.3273 task=16.0510 ppl_loss=8.7237 ppl=11601.71
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 500 | joint=-7.3180 task=16.0464 ppl_loss=8.7284 ppl=11479.42
# [PEZ λ=1.0 ADV] Epoch 2/3, batch 550 | joint=-7.2946 task=16.0447 ppl_loss=8.7501 ppl=11708.41
# [PEZ λ=1.0 ADV] Epoch 2/3 | joint=-7.3076 task=16.0562 ppl_loss=8.7487 ppl=11668.20 val_loss=16.7023 val_acc=0.4517 prompt_ppl=4451.33
# Prompt: burychev incadrSfântul judetfehlerarrondissementMuzeul Timişoara suprafete
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 50 | joint=-6.9973 task=15.5963 ppl_loss=8.5989 ppl=9418.53
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 100 | joint=-7.2761 task=15.8877 ppl_loss=8.6116 ppl=11235.20
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 150 | joint=-7.1570 task=15.8404 ppl_loss=8.6835 ppl=10677.31
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 200 | joint=-7.1061 task=15.7930 ppl_loss=8.6869 ppl=10390.24
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 250 | joint=-7.1473 task=15.8403 ppl_loss=8.6929 ppl=10530.38
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 300 | joint=-7.1888 task=15.8694 ppl_loss=8.6806 ppl=10693.74
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 350 | joint=-7.1822 task=15.8832 ppl_loss=8.7009 ppl=10977.04
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 400 | joint=-7.1907 task=15.8876 ppl_loss=8.6968 ppl=10737.17
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 450 | joint=-7.1800 task=15.9127 ppl_loss=8.7327 ppl=11723.31
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 500 | joint=-7.1748 task=15.9268 ppl_loss=8.7520 ppl=11909.70
# [PEZ λ=1.0 ADV] Epoch 3/3, batch 550 | joint=-7.2416 task=15.9734 ppl_loss=8.7318 ppl=11755.12
# [PEZ λ=1.0 ADV] Epoch 3/3 | joint=-7.2015 task=15.9386 ppl_loss=8.7371 ppl=11667.91 val_loss=14.5557 val_acc=0.3810 prompt_ppl=13637.55
# Prompt: skeletal no suprafeteabia Correctioncada operations calibration summarize scaun

# %%
print("\n=== Summary (val_acc) ===")
print("Continuous Non-Adv:", cont_non_adv["history"]["val_acc"])
print("Continuous Adv:", cont_adv["history"]["val_acc"])
for name, lam, run in pez_runs:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")
for name, lam, run in pez_runs_adv:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")

# %%
# Grid search over lambda and learning rate for PEZ (balanced loader, non-adversarial)
print("\n" + "=" * 80)
print("GRID SEARCH: Lambda and Learning Rate for PEZ (Non-Adversarial, Balanced Loader)")
print("=" * 80)

lambda_grid = [0.0, 0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 1.0]
lr_grid_pez = [1e-4, 5e-4, 1e-3, 5e-3, 1e-2]
pez_grid_results = []

for lam in lambda_grid:
    for lr in lr_grid_pez:
        print(f"\n--- Testing λ={lam}, LR={lr} ---")
        # Create a temporary config with this learning rate
        temp_cfg = ExperimentConfig()
        temp_cfg.lr = lr
        
        result = train_pez(
            temp_cfg,
            tokenizer,
            gpt2_model,
            gpt2_tokenizer,
            train_dl,
            val_dl,
            lambda_ppl=lam,
            adversarial=False,
        )
        
        best_val_acc = max(result["history"]["val_acc"])
        final_val_acc = result["history"]["val_acc"][-1]
        prompt_ppl = result["history"]["prompt_ppl_ppx"][-1] if result["history"]["prompt_ppl_ppx"] else 0.0
        
        pez_grid_results.append({
            "lambda": lam,
            "lr": lr,
            "best_val_acc": best_val_acc,
            "final_val_acc": final_val_acc,
            "prompt_ppl": prompt_ppl,
            "history": result["history"]
        })
        print(f"λ={lam}, LR={lr:.0e}: best_val_acc={best_val_acc:.4f}, final_val_acc={final_val_acc:.4f}, prompt_ppl={prompt_ppl:.2f}")

print("\n" + "=" * 80)
print("PEZ Grid Search Results (sorted by best_val_acc):")
print("=" * 80)
sorted_results = sorted(pez_grid_results, key=lambda x: x["best_val_acc"], reverse=True)
for r in sorted_results[:10]:  # Show top 10
    print(f"λ={r['lambda']:.2f}, LR={r['lr']:.0e}: best_val_acc={r['best_val_acc']:.4f}, final_val_acc={r['final_val_acc']:.4f}, prompt_ppl={r['prompt_ppl']:.2f}")

best_pez_result = max(pez_grid_results, key=lambda x: x["best_val_acc"])
print(f"\nBest combination: λ={best_pez_result['lambda']:.2f}, LR={best_pez_result['lr']:.0e}")
print(f"  best_val_acc={best_pez_result['best_val_acc']:.4f}, final_val_acc={best_pez_result['final_val_acc']:.4f}")

# %%
print("\n=== Summary (val_acc) ===")
print("Continuous Non-Adv:", cont_non_adv["history"]["val_acc"])
print("Continuous Adv:", cont_adv["history"]["val_acc"])
for name, lam, run in pez_runs:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")
for name, lam, run in pez_runs_adv:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")

# %%
print("\n=== Summary (val_acc) ===")
print("Continuous Non-Adv:", cont_non_adv["history"]["val_acc"])
print("Continuous Adv:", cont_adv["history"]["val_acc"])
for name, lam, run in pez_runs:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")
for name, lam, run in pez_runs_adv:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")

# %%
print("\n=== Summary (val_acc) ===")
print("Continuous Non-Adv:", cont_non_adv["history"]["val_acc"])
print("Continuous Adv:", cont_adv["history"]["val_acc"])
for name, lam, run in pez_runs:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")for name, lam, run in pez_runs_adv:
    print(f"{name} λ={lam}: {run['history']['val_acc']}")
# Out:
# === Summary (val_acc) ===
# Continuous Non-Adv: [0.6217125382262997, 0.6217125382262997, 0.6217125382262997]
# Continuous Adv: [0.3782874617737003, 0.3782874617737003, 0.3782874617737003]
# pez_non_adv λ=0.0: [0.5996941896024465, 0.3801223241590214, 0.38837920489296635]
# pez_non_adv λ=0.01: [0.5336391437308868, 0.6085626911314985, 0.3785932721712538]
# pez_non_adv λ=0.05: [0.3892966360856269, 0.5446483180428134, 0.3782874617737003]
# pez_non_adv λ=0.1: [0.40336391437308866, 0.40152905198776756, 0.44128440366972477]
# pez_non_adv λ=0.5: [0.38409785932721713, 0.3856269113149847, 0.37737003058103974]
# pez_non_adv λ=1.0: [0.40703363914373086, 0.41039755351681956, 0.38623853211009174]
# pez_adv λ=0.0: [0.5718654434250765, 0.3874617737003058, 0.41681957186544344]
# pez_adv λ=0.01: [0.39755351681957185, 0.3801223241590214, 0.3782874617737003]
# pez_adv λ=0.05: [0.3782874617737003, 0.3892966360856269, 0.445565749235474]
# pez_adv λ=0.1: [0.5440366972477064, 0.3785932721712538, 0.39785932721712536]
# pez_adv λ=0.5: [0.39785932721712536, 0.3782874617737003, 0.3908256880733945]
# pez_adv λ=1.0: [0.591743119266055, 0.45168195718654436, 0.38103975535168194]

# %%
print("\n" + "=" * 80)
print("EXPERIMENT SUMMARY")
print("=" * 80)

# -----------------------------
# 1. Continuous soft prompt baselines
# -----------------------------
def summarize_continuous(name, result):
    vals = result["history"]["val_acc"]
    best = max(vals)
    final = vals[-1]
    print(f"{name:25s} | best_val_acc={best:.4f}  final_val_acc={final:.4f}")

print("\n=== Continuous Soft Prompt Baselines ===")
summarize_continuous("Continuous Non-Adv", cont_non_adv)
summarize_continuous("Continuous Adv",     cont_adv)

# -----------------------------
# 2. PEZ: non-adversarial vs adversarial by λ
# -----------------------------
# pez_runs:      [(name, lam, result_dict), ...]  # non-adv
# pez_runs_adv: [(name, lam, result_dict), ...]  # adv

nonadv_by_lam = {lam: run for (name, lam, run) in pez_runs}
adv_by_lam    = {lam: run for (name, lam, run) in pez_runs_adv}

all_lams = sorted(set(nonadv_by_lam.keys()) | set(adv_by_lam.keys()))

print("\n=== PEZ (Non-Adversarial vs Adversarial) by λ ===")
header = (
    f"{'λ':>6} | "
    f"{'non-adv best':>12} {'non-adv final':>12} {'non-adv prompt_ppl':>17} || "
    f"{'adv best':>10} {'adv final':>10} {'adv prompt_ppl':>15}"
)
print(header)
print("-" * len(header))

for lam in all_lams:
    nonadv = nonadv_by_lam.get(lam)
    adv    = adv_by_lam.get(lam)

    # Non-adv stats
    if nonadv is not None:
        nav_vals = nonadv["history"]["val_acc"]
        nav_best = max(nav_vals)
        nav_final = nav_vals[-1]
        nav_ppl = nonadv["history"].get("prompt_ppl_ppx", [float("nan")])[-1]
    else:
        nav_best = nav_final = nav_ppl = float("nan")

    # Adv stats
    if adv is not None:
        adv_vals = adv["history"]["val_acc"]
        adv_best = max(adv_vals)
        adv_final = adv_vals[-1]
        adv_ppl = adv["history"].get("prompt_ppl_ppx", [float("nan")])[-1]
    else:
        adv_best = adv_final = adv_ppl = float("nan")

    print(
        f"{lam:6.3f} | "
        f"{nav_best:12.4f} {nav_final:12.4f} {nav_ppl:17.2f} || "
        f"{adv_best:10.4f} {adv_final:10.4f} {adv_ppl:15.2f}"
    )

# -----------------------------
# 3. Example prompts per λ
# -----------------------------
print("\n=== Example Prompts per λ (Non-Adv vs Adv) ===")
for lam in all_lams:
    nonadv = nonadv_by_lam.get(lam)
    adv    = adv_by_lam.get(lam)

    print(f"\nλ = {lam}")
    if nonadv is not None:
        try:
            nav_prompt = nonadv["model"].decode_prompt(tokenizer)
        except Exception:
            nav_prompt = "<no decode_prompt method>"
        print(f"  [Non-Adv] {nav_prompt}")
    else:
        print("  [Non-Adv] (no run)")

    if adv is not None:
        try:
            adv_prompt = adv["model"].decode_prompt(tokenizer)
        except Exception:
            adv_prompt = "<no decode_prompt method>"
        print(f"  [Adv]     {adv_prompt}")
    else:
        print("  [Adv]     (no run)")

print("\n" + "=" * 80)
print("End of summary")
print("=" * 80)
# Out:
# ================================================================================
# EXPERIMENT SUMMARY
# ================================================================================
#
# === Continuous Soft Prompt Baselines ===
# Continuous Non-Adv        | best_val_acc=0.6217  final_val_acc=0.6217
# Continuous Adv            | best_val_acc=0.3783  final_val_acc=0.3783
#
# === PEZ (Non-Adversarial vs Adversarial) by λ ===
#      λ | non-adv best non-adv final non-adv prompt_ppl ||   adv best  adv final  adv prompt_ppl
# -----------------------------------------------------------------------------------------------
#  0.000 |       0.5997       0.3884              0.00 ||     0.5719     0.4168            0.00
#  0.010 |       0.6086       0.3786           7338.29 ||     0.3976     0.3783         2189.04
#  0.050 |       0.5446       0.3783           6141.04 ||     0.4456     0.4456        16442.28
#  0.100 |       0.4413       0.4413           3583.40 ||     0.5440     0.3979        16234.79
#  0.500 |       0.3856       0.3774            919.75 ||     0.3979     0.3908         8645.68
#  1.000 |       0.4104       0.3862           2387.97 ||     0.5917     0.3810        13637.55
#
# === Example Prompts per λ (Non-Adv vs Adv) ===
#
# λ = 0.0
#   [Non-Adv] cerinte pagina calorii trackback placeholder ConstanțaCamereMass senzati
#   [Adv]     costing căt Famous sticla?" suprafete Plastic totusi unlike emoți
#
# λ = 0.01
#   [Non-Adv] sunteti ciocolat hypothesis manancOEneeded proaspat zgomotaparatul
#   [Adv]     praf prevazut gradini caldura clientilor clientilor pastraone totirival
#
# λ = 0.05
#   [Non-Adv] mananc mananc superioara reteta proaspat ingrijire mananc
#   [Adv]     stunnedney compozitiApplicantsreclining**dial Leicestercyangrav
#
# λ = 0.1
#   [Non-Adv] varf compoziti ingrijire 04/2
#   [Adv]     Cyber Dayscosting mancare assureddium pharmacist laboratories suprafete producator
#
# λ = 0.5
#   [Non-Adv] awaycît achizitierung senzati taiat suprafete suprafete
#   [Adv]     pan chlorinechezcône moale Falconcifra 04/2 pretulfoli
#
# λ = 1.0
#   [Non-Adv] bebelus dumneavoastra taiatinability
#   [Adv]     skeletal no suprafeteabia Correctioncada operations calibration summarize scaun
#
# ================================================================================
# End of summary
# ================================================================================
